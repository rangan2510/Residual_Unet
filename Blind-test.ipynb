# %% [markdown]
# First, make some essential imports and then have a look at the data directory. The cell below gives a peek into what is in the BreakHis dataset. The goal is to initially create a pandas dataframe with two columns: images and labels. In this dataset, the file name itself contain the labels, so we will use that information.

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        pass

import time
import datetime
timestamp_exec_start = time.time()

# %% [markdown]
# Just the filenames are enough to get class information of the images. There are four classes for benign, and four for malignant. Ignoring the magnification, there is a total of 8 classes. The next cell simply makes a list of all the files that are images.

# %%
files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")
# Out:
# Processed  7909 files

# %% [markdown]
# Next, we build the class labels from the file names and then build up a dataframe. Based on the value of the "REDUCED_CLASSES" flag, we either take 8 classes, or we take 2 classes.
# - B  = Benign
#     * A = Adenosis
#     * F = Fibroadenoma
#     * TA = Tubular Adenoma
#     * PT = Phyllodes Tumor
# - M  = Malignant
#     * DC = Ductal Carcinoma
#     * LC = Lobular Carcinoma
#     * MC = Mucinous Carcinoma (Colloid)
#     * PC = Papillary Carcinoma

# %%
labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = True

X = []
Y = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))

data = {"images":X,"labels":Y}
images_df = pd.DataFrame(data, columns = ['images','labels'])
images_df.groupby("labels")["labels"].count()
# Out:
# labels
# 0    2480
# 1    5429
# Name: labels, dtype: int64

# %% [markdown]
# Import Pytorch Stuff

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

# %%
train, val = train_test_split(images_df, stratify=images_df.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6487, 1622)

# %%
class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
## Parameters for model

# Hyper parameters
num_epochs = 100
num_classes = 2
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Utility function for saving model
# During training, the loss values are stored in a list.
# We check the last two values to see if the loss has reduced.
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %% [markdown]
# Now, we create the model and train it.

# %%
import torch.nn as nn
from torchvision import models

def convrelu(in_channels, out_channels, kernel, padding):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel, padding=padding),
        nn.ReLU(inplace=True),
    )

#%%
class Plugin1(nn.Module):
    def __init__(self):
        super().__init__()
        self.reshape_0 = convrelu(512,256,1,0)
        self.conv = list(models.resnet18(pretrained=True).children())[7]
        self.upsample = nn.Upsample(scale_factor=2, mode='bicubic', align_corners=True)
        self.reshape_1 = convrelu(512, 256, 2,0)

    def forward(self,x):
        x = self.reshape_0(x)
        enc = self.conv(x)
        dec = self.upsample(enc)
        dec = self.reshape_1(dec)
        out = torch.cat([x,dec], dim=1)
        return out

# %%
class ResNetUNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()

        self.base_model = models.resnet18(pretrained=True)
        self.base_layers = list(self.base_model.children())

        self.layer0 = nn.Sequential(*self.base_layers[:3]) # size=(N, 64, x.H/2, x.W/2)
        self.layer0_1x1 = convrelu(64, 64, 1, 0)
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 64, x.H/4, x.W/4)
        self.layer1_1x1 = convrelu(64, 64, 1, 0)
        self.layer2 = self.base_layers[5]  # size=(N, 128, x.H/8, x.W/8)
        self.layer2_1x1 = convrelu(128, 128, 1, 0)
        self.layer3 = self.base_layers[6]  # size=(N, 256, x.H/16, x.W/16)
        self.layer3_1x1 = convrelu(256, 256, 1, 0)
        self.layer4 = self.base_layers[7]  # size=(N, 512, x.H/32, x.W/32)
        self.layer4_1x1 = convrelu(512, 512, 1, 0)

        self.upsample = nn.Upsample(scale_factor=2, mode='bicubic', align_corners=True) # this is now not being used. Keeping it for testing only.
        
        
        self.conv_up3 = convrelu(256, 512, 3, 1)
        self.conv_up2 = convrelu(128 + 512, 256, 3, 1)
        self.conv_up1 = convrelu(64 + 256, 256, 3, 1)
        self.conv_up0 = convrelu(64 + 256, 128, 3, 1)

        self.conv_original_size0 = convrelu(3, 64, 3, 1)
        self.conv_original_size1 = convrelu(64, 64, 3, 1)
        self.conv_original_size2 = convrelu(64 + 128, 64, 3, 1)

        self.conv_last = nn.Conv2d(64, n_class, 1)
        
        self.avg = nn.AvgPool2d(8) # 8x2x28x28
        self.fc = nn.Linear(n_class*28*28,8)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, input):
        x_original = self.conv_original_size0(input)
        x_original = self.conv_original_size1(x_original)

        layer0 = self.layer0(input)
        layer1 = self.layer1(layer0)
        layer2 = self.layer2(layer1)
        layer3 = self.layer3(layer2)
        # layer4 = self.layer4(layer3)

        # layer4 = self.layer4_1x1(layer4)
        # x = self.upsample(layer4)
        
        layer3 = self.layer3_1x1(layer3)
        # x = torch.cat([x, layer3], dim=1)
        x = self.conv_up3(layer3)
        x = self.upsample(x)
        layer2 = self.layer2_1x1(layer2)
        x = torch.cat([x, layer2], dim=1)
        x = self.conv_up2(x)
        x = self.upsample(x)
        
        layer1 = self.layer1_1x1(layer1)
        x = torch.cat([x, layer1], dim=1)
        x = self.conv_up1(x)
        x = self.upsample(x)  #       
        layer0 = self.layer0_1x1(layer0)
        x = torch.cat([x, layer0], dim=1)
        x = self.conv_up0(x)
        x = self.upsample(x)
        x = torch.cat([x, x_original], dim=1)
        x = self.conv_original_size2(x)

        out = self.conv_last(x)  
        out = self.avg(out)
        out = out.view(-1,num_classes*28*28)
        out = self.fc(out)
        # out = self.softmax(out)
        
        return out

# %%
model = ResNetUNet(num_classes).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 124MB/s]

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %% [markdown]
# At this point, we download a pre-trained model that was trained during the previous sesstions. OneDrive allows direct downloads. Simply open the file in the browser in OneDrive and copy the link in the **embed** code. In the URL string, replace "embed" with "download" and you are good to go. Every time you upload a file, simply change the URL.

# %%
import os
import urllib.request


url = "https://onedrive.live.com/download?cid=E5569BBAB912B6A5&resid=E5569BBAB912B6A5%21533330&authkey=AJe2lbuQPspQVBE"
file_name = "download.dct"
print("Downloading pre-trained model state...")
urllib.request.urlretrieve(url, file_name)
print("Done!")
model.load_state_dict(torch.load(file_name))
import os.path
if os.path.exists(file_name):
    try:
        model.load_state_dict(torch.load(file_name))
        print("Downloaded model state loaded successfully.")
    except:
        print("Error loading state dict.")
# Out:
# Downloading pre-trained model state...
# Done!
# Downloaded model state loaded successfully.

# %%
# Train the model
timestamp_train_start = time.time()


loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 8.999962374567986
#    Saving model state
# Epoch [1/100], Step [200/406], Loss: 0.0057
# Epoch [1/100], Step [300/406], Loss: 0.0090
# Epoch [1/100], Step [400/406], Loss: 0.0143
# Epoch done in  0:02:47.658359
# Epoch  2  started...
# Epoch [2/100], Step [100/406], Loss: 0.0029
# Epoch [2/100], Step [200/406], Loss: 0.1319
# Epoch [2/100], Step [300/406], Loss: 0.0001
# Epoch [2/100], Step [400/406], Loss: 0.1898
# Epoch done in  0:02:46.290828
# Epoch  3  started...
# Epoch [3/100], Step [100/406], Loss: 0.0063
# Epoch [3/100], Step [200/406], Loss: 0.1280
# Epoch [3/100], Step [300/406], Loss: 0.0004
# Epoch [3/100], Step [400/406], Loss: 0.0050
# Epoch done in  0:02:45.944856
# Epoch  4  started...
# Epoch [4/100], Step [100/406], Loss: 0.0004
# Epoch [4/100], Step [200/406], Loss: 0.0019
# Epoch [4/100], Step [300/406], Loss: 0.0004
# Epoch [4/100], Step [400/406], Loss: 0.0088
# Epoch done in  0:02:46.161819
# Epoch  5  started...
# Epoch [5/100], Step [100/406], Loss: 0.0011
# Epoch [5/100], Step [200/406], Loss: 0.0000
# Epoch [5/100], Step [300/406], Loss: 0.0158
# Epoch [5/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.192839
# Epoch  6  started...
# Epoch [6/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 3.482401371002197e-05
#    Saving model state
# Epoch [6/100], Step [200/406], Loss: 0.0004
# Epoch [6/100], Step [300/406], Loss: 0.0000
# Epoch [6/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:46.368811
# Epoch  7  started...
# Epoch [7/100], Step [100/406], Loss: 0.0000
# Epoch [7/100], Step [200/406], Loss: 0.0006
# Epoch [7/100], Step [300/406], Loss: 0.0003
# Epoch [7/100], Step [400/406], Loss: 0.0040
# Epoch done in  0:02:45.858668
# Epoch  8  started...
# Epoch [8/100], Step [100/406], Loss: 0.0010
# Epoch [8/100], Step [200/406], Loss: 0.0001
# Epoch [8/100], Step [300/406], Loss: 0.0008
# Epoch [8/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.031599
# Epoch  9  started...
# Epoch [9/100], Step [100/406], Loss: 0.0009
# Epoch [9/100], Step [200/406], Loss: 0.0001
# Epoch [9/100], Step [300/406], Loss: 0.0000
# => Loss reduced by:	 1.3113021850585938e-06
#    Saving model state
# Epoch [9/100], Step [400/406], Loss: 0.0035
# Epoch done in  0:02:46.852041
# Epoch  10  started...
# Epoch [10/100], Step [100/406], Loss: 0.0000
# Epoch [10/100], Step [200/406], Loss: 0.0000
# Epoch [10/100], Step [300/406], Loss: 0.0099
# Epoch [10/100], Step [400/406], Loss: 0.0005
# Epoch done in  0:02:46.378342
# Epoch  11  started...
# Epoch [11/100], Step [100/406], Loss: 0.0007
# Epoch [11/100], Step [200/406], Loss: 0.1582
# Epoch [11/100], Step [300/406], Loss: 0.0000
# Epoch [11/100], Step [400/406], Loss: 0.0016
# Epoch done in  0:02:46.179999
# Epoch  12  started...
# Epoch [12/100], Step [100/406], Loss: 0.0000
# Epoch [12/100], Step [200/406], Loss: 0.0003
# Epoch [12/100], Step [300/406], Loss: 0.0000
# Epoch [12/100], Step [400/406], Loss: 0.0034
# Epoch done in  0:02:46.254852
# Epoch  13  started...
# Epoch [13/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 2.980232238769531e-07
#    Saving model state
# Epoch [13/100], Step [200/406], Loss: 0.0007
# Epoch [13/100], Step [300/406], Loss: 0.0003
# Epoch [13/100], Step [400/406], Loss: 0.0004
# Epoch done in  0:02:46.501925
# Epoch  14  started...
# Epoch [14/100], Step [100/406], Loss: 0.0001
# Epoch [14/100], Step [200/406], Loss: 0.0055
# Epoch [14/100], Step [300/406], Loss: 0.0141
# Epoch [14/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.313982
# Epoch  15  started...
# Epoch [15/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 3.8743019104003906e-07
#    Saving model state
# Epoch [15/100], Step [200/406], Loss: 0.0000
# Epoch [15/100], Step [300/406], Loss: 0.0001
# Epoch [15/100], Step [400/406], Loss: 0.0000
# => Loss reduced by:	 7.748603820800781e-07
#    Saving model state
# Epoch done in  0:02:46.447334
# Epoch  16  started...
# Epoch [16/100], Step [100/406], Loss: 0.0002
# Epoch [16/100], Step [200/406], Loss: 0.0000
# Epoch [16/100], Step [300/406], Loss: 0.0010
# Epoch [16/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.145684
# Epoch  17  started...
# Epoch [17/100], Step [100/406], Loss: 0.0002
# Epoch [17/100], Step [200/406], Loss: 0.0013
# Epoch [17/100], Step [300/406], Loss: 0.0000
# Epoch [17/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.296775
# Epoch  18  started...
# Epoch [18/100], Step [100/406], Loss: 0.0001
# Epoch [18/100], Step [200/406], Loss: 0.0000
# Epoch [18/100], Step [300/406], Loss: 0.0000
# Epoch [18/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.725527
# Epoch  19  started...
# Epoch [19/100], Step [100/406], Loss: 0.0000
# Epoch [19/100], Step [200/406], Loss: 0.0000
# Epoch [19/100], Step [300/406], Loss: 0.0000
# Epoch [19/100], Step [400/406], Loss: 0.0008
# Epoch done in  0:02:46.144317
# Epoch  20  started...
# Epoch [20/100], Step [100/406], Loss: 0.0001
# Epoch [20/100], Step [200/406], Loss: 0.0000
# Epoch [20/100], Step [300/406], Loss: 0.0085
# Epoch [20/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.260807
# Epoch  21  started...
# Epoch [21/100], Step [100/406], Loss: 0.0001
# Epoch [21/100], Step [200/406], Loss: 0.0018
# Epoch [21/100], Step [300/406], Loss: 0.0001
# Epoch [21/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.184210
# Epoch  22  started...
# Epoch [22/100], Step [100/406], Loss: 0.0003
# Epoch [22/100], Step [200/406], Loss: 0.0000
# Epoch [22/100], Step [300/406], Loss: 0.0000
# Epoch [22/100], Step [400/406], Loss: 0.2178
# Epoch done in  0:02:46.292221
# Epoch  23  started...
# Epoch [23/100], Step [100/406], Loss: 0.0008
# Epoch [23/100], Step [200/406], Loss: 0.0000
# Epoch [23/100], Step [300/406], Loss: 0.0000
# Epoch [23/100], Step [400/406], Loss: 0.0117
# Epoch done in  0:02:46.935339
# Epoch  24  started...
# Epoch [24/100], Step [100/406], Loss: 0.0000
# Epoch [24/100], Step [200/406], Loss: 0.0002
# Epoch [24/100], Step [300/406], Loss: 0.0000
# Epoch [24/100], Step [400/406], Loss: 0.0041
# Epoch done in  0:02:46.353512
# Epoch  25  started...
# Epoch [25/100], Step [100/406], Loss: 0.0070
# Epoch [25/100], Step [200/406], Loss: 0.0002
# Epoch [25/100], Step [300/406], Loss: 0.0000
# Epoch [25/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.058599
# Epoch  26  started...
# Epoch [26/100], Step [100/406], Loss: 0.0080
# Epoch [26/100], Step [200/406], Loss: 0.0001
# Epoch [26/100], Step [300/406], Loss: 0.0000
# Epoch [26/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.416088
# Epoch  27  started...
# Epoch [27/100], Step [100/406], Loss: 0.0001
# Epoch [27/100], Step [200/406], Loss: 0.1556
# Epoch [27/100], Step [300/406], Loss: 0.0009
# Epoch [27/100], Step [400/406], Loss: 0.0034
# Epoch done in  0:02:46.044206
# Epoch  28  started...
# Epoch [28/100], Step [100/406], Loss: 0.0002
# Epoch [28/100], Step [200/406], Loss: 0.0000
# Epoch [28/100], Step [300/406], Loss: 0.0047
# Epoch [28/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.289975
# Epoch  29  started...
# Epoch [29/100], Step [100/406], Loss: 0.0000
# Epoch [29/100], Step [200/406], Loss: 0.0001
# Epoch [29/100], Step [300/406], Loss: 0.0011
# Epoch [29/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.302786
# Epoch  30  started...
# Epoch [30/100], Step [100/406], Loss: 0.0002
# Epoch [30/100], Step [200/406], Loss: 0.0000
# Epoch [30/100], Step [300/406], Loss: 0.0011
# Epoch [30/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:53.083070
# Epoch  31  started...
# Epoch [31/100], Step [100/406], Loss: 0.0001
# Epoch [31/100], Step [200/406], Loss: 0.0024
# Epoch [31/100], Step [300/406], Loss: 0.0001
# Epoch [31/100], Step [400/406], Loss: 0.0023
# Epoch done in  0:02:45.880525
# Epoch  32  started...
# Epoch [32/100], Step [100/406], Loss: 0.2771
# Epoch [32/100], Step [200/406], Loss: 0.0000
# Epoch [32/100], Step [300/406], Loss: 0.0008
# Epoch [32/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.091546
# Epoch  33  started...
# Epoch [33/100], Step [100/406], Loss: 0.0001
# Epoch [33/100], Step [200/406], Loss: 0.0000
# Epoch [33/100], Step [300/406], Loss: 0.0001
# Epoch [33/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.356738
# Epoch  34  started...
# Epoch [34/100], Step [100/406], Loss: 0.0221
# Epoch [34/100], Step [200/406], Loss: 0.0469
# Epoch [34/100], Step [300/406], Loss: 0.0860
# Epoch [34/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:53.295580
# Epoch  35  started...
# Epoch [35/100], Step [100/406], Loss: 0.0002
# Epoch [35/100], Step [200/406], Loss: 0.0053
# Epoch [35/100], Step [300/406], Loss: 0.0001
# Epoch [35/100], Step [400/406], Loss: 0.1528
# Epoch done in  0:02:45.881181
# Epoch  36  started...
# Epoch [36/100], Step [100/406], Loss: 0.0000
# Epoch [36/100], Step [200/406], Loss: 0.0000
# Epoch [36/100], Step [300/406], Loss: 0.0000
# Epoch [36/100], Step [400/406], Loss: 0.0018
# Epoch done in  0:02:46.130676
# Epoch  37  started...
# Epoch [37/100], Step [100/406], Loss: 0.0000
# Epoch [37/100], Step [200/406], Loss: 0.0002
# Epoch [37/100], Step [300/406], Loss: 0.0067
# Epoch [37/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.244796
# Epoch  38  started...
# Epoch [38/100], Step [100/406], Loss: 0.0002
# Epoch [38/100], Step [200/406], Loss: 0.0000
# Epoch [38/100], Step [300/406], Loss: 0.0000
# Epoch [38/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.218439
# Epoch  39  started...
# Epoch [39/100], Step [100/406], Loss: 0.0000
# Epoch [39/100], Step [200/406], Loss: 0.0000
# => Loss reduced by:	 2.9802322387695312e-08
#    Saving model state
# Epoch [39/100], Step [300/406], Loss: 0.0000
# Epoch [39/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.136731
# Epoch  40  started...
# Epoch [40/100], Step [100/406], Loss: 0.0000
# Epoch [40/100], Step [200/406], Loss: 0.0003
# Epoch [40/100], Step [300/406], Loss: 0.0001
# Epoch [40/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.036809
# Epoch  41  started...
# Epoch [41/100], Step [100/406], Loss: 0.0002
# Epoch [41/100], Step [200/406], Loss: 0.0000
# Epoch [41/100], Step [300/406], Loss: 0.0000
# Epoch [41/100], Step [400/406], Loss: 0.0024
# Epoch done in  0:02:46.093591
# Epoch  42  started...
# Epoch [42/100], Step [100/406], Loss: 0.0000
# Epoch [42/100], Step [200/406], Loss: 0.0000
# Epoch [42/100], Step [300/406], Loss: 0.0001
# Epoch [42/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.289285
# Epoch  43  started...
# Epoch [43/100], Step [100/406], Loss: 0.0000
# Epoch [43/100], Step [200/406], Loss: 0.0006
# Epoch [43/100], Step [300/406], Loss: 0.0111
# Epoch [43/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.215675
# Epoch  44  started...
# Epoch [44/100], Step [100/406], Loss: 0.0000
# Epoch [44/100], Step [200/406], Loss: 0.0002
# Epoch [44/100], Step [300/406], Loss: 0.0000
# Epoch [44/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.217657
# Epoch  45  started...
# Epoch [45/100], Step [100/406], Loss: 0.0000
# Epoch [45/100], Step [200/406], Loss: 0.0000
# Epoch [45/100], Step [300/406], Loss: 0.0688
# Epoch [45/100], Step [400/406], Loss: 0.1022
# Epoch done in  0:02:46.418808
# Epoch  46  started...
# Epoch [46/100], Step [100/406], Loss: 0.0005
# Epoch [46/100], Step [200/406], Loss: 0.0000
# Epoch [46/100], Step [300/406], Loss: 0.0000
# Epoch [46/100], Step [400/406], Loss: 0.0005
# Epoch done in  0:02:46.230808
# Epoch  47  started...
# Epoch [47/100], Step [100/406], Loss: 0.0001
# Epoch [47/100], Step [200/406], Loss: 0.0000
# Epoch [47/100], Step [300/406], Loss: 0.0000
# Epoch [47/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:46.013108
# Epoch  48  started...
# Epoch [48/100], Step [100/406], Loss: 0.0000
# Epoch [48/100], Step [200/406], Loss: 0.0000
# Epoch [48/100], Step [300/406], Loss: 0.0000
# Epoch [48/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.064868
# Epoch  49  started...
# Epoch [49/100], Step [100/406], Loss: 0.0000
# Epoch [49/100], Step [200/406], Loss: 0.0001
# Epoch [49/100], Step [300/406], Loss: 0.0002
# Epoch [49/100], Step [400/406], Loss: 0.0013
# Epoch done in  0:02:46.365054
# Epoch  50  started...
# Epoch [50/100], Step [100/406], Loss: 0.0000
# Epoch [50/100], Step [200/406], Loss: 0.0007
# Epoch [50/100], Step [300/406], Loss: 0.0018
# Epoch [50/100], Step [400/406], Loss: 0.0076
# Epoch done in  0:02:46.233079
# Epoch  51  started...
# Epoch [51/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [51/100], Step [200/406], Loss: 0.0000
# Epoch [51/100], Step [300/406], Loss: 0.0048
# Epoch [51/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.233021
# Epoch  52  started...
# Epoch [52/100], Step [100/406], Loss: 0.0000
# Epoch [52/100], Step [200/406], Loss: 0.0000
# Epoch [52/100], Step [300/406], Loss: 0.0000
# Epoch [52/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:46.074233
# Epoch  53  started...
# Epoch [53/100], Step [100/406], Loss: 0.0000
# Epoch [53/100], Step [200/406], Loss: 0.1750
# Epoch [53/100], Step [300/406], Loss: 0.0000
# Epoch [53/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.624825
# Epoch  54  started...
# Epoch [54/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [54/100], Step [200/406], Loss: 0.0000
# Epoch [54/100], Step [300/406], Loss: 0.0000
# Epoch [54/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.535903
# Epoch  55  started...
# Epoch [55/100], Step [100/406], Loss: 0.0000
# Epoch [55/100], Step [200/406], Loss: 0.0000
# Epoch [55/100], Step [300/406], Loss: 0.0000
# Epoch [55/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.583715
# Epoch  56  started...
# Epoch [56/100], Step [100/406], Loss: 0.0000
# Epoch [56/100], Step [200/406], Loss: 0.0000
# Epoch [56/100], Step [300/406], Loss: 0.1225
# Epoch [56/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.353718
# Epoch  57  started...
# Epoch [57/100], Step [100/406], Loss: 0.0000
# Epoch [57/100], Step [200/406], Loss: 0.0000
# Epoch [57/100], Step [300/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [57/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.416635
# Epoch  58  started...
# Epoch [58/100], Step [100/406], Loss: 0.0000
# Epoch [58/100], Step [200/406], Loss: 0.0000
# Epoch [58/100], Step [300/406], Loss: 0.0000
# Epoch [58/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.314095
# Epoch  59  started...
# Epoch [59/100], Step [100/406], Loss: 0.0002
# Epoch [59/100], Step [200/406], Loss: 0.0000
# Epoch [59/100], Step [300/406], Loss: 0.0000
# Epoch [59/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.222737
# Epoch  60  started...
# Epoch [60/100], Step [100/406], Loss: 0.0071
# Epoch [60/100], Step [200/406], Loss: 0.0000
# Epoch [60/100], Step [300/406], Loss: 0.3328
# Epoch [60/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.917117
# Epoch  61  started...
# Epoch [61/100], Step [100/406], Loss: 0.0002
# Epoch [61/100], Step [200/406], Loss: 0.0000
# Epoch [61/100], Step [300/406], Loss: 0.0002
# Epoch [61/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.335029
# Epoch  62  started...
# Epoch [62/100], Step [100/406], Loss: 0.0000
# Epoch [62/100], Step [200/406], Loss: 0.0002
# Epoch [62/100], Step [300/406], Loss: 0.0000
# Epoch [62/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.265314
# Epoch  63  started...
# Epoch [63/100], Step [100/406], Loss: 0.0001
# Epoch [63/100], Step [200/406], Loss: 0.0000
# Epoch [63/100], Step [300/406], Loss: 0.0000
# Epoch [63/100], Step [400/406], Loss: 0.0005
# Epoch done in  0:02:45.963602
# Epoch  64  started...
# Epoch [64/100], Step [100/406], Loss: 0.0005
# Epoch [64/100], Step [200/406], Loss: 0.0000
# Epoch [64/100], Step [300/406], Loss: 0.0000
# Epoch [64/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:47.645723
# Epoch  65  started...
# Epoch [65/100], Step [100/406], Loss: 0.0000
# Epoch [65/100], Step [200/406], Loss: 0.0001
# Epoch [65/100], Step [300/406], Loss: 0.0000
# Epoch [65/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:46.228437
# Epoch  66  started...
# Epoch [66/100], Step [100/406], Loss: 0.0466
# Epoch [66/100], Step [200/406], Loss: 0.0000
# Epoch [66/100], Step [300/406], Loss: 0.0001
# Epoch [66/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.567024
# Epoch  67  started...
# Epoch [67/100], Step [100/406], Loss: 0.0006
# Epoch [67/100], Step [200/406], Loss: 0.0012
# Epoch [67/100], Step [300/406], Loss: 0.0000
# Epoch [67/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.185918
# Epoch  68  started...
# Epoch [68/100], Step [100/406], Loss: 0.0001
# Epoch [68/100], Step [200/406], Loss: 0.0002
# Epoch [68/100], Step [300/406], Loss: 0.0000
# Epoch [68/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.913157
# Epoch  69  started...
# Epoch [69/100], Step [100/406], Loss: 0.0000
# Epoch [69/100], Step [200/406], Loss: 0.0000
# Epoch [69/100], Step [300/406], Loss: 0.0000
# Epoch [69/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.397704
# Epoch  70  started...
# Epoch [70/100], Step [100/406], Loss: 0.0000
# Epoch [70/100], Step [200/406], Loss: 0.0000
# Epoch [70/100], Step [300/406], Loss: 0.0000
# Epoch [70/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:46.023056
# Epoch  71  started...
# Epoch [71/100], Step [100/406], Loss: 0.0000
# Epoch [71/100], Step [200/406], Loss: 0.1647
# Epoch [71/100], Step [300/406], Loss: 0.0000
# Epoch [71/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.961485
# Epoch  72  started...
# Epoch [72/100], Step [100/406], Loss: 0.0000
# Epoch [72/100], Step [200/406], Loss: 0.0094
# Epoch [72/100], Step [300/406], Loss: 0.0001
# Epoch [72/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.962734
# Epoch  73  started...
# Epoch [73/100], Step [100/406], Loss: 0.0000
# Epoch [73/100], Step [200/406], Loss: 0.0001
# Epoch [73/100], Step [300/406], Loss: 0.0000
# Epoch [73/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.114199
# Epoch  74  started...
# Epoch [74/100], Step [100/406], Loss: 0.0000
# Epoch [74/100], Step [200/406], Loss: 0.0000
# Epoch [74/100], Step [300/406], Loss: 0.0006
# Epoch [74/100], Step [400/406], Loss: 0.0002
# Epoch done in  0:02:45.863396
# Epoch  75  started...
# Epoch [75/100], Step [100/406], Loss: 0.0000
# Epoch [75/100], Step [200/406], Loss: 0.0000
# Epoch [75/100], Step [300/406], Loss: 0.0009
# Epoch [75/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.038985
# Epoch  76  started...
# Epoch [76/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [76/100], Step [200/406], Loss: 0.0000
# Epoch [76/100], Step [300/406], Loss: 0.0019
# Epoch [76/100], Step [400/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch done in  0:02:46.175808
# Epoch  77  started...
# Epoch [77/100], Step [100/406], Loss: 0.0004
# Epoch [77/100], Step [200/406], Loss: 0.0000
# Epoch [77/100], Step [300/406], Loss: 0.0107
# Epoch [77/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.041945
# Epoch  78  started...
# Epoch [78/100], Step [100/406], Loss: 0.0000
# Epoch [78/100], Step [200/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [78/100], Step [300/406], Loss: 0.0001
# Epoch [78/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.976937
# Epoch  79  started...
# Epoch [79/100], Step [100/406], Loss: 0.0001
# Epoch [79/100], Step [200/406], Loss: 0.0000
# Epoch [79/100], Step [300/406], Loss: 0.0001
# Epoch [79/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.000391
# Epoch  80  started...
# Epoch [80/100], Step [100/406], Loss: 0.0000
# Epoch [80/100], Step [200/406], Loss: 0.0001
# Epoch [80/100], Step [300/406], Loss: 0.0006
# Epoch [80/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.071307
# Epoch  81  started...
# Epoch [81/100], Step [100/406], Loss: 0.0000
# Epoch [81/100], Step [200/406], Loss: 0.0024
# Epoch [81/100], Step [300/406], Loss: 0.0000
# Epoch [81/100], Step [400/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch done in  0:02:55.712548
# Epoch  82  started...
# Epoch [82/100], Step [100/406], Loss: 0.0000
# Epoch [82/100], Step [200/406], Loss: 0.0000
# Epoch [82/100], Step [300/406], Loss: 0.0000
# Epoch [82/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.003363
# Epoch  83  started...
# Epoch [83/100], Step [100/406], Loss: 0.0000
# Epoch [83/100], Step [200/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [83/100], Step [300/406], Loss: 0.0000
# Epoch [83/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.113510
# Epoch  84  started...
# Epoch [84/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [84/100], Step [200/406], Loss: 0.0000
# Epoch [84/100], Step [300/406], Loss: 0.0000
# Epoch [84/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.035925
# Epoch  85  started...
# Epoch [85/100], Step [100/406], Loss: 0.0000
# Epoch [85/100], Step [200/406], Loss: 0.0059
# Epoch [85/100], Step [300/406], Loss: 0.0000
# Epoch [85/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.044786
# Epoch  86  started...
# Epoch [86/100], Step [100/406], Loss: 0.0006
# Epoch [86/100], Step [200/406], Loss: 0.0000
# Epoch [86/100], Step [300/406], Loss: 0.0001
# Epoch [86/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.883840
# Epoch  87  started...
# Epoch [87/100], Step [100/406], Loss: 0.0000
# Epoch [87/100], Step [200/406], Loss: 0.0001
# Epoch [87/100], Step [300/406], Loss: 0.0000
# Epoch [87/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:45.998145
# Epoch  88  started...
# Epoch [88/100], Step [100/406], Loss: 0.0050
# Epoch [88/100], Step [200/406], Loss: 0.0000
# Epoch [88/100], Step [300/406], Loss: 0.0000
# Epoch [88/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.929473
# Epoch  89  started...
# Epoch [89/100], Step [100/406], Loss: 0.0000
# Epoch [89/100], Step [200/406], Loss: 0.0000
# Epoch [89/100], Step [300/406], Loss: 0.0000
# Epoch [89/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.095210
# Epoch  90  started...
# Epoch [90/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [90/100], Step [200/406], Loss: 0.0000
# Epoch [90/100], Step [300/406], Loss: 0.0000
# Epoch [90/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.123018
# Epoch  91  started...
# Epoch [91/100], Step [100/406], Loss: 0.0000
# Epoch [91/100], Step [200/406], Loss: 0.0001
# Epoch [91/100], Step [300/406], Loss: 0.0003
# Epoch [91/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.166882
# Epoch  92  started...
# Epoch [92/100], Step [100/406], Loss: 0.0003
# Epoch [92/100], Step [200/406], Loss: 0.0000
# Epoch [92/100], Step [300/406], Loss: 0.0018
# Epoch [92/100], Step [400/406], Loss: 0.0001
# Epoch done in  0:02:46.092840
# Epoch  93  started...
# Epoch [93/100], Step [100/406], Loss: 0.0005
# Epoch [93/100], Step [200/406], Loss: 0.0000
# Epoch [93/100], Step [300/406], Loss: 0.0000
# Epoch [93/100], Step [400/406], Loss: 0.0004
# Epoch done in  0:02:46.003653
# Epoch  94  started...
# Epoch [94/100], Step [100/406], Loss: 0.0001
# Epoch [94/100], Step [200/406], Loss: 0.0025
# Epoch [94/100], Step [300/406], Loss: 0.0012
# Epoch [94/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.158943
# Epoch  95  started...
# Epoch [95/100], Step [100/406], Loss: 0.0001
# Epoch [95/100], Step [200/406], Loss: 0.0001
# Epoch [95/100], Step [300/406], Loss: 0.0000
# Epoch [95/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:45.995718
# Epoch  96  started...
# Epoch [96/100], Step [100/406], Loss: 0.0000
# Epoch [96/100], Step [200/406], Loss: 0.0000
# Epoch [96/100], Step [300/406], Loss: 0.0001
# Epoch [96/100], Step [400/406], Loss: 0.0079
# Epoch done in  0:02:45.947955
# Epoch  97  started...
# Epoch [97/100], Step [100/406], Loss: 0.0003
# Epoch [97/100], Step [200/406], Loss: 0.0000
# Epoch [97/100], Step [300/406], Loss: 0.0000
# Epoch [97/100], Step [400/406], Loss: 0.1964
# Epoch done in  0:02:46.127619
# Epoch  98  started...
# Epoch [98/100], Step [100/406], Loss: 0.0000
# Epoch [98/100], Step [200/406], Loss: 0.0000
# Epoch [98/100], Step [300/406], Loss: 0.0000
# Epoch [98/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.180341
# Epoch  99  started...
# Epoch [99/100], Step [100/406], Loss: 0.0005
# Epoch [99/100], Step [200/406], Loss: 0.0000
# Epoch [99/100], Step [300/406], Loss: 0.0000
# Epoch [99/100], Step [400/406], Loss: 0.0003
# Epoch done in  0:02:46.010662
# Epoch  100  started...
# Epoch [100/100], Step [100/406], Loss: 0.0000
# => Loss reduced by:	 0.0
#    Saving model state
# Epoch [100/100], Step [200/406], Loss: 0.0000
# Epoch [100/100], Step [300/406], Loss: 0.0000
# Epoch [100/100], Step [400/406], Loss: 0.0000
# Epoch done in  0:02:46.378141
# Training done in  4:37:25.424121

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 99.50678175092479 %

# %%
timestamp_exec_end = time.time()
print("Total execution time: ",str(datetime.timedelta(seconds=(timestamp_exec_end - timestamp_exec_start))))
# Out:
# Total execution time:  4:38:20.625450

# %% [markdown]
# #BLIND TESTING

# %%
files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'jpg'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")

X = []
Y = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    if x[0] == 'b':
        y = 0
        X.append(str(f))
        Y.append(y)
    elif x[0] == 'i':
        if x[1] == 'v':
            y = 1
            X.append(str(f))
            Y.append(y)

data = {"images":X,"labels":Y}
images_df = pd.DataFrame(data, columns = ['images','labels'])
images_df.groupby("labels")["labels"].count()
# Out:
# Processed  400 files
# labels
# 0    100
# 1    100
# Name: labels, dtype: int64

# %%
dataset_blind = MyDataset(df_data=images_df,transform=trans_valid)
blind_valid = DataLoader(dataset = dataset_blind, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %%
print(len(blind_valid))
# Out:
# 25

# %%
model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in blind_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the test images: 98.0 %
