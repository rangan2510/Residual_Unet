# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
        # print(os.path.join(dirname, filename))

import time
import datetime
timestamp_exec_start = time.time()


files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")


labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = False

X = []
Y = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))

data = {"images":X,"labels":Y}
images_df = pd.DataFrame(data, columns = ['images','labels'])
images_df.groupby("labels")["labels"].count()
# Out:
# Processed  7909 files
# labels
# 0     444
# 1    1014
# 2     569
# 3     453
# 4    3451
# 5     626
# 6     792
# 7     560
# Name: labels, dtype: int64

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

# %%
train, val = train_test_split(images_df, stratify=images_df.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6327, 1582)

# %%
class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
## Parameters for model

# Hyper parameters
num_epochs = 200
num_classes = 8
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Utility function for saving model
# During training, the loss values are stored in a list.
# We check the last two values to see if the loss has reduced.
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %% [markdown]
# Now, we create the model and train it.

# %%
import torch.nn as nn
from torchvision import models


model =  models.shufflenet_v2_x1_0(pretrained=True)
model.fc = nn.Linear(in_features=1024, out_features=num_classes, bias=True)
model = model.to(device)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to /root/.cache/torch/checkpoints/shufflenetv2_x1-5666bf0f80.pth
# HBox(children=(FloatProgress(value=0.0, max=9218294.0), HTML(value='')))
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(464, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=1024, out_features=8, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %% [markdown]
# import os
# import urllib.request
# url = "https://onedrive.live.com/download?cid=E5569BBAB912B6A5&resid=E5569BBAB912B6A5%21532997&authkey=AIIbJpY85FBd61c"
# file_name = "download.dct"
# print("Downloading pre-trained model state...")
# urllib.request.urlretrieve(url, file_name)
# print("Done!")
# model.load_state_dict(torch.load(file_name))
# import os.path
# if os.path.exists(file_name):
#     try:
#         model.load_state_dict(torch.load(file_name))
#         print("Downloaded model state loaded successfully.")
#     except:
#         print("Error loading state dict.")

# %%
# Train the model
timestamp_train_start = time.time()

loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/200], Step [100/396], Loss: 1.9477
# => Loss reduced by:	 7.052331805229187
#    Saving model state
# Epoch [1/200], Step [200/396], Loss: 1.6581
# => Loss reduced by:	 0.2896103858947754
#    Saving model state
# Epoch [1/200], Step [300/396], Loss: 1.8876
# Epoch done in  0:02:27.466482
# Epoch  2  started...
# Epoch [2/200], Step [100/396], Loss: 1.1990
# => Loss reduced by:	 0.4590599536895752
#    Saving model state
# Epoch [2/200], Step [200/396], Loss: 1.3895
# Epoch [2/200], Step [300/396], Loss: 1.3788
# Epoch done in  0:01:51.481608
# Epoch  3  started...
# Epoch [3/200], Step [100/396], Loss: 1.1901
# => Loss reduced by:	 0.008939504623413086
#    Saving model state
# Epoch [3/200], Step [200/396], Loss: 1.3007
# Epoch [3/200], Step [300/396], Loss: 1.2669
# Epoch done in  0:01:48.734219
# Epoch  4  started...
# Epoch [4/200], Step [100/396], Loss: 1.3042
# Epoch [4/200], Step [200/396], Loss: 1.5882
# Epoch [4/200], Step [300/396], Loss: 1.0486
# => Loss reduced by:	 0.14150667190551758
#    Saving model state
# Epoch done in  0:01:51.164051
# Epoch  5  started...
# Epoch [5/200], Step [100/396], Loss: 1.1650
# Epoch [5/200], Step [200/396], Loss: 0.9975
# => Loss reduced by:	 0.05108952522277832
#    Saving model state
# Epoch [5/200], Step [300/396], Loss: 1.2296
# Epoch done in  0:01:49.905009
# Epoch  6  started...
# Epoch [6/200], Step [100/396], Loss: 0.9528
# => Loss reduced by:	 0.04466354846954346
#    Saving model state
# Epoch [6/200], Step [200/396], Loss: 0.9484
# => Loss reduced by:	 0.004372835159301758
#    Saving model state
# Epoch [6/200], Step [300/396], Loss: 0.7953
# => Loss reduced by:	 0.15315008163452148
#    Saving model state
# Epoch done in  0:01:48.880910
# Epoch  7  started...
# Epoch [7/200], Step [100/396], Loss: 1.0949
# Epoch [7/200], Step [200/396], Loss: 0.7442
# => Loss reduced by:	 0.051077306270599365
#    Saving model state
# Epoch [7/200], Step [300/396], Loss: 0.5832
# => Loss reduced by:	 0.16100066900253296
#    Saving model state
# Epoch done in  0:01:48.970400
# Epoch  8  started...
# Epoch [8/200], Step [100/396], Loss: 1.0523
# Epoch [8/200], Step [200/396], Loss: 0.4760
# => Loss reduced by:	 0.10715556144714355
#    Saving model state
# Epoch [8/200], Step [300/396], Loss: 0.5447
# Epoch done in  0:01:48.338277
# Epoch  9  started...
# Epoch [9/200], Step [100/396], Loss: 0.9773
# Epoch [9/200], Step [200/396], Loss: 0.5742
# Epoch [9/200], Step [300/396], Loss: 0.7629
# Epoch done in  0:01:48.610859
# Epoch  10  started...
# Epoch [10/200], Step [100/396], Loss: 0.6043
# Epoch [10/200], Step [200/396], Loss: 0.3442
# => Loss reduced by:	 0.1318432092666626
#    Saving model state
# Epoch [10/200], Step [300/396], Loss: 0.5209
# Epoch done in  0:01:48.775827
# Epoch  11  started...
# Epoch [11/200], Step [100/396], Loss: 0.6968
# Epoch [11/200], Step [200/396], Loss: 0.5376
# Epoch [11/200], Step [300/396], Loss: 0.6820
# Epoch done in  0:01:48.658176
# Epoch  12  started...
# Epoch [12/200], Step [100/396], Loss: 0.4981
# Epoch [12/200], Step [200/396], Loss: 0.4221
# Epoch [12/200], Step [300/396], Loss: 0.5721
# Epoch done in  0:01:48.416972
# Epoch  13  started...
# Epoch [13/200], Step [100/396], Loss: 0.5650
# Epoch [13/200], Step [200/396], Loss: 0.5265
# Epoch [13/200], Step [300/396], Loss: 0.5593
# Epoch done in  0:01:48.299373
# Epoch  14  started...
# Epoch [14/200], Step [100/396], Loss: 0.5061
# Epoch [14/200], Step [200/396], Loss: 0.4842
# Epoch [14/200], Step [300/396], Loss: 0.4089
# Epoch done in  0:01:48.732360
# Epoch  15  started...
# Epoch [15/200], Step [100/396], Loss: 0.5809
# Epoch [15/200], Step [200/396], Loss: 0.4696
# Epoch [15/200], Step [300/396], Loss: 0.4202
# Epoch done in  0:01:48.551470
# Epoch  16  started...
# Epoch [16/200], Step [100/396], Loss: 0.4332
# Epoch [16/200], Step [200/396], Loss: 0.3483
# Epoch [16/200], Step [300/396], Loss: 0.3497
# Epoch done in  0:01:49.736584
# Epoch  17  started...
# Epoch [17/200], Step [100/396], Loss: 0.1266
# => Loss reduced by:	 0.21760675311088562
#    Saving model state
# Epoch [17/200], Step [200/396], Loss: 0.2394
# Epoch [17/200], Step [300/396], Loss: 0.2016
# Epoch done in  0:01:48.618246
# Epoch  18  started...
# Epoch [18/200], Step [100/396], Loss: 0.3175
# Epoch [18/200], Step [200/396], Loss: 0.6404
# Epoch [18/200], Step [300/396], Loss: 0.3894
# Epoch done in  0:01:48.333844
# Epoch  19  started...
# Epoch [19/200], Step [100/396], Loss: 0.3495
# Epoch [19/200], Step [200/396], Loss: 0.1470
# Epoch [19/200], Step [300/396], Loss: 0.3654
# Epoch done in  0:01:48.444744
# Epoch  20  started...
# Epoch [20/200], Step [100/396], Loss: 0.3025
# Epoch [20/200], Step [200/396], Loss: 0.1292
# Epoch [20/200], Step [300/396], Loss: 0.1103
# => Loss reduced by:	 0.01631147414445877
#    Saving model state
# Epoch done in  0:01:47.631149
# Epoch  21  started...
# Epoch [21/200], Step [100/396], Loss: 0.2260
# Epoch [21/200], Step [200/396], Loss: 0.3998
# Epoch [21/200], Step [300/396], Loss: 0.3905
# Epoch done in  0:01:48.203426
# Epoch  22  started...
# Epoch [22/200], Step [100/396], Loss: 0.1990
# Epoch [22/200], Step [200/396], Loss: 0.3748
# Epoch [22/200], Step [300/396], Loss: 0.2939
# Epoch done in  0:01:48.025228
# Epoch  23  started...
# Epoch [23/200], Step [100/396], Loss: 0.2438
# Epoch [23/200], Step [200/396], Loss: 0.4736
# Epoch [23/200], Step [300/396], Loss: 0.1038
# => Loss reduced by:	 0.006492309272289276
#    Saving model state
# Epoch done in  0:01:51.877547
# Epoch  24  started...
# Epoch [24/200], Step [100/396], Loss: 0.2424
# Epoch [24/200], Step [200/396], Loss: 0.3270
# Epoch [24/200], Step [300/396], Loss: 0.1689
# Epoch done in  0:01:50.092424
# Epoch  25  started...
# Epoch [25/200], Step [100/396], Loss: 0.1182
# Epoch [25/200], Step [200/396], Loss: 0.1565
# Epoch [25/200], Step [300/396], Loss: 0.4673
# Epoch done in  0:01:51.050519
# Epoch  26  started...
# Epoch [26/200], Step [100/396], Loss: 0.2866
# Epoch [26/200], Step [200/396], Loss: 0.1063
# Epoch [26/200], Step [300/396], Loss: 0.6010
# Epoch done in  0:01:49.682876
# Epoch  27  started...
# Epoch [27/200], Step [100/396], Loss: 0.2999
# Epoch [27/200], Step [200/396], Loss: 0.1628
# Epoch [27/200], Step [300/396], Loss: 0.2370
# Epoch done in  0:01:50.297189
# Epoch  28  started...
# Epoch [28/200], Step [100/396], Loss: 0.4620
# Epoch [28/200], Step [200/396], Loss: 0.0883
# => Loss reduced by:	 0.01549297571182251
#    Saving model state
# Epoch [28/200], Step [300/396], Loss: 0.2908
# Epoch done in  0:01:49.820770
# Epoch  29  started...
# Epoch [29/200], Step [100/396], Loss: 0.1628
# Epoch [29/200], Step [200/396], Loss: 0.2932
# Epoch [29/200], Step [300/396], Loss: 0.3598
# Epoch done in  0:01:49.070544
# Epoch  30  started...
# Epoch [30/200], Step [100/396], Loss: 0.3151
# Epoch [30/200], Step [200/396], Loss: 0.7998
# Epoch [30/200], Step [300/396], Loss: 0.1466
# Epoch done in  0:01:48.591421
# Epoch  31  started...
# Epoch [31/200], Step [100/396], Loss: 0.2969
# Epoch [31/200], Step [200/396], Loss: 0.1609
# Epoch [31/200], Step [300/396], Loss: 0.0983
# Epoch done in  0:01:48.856444
# Epoch  32  started...
# Epoch [32/200], Step [100/396], Loss: 0.0901
# Epoch [32/200], Step [200/396], Loss: 0.3005
# Epoch [32/200], Step [300/396], Loss: 0.2420
# Epoch done in  0:01:48.412146
# Epoch  33  started...
# Epoch [33/200], Step [100/396], Loss: 0.2772
# Epoch [33/200], Step [200/396], Loss: 0.4967
# Epoch [33/200], Step [300/396], Loss: 0.4148
# Epoch done in  0:01:48.706765
# Epoch  34  started...
# Epoch [34/200], Step [100/396], Loss: 0.3777
# Epoch [34/200], Step [200/396], Loss: 0.0559
# => Loss reduced by:	 0.032364532351493835
#    Saving model state
# Epoch [34/200], Step [300/396], Loss: 0.2432
# Epoch done in  0:01:49.479483
# Epoch  35  started...
# Epoch [35/200], Step [100/396], Loss: 0.1760
# Epoch [35/200], Step [200/396], Loss: 0.1535
# Epoch [35/200], Step [300/396], Loss: 0.1590
# Epoch done in  0:01:49.043315
# Epoch  36  started...
# Epoch [36/200], Step [100/396], Loss: 0.2623
# Epoch [36/200], Step [200/396], Loss: 0.1664
# Epoch [36/200], Step [300/396], Loss: 0.1826
# Epoch done in  0:01:49.283680
# Epoch  37  started...
# Epoch [37/200], Step [100/396], Loss: 0.2753
# Epoch [37/200], Step [200/396], Loss: 0.2037
# Epoch [37/200], Step [300/396], Loss: 0.0659
# Epoch done in  0:01:49.976395
# Epoch  38  started...
# Epoch [38/200], Step [100/396], Loss: 0.0269
# => Loss reduced by:	 0.029035180807113647
#    Saving model state
# Epoch [38/200], Step [200/396], Loss: 0.1179
# Epoch [38/200], Step [300/396], Loss: 0.3487
# Epoch done in  0:01:49.250064
# Epoch  39  started...
# Epoch [39/200], Step [100/396], Loss: 0.0372
# Epoch [39/200], Step [200/396], Loss: 0.1178
# Epoch [39/200], Step [300/396], Loss: 0.3353
# Epoch done in  0:01:48.521934
# Epoch  40  started...
# Epoch [40/200], Step [100/396], Loss: 0.1107
# Epoch [40/200], Step [200/396], Loss: 0.0353
# Epoch [40/200], Step [300/396], Loss: 0.1233
# Epoch done in  0:01:47.567067
# Epoch  41  started...
# Epoch [41/200], Step [100/396], Loss: 0.0998
# Epoch [41/200], Step [200/396], Loss: 0.0339
# Epoch [41/200], Step [300/396], Loss: 0.3965
# Epoch done in  0:01:48.139297
# Epoch  42  started...
# Epoch [42/200], Step [100/396], Loss: 0.1063
# Epoch [42/200], Step [200/396], Loss: 0.6506
# Epoch [42/200], Step [300/396], Loss: 0.0598
# Epoch done in  0:01:48.770445
# Epoch  43  started...
# Epoch [43/200], Step [100/396], Loss: 0.0928
# Epoch [43/200], Step [200/396], Loss: 0.1602
# Epoch [43/200], Step [300/396], Loss: 0.2337
# Epoch done in  0:01:48.180332
# Epoch  44  started...
# Epoch [44/200], Step [100/396], Loss: 0.0654
# Epoch [44/200], Step [200/396], Loss: 0.1537
# Epoch [44/200], Step [300/396], Loss: 0.0598
# Epoch done in  0:01:48.029001
# Epoch  45  started...
# Epoch [45/200], Step [100/396], Loss: 0.1465
# Epoch [45/200], Step [200/396], Loss: 0.1687
# Epoch [45/200], Step [300/396], Loss: 0.0973
# Epoch done in  0:01:47.708137
# Epoch  46  started...
# Epoch [46/200], Step [100/396], Loss: 0.1793
# Epoch [46/200], Step [200/396], Loss: 0.0443
# Epoch [46/200], Step [300/396], Loss: 0.4213
# Epoch done in  0:01:46.359868
# Epoch  47  started...
# Epoch [47/200], Step [100/396], Loss: 0.1321
# Epoch [47/200], Step [200/396], Loss: 0.2425
# Epoch [47/200], Step [300/396], Loss: 0.3015
# Epoch done in  0:01:47.119174
# Epoch  48  started...
# Epoch [48/200], Step [100/396], Loss: 0.3216
# Epoch [48/200], Step [200/396], Loss: 0.1268
# Epoch [48/200], Step [300/396], Loss: 0.3673
# Epoch done in  0:01:46.727661
# Epoch  49  started...
# Epoch [49/200], Step [100/396], Loss: 0.0913
# Epoch [49/200], Step [200/396], Loss: 0.3637
# Epoch [49/200], Step [300/396], Loss: 0.2847
# Epoch done in  0:01:46.368963
# Epoch  50  started...
# Epoch [50/200], Step [100/396], Loss: 0.7045
# Epoch [50/200], Step [200/396], Loss: 0.1382
# Epoch [50/200], Step [300/396], Loss: 0.0708
# Epoch done in  0:01:45.499197
# Epoch  51  started...
# Epoch [51/200], Step [100/396], Loss: 0.1260
# Epoch [51/200], Step [200/396], Loss: 0.2149
# Epoch [51/200], Step [300/396], Loss: 0.1208
# Epoch done in  0:01:46.112126
# Epoch  52  started...
# Epoch [52/200], Step [100/396], Loss: 0.0081
# => Loss reduced by:	 0.018782347440719604
#    Saving model state
# Epoch [52/200], Step [200/396], Loss: 0.0321
# Epoch [52/200], Step [300/396], Loss: 0.1830
# Epoch done in  0:01:45.731276
# Epoch  53  started...
# Epoch [53/200], Step [100/396], Loss: 0.0867
# Epoch [53/200], Step [200/396], Loss: 0.1487
# Epoch [53/200], Step [300/396], Loss: 0.0742
# Epoch done in  0:01:45.490775
# Epoch  54  started...
# Epoch [54/200], Step [100/396], Loss: 0.1284
# Epoch [54/200], Step [200/396], Loss: 0.0816
# Epoch [54/200], Step [300/396], Loss: 0.2656
# Epoch done in  0:01:45.374027
# Epoch  55  started...
# Epoch [55/200], Step [100/396], Loss: 0.0568
# Epoch [55/200], Step [200/396], Loss: 0.2932
# Epoch [55/200], Step [300/396], Loss: 0.0795
# Epoch done in  0:01:45.703010
# Epoch  56  started...
# Epoch [56/200], Step [100/396], Loss: 0.2778
# Epoch [56/200], Step [200/396], Loss: 0.2308
# Epoch [56/200], Step [300/396], Loss: 0.0334
# Epoch done in  0:01:45.801643
# Epoch  57  started...
# Epoch [57/200], Step [100/396], Loss: 0.1373
# Epoch [57/200], Step [200/396], Loss: 0.0542
# Epoch [57/200], Step [300/396], Loss: 0.1562
# Epoch done in  0:01:46.854360
# Epoch  58  started...
# Epoch [58/200], Step [100/396], Loss: 0.1163
# Epoch [58/200], Step [200/396], Loss: 0.2167
# Epoch [58/200], Step [300/396], Loss: 0.0369
# Epoch done in  0:01:46.198532
# Epoch  59  started...
# Epoch [59/200], Step [100/396], Loss: 0.3463
# Epoch [59/200], Step [200/396], Loss: 0.0294
# Epoch [59/200], Step [300/396], Loss: 0.0297
# Epoch done in  0:01:45.790630
# Epoch  60  started...
# Epoch [60/200], Step [100/396], Loss: 0.0317
# Epoch [60/200], Step [200/396], Loss: 0.0979
# Epoch [60/200], Step [300/396], Loss: 0.1143
# Epoch done in  0:01:46.640144
# Epoch  61  started...
# Epoch [61/200], Step [100/396], Loss: 0.2221
# Epoch [61/200], Step [200/396], Loss: 0.1589
# Epoch [61/200], Step [300/396], Loss: 0.1355
# Epoch done in  0:01:45.990057
# Epoch  62  started...
# Epoch [62/200], Step [100/396], Loss: 0.2730
# Epoch [62/200], Step [200/396], Loss: 0.0866
# Epoch [62/200], Step [300/396], Loss: 0.0552
# Epoch done in  0:01:46.281213
# Epoch  63  started...
# Epoch [63/200], Step [100/396], Loss: 0.2269
# Epoch [63/200], Step [200/396], Loss: 0.0771
# Epoch [63/200], Step [300/396], Loss: 0.1035
# Epoch done in  0:01:45.375307
# Epoch  64  started...
# Epoch [64/200], Step [100/396], Loss: 0.0169
# Epoch [64/200], Step [200/396], Loss: 0.0472
# Epoch [64/200], Step [300/396], Loss: 0.0361
# Epoch done in  0:01:45.770102
# Epoch  65  started...
# Epoch [65/200], Step [100/396], Loss: 0.0464
# Epoch [65/200], Step [200/396], Loss: 0.4691
# Epoch [65/200], Step [300/396], Loss: 0.1730
# Epoch done in  0:01:45.413948
# Epoch  66  started...
# Epoch [66/200], Step [100/396], Loss: 0.0449
# Epoch [66/200], Step [200/396], Loss: 0.1239
# Epoch [66/200], Step [300/396], Loss: 0.0193
# Epoch done in  0:01:45.670819
# Epoch  67  started...
# Epoch [67/200], Step [100/396], Loss: 0.0663
# Epoch [67/200], Step [200/396], Loss: 0.0859
# Epoch [67/200], Step [300/396], Loss: 0.0276
# Epoch done in  0:01:45.021385
# Epoch  68  started...
# Epoch [68/200], Step [100/396], Loss: 0.1875
# Epoch [68/200], Step [200/396], Loss: 0.0905
# Epoch [68/200], Step [300/396], Loss: 0.1146
# Epoch done in  0:01:45.683515
# Epoch  69  started...
# Epoch [69/200], Step [100/396], Loss: 0.3404
# Epoch [69/200], Step [200/396], Loss: 0.0246
# Epoch [69/200], Step [300/396], Loss: 0.0188
# Epoch done in  0:01:46.082486
# Epoch  70  started...
# Epoch [70/200], Step [100/396], Loss: 0.0621
# Epoch [70/200], Step [200/396], Loss: 0.0089
# Epoch [70/200], Step [300/396], Loss: 0.0300
# Epoch done in  0:01:46.165184
# Epoch  71  started...
# Epoch [71/200], Step [100/396], Loss: 0.1403
# Epoch [71/200], Step [200/396], Loss: 0.0424
# Epoch [71/200], Step [300/396], Loss: 0.0379
# Epoch done in  0:01:45.740111
# Epoch  72  started...
# Epoch [72/200], Step [100/396], Loss: 0.1114
# Epoch [72/200], Step [200/396], Loss: 0.0849
# Epoch [72/200], Step [300/396], Loss: 0.0636
# Epoch done in  0:01:46.135986
# Epoch  73  started...
# Epoch [73/200], Step [100/396], Loss: 0.0229
# Epoch [73/200], Step [200/396], Loss: 0.2478
# Epoch [73/200], Step [300/396], Loss: 0.0387
# Epoch done in  0:01:46.625260
# Epoch  74  started...
# Epoch [74/200], Step [100/396], Loss: 0.4034
# Epoch [74/200], Step [200/396], Loss: 0.0150
# Epoch [74/200], Step [300/396], Loss: 0.1758
# Epoch done in  0:01:46.904296
# Epoch  75  started...
# Epoch [75/200], Step [100/396], Loss: 0.0478
# Epoch [75/200], Step [200/396], Loss: 0.0355
# Epoch [75/200], Step [300/396], Loss: 0.4408
# Epoch done in  0:01:46.282551
# Epoch  76  started...
# Epoch [76/200], Step [100/396], Loss: 0.0290
# Epoch [76/200], Step [200/396], Loss: 0.0567
# Epoch [76/200], Step [300/396], Loss: 0.0431
# Epoch done in  0:01:47.213677
# Epoch  77  started...
# Epoch [77/200], Step [100/396], Loss: 0.0481
# Epoch [77/200], Step [200/396], Loss: 0.1331
# Epoch [77/200], Step [300/396], Loss: 0.0706
# Epoch done in  0:01:49.507025
# Epoch  78  started...
# Epoch [78/200], Step [100/396], Loss: 0.1273
# Epoch [78/200], Step [200/396], Loss: 0.0054
# => Loss reduced by:	 0.002677604556083679
#    Saving model state
# Epoch [78/200], Step [300/396], Loss: 0.1134
# Epoch done in  0:01:47.843154
# Epoch  79  started...
# Epoch [79/200], Step [100/396], Loss: 0.0183
# Epoch [79/200], Step [200/396], Loss: 0.0910
# Epoch [79/200], Step [300/396], Loss: 0.0226
# Epoch done in  0:01:47.902270
# Epoch  80  started...
# Epoch [80/200], Step [100/396], Loss: 0.0782
# Epoch [80/200], Step [200/396], Loss: 0.0904
# Epoch [80/200], Step [300/396], Loss: 0.1425
# Epoch done in  0:01:47.950420
# Epoch  81  started...
# Epoch [81/200], Step [100/396], Loss: 0.1002
# Epoch [81/200], Step [200/396], Loss: 0.1119
# Epoch [81/200], Step [300/396], Loss: 0.1463
# Epoch done in  0:01:47.801802
# Epoch  82  started...
# Epoch [82/200], Step [100/396], Loss: 0.1295
# Epoch [82/200], Step [200/396], Loss: 0.0431
# Epoch [82/200], Step [300/396], Loss: 0.0461
# Epoch done in  0:01:50.706631
# Epoch  83  started...
# Epoch [83/200], Step [100/396], Loss: 0.1517
# Epoch [83/200], Step [200/396], Loss: 0.1082
# Epoch [83/200], Step [300/396], Loss: 0.0197
# Epoch done in  0:01:48.731181
# Epoch  84  started...
# Epoch [84/200], Step [100/396], Loss: 0.0229
# Epoch [84/200], Step [200/396], Loss: 0.0400
# Epoch [84/200], Step [300/396], Loss: 0.0654
# Epoch done in  0:01:46.291927
# Epoch  85  started...
# Epoch [85/200], Step [100/396], Loss: 0.0466
# Epoch [85/200], Step [200/396], Loss: 0.0311
# Epoch [85/200], Step [300/396], Loss: 0.0865
# Epoch done in  0:01:45.910577
# Epoch  86  started...
# Epoch [86/200], Step [100/396], Loss: 0.0361
# Epoch [86/200], Step [200/396], Loss: 0.0317
# Epoch [86/200], Step [300/396], Loss: 0.0628
# Epoch done in  0:01:45.750771
# Epoch  87  started...
# Epoch [87/200], Step [100/396], Loss: 0.0741
# Epoch [87/200], Step [200/396], Loss: 0.0264
# Epoch [87/200], Step [300/396], Loss: 0.0514
# Epoch done in  0:01:47.476869
# Epoch  88  started...
# Epoch [88/200], Step [100/396], Loss: 0.0402
# Epoch [88/200], Step [200/396], Loss: 0.0343
# Epoch [88/200], Step [300/396], Loss: 0.0633
# Epoch done in  0:01:48.158028
# Epoch  89  started...
# Epoch [89/200], Step [100/396], Loss: 0.0581
# Epoch [89/200], Step [200/396], Loss: 0.0136
# Epoch [89/200], Step [300/396], Loss: 0.1131
# Epoch done in  0:01:50.696223
# Epoch  90  started...
# Epoch [90/200], Step [100/396], Loss: 0.0546
# Epoch [90/200], Step [200/396], Loss: 0.0364
# Epoch [90/200], Step [300/396], Loss: 0.1738
# Epoch done in  0:01:50.500591
# Epoch  91  started...
# Epoch [91/200], Step [100/396], Loss: 0.0074
# Epoch [91/200], Step [200/396], Loss: 0.1235
# Epoch [91/200], Step [300/396], Loss: 0.0931
# Epoch done in  0:01:53.287882
# Epoch  92  started...
# Epoch [92/200], Step [100/396], Loss: 0.0527
# Epoch [92/200], Step [200/396], Loss: 0.1321
# Epoch [92/200], Step [300/396], Loss: 0.0214
# Epoch done in  0:01:55.258729
# Epoch  93  started...
# Epoch [93/200], Step [100/396], Loss: 0.0331
# Epoch [93/200], Step [200/396], Loss: 0.0145
# Epoch [93/200], Step [300/396], Loss: 0.4734
# Epoch done in  0:01:56.276744
# Epoch  94  started...
# Epoch [94/200], Step [100/396], Loss: 0.0097
# Epoch [94/200], Step [200/396], Loss: 0.1753
# Epoch [94/200], Step [300/396], Loss: 0.1383
# Epoch done in  0:01:56.074661
# Epoch  95  started...
# Epoch [95/200], Step [100/396], Loss: 0.0326
# Epoch [95/200], Step [200/396], Loss: 0.0549
# Epoch [95/200], Step [300/396], Loss: 0.0052
# => Loss reduced by:	 0.0002505183219909668
#    Saving model state
# Epoch done in  0:01:58.028706
# Epoch  96  started...
# Epoch [96/200], Step [100/396], Loss: 0.0758
# Epoch [96/200], Step [200/396], Loss: 0.0141
# Epoch [96/200], Step [300/396], Loss: 0.1385
# Epoch done in  0:01:56.668068
# Epoch  97  started...
# Epoch [97/200], Step [100/396], Loss: 0.0054
# Epoch [97/200], Step [200/396], Loss: 0.0724
# Epoch [97/200], Step [300/396], Loss: 0.0155
# Epoch done in  0:01:56.294119
# Epoch  98  started...
# Epoch [98/200], Step [100/396], Loss: 0.0077
# Epoch [98/200], Step [200/396], Loss: 0.0354
# Epoch [98/200], Step [300/396], Loss: 0.1692
# Epoch done in  0:01:56.222609
# Epoch  99  started...
# Epoch [99/200], Step [100/396], Loss: 0.0889
# Epoch [99/200], Step [200/396], Loss: 0.0371
# Epoch [99/200], Step [300/396], Loss: 0.0100
# Epoch done in  0:01:56.506247
# Epoch  100  started...
# Epoch [100/200], Step [100/396], Loss: 0.1726
# Epoch [100/200], Step [200/396], Loss: 0.0734
# Epoch [100/200], Step [300/396], Loss: 0.0384
# Epoch done in  0:01:57.741457
# Epoch  101  started...
# Epoch [101/200], Step [100/396], Loss: 0.6351
# Epoch [101/200], Step [200/396], Loss: 0.1203
# Epoch [101/200], Step [300/396], Loss: 0.0048
# => Loss reduced by:	 0.0003479421138763428
#    Saving model state
# Epoch done in  0:01:57.977679
# Epoch  102  started...
# Epoch [102/200], Step [100/396], Loss: 0.1677
# Epoch [102/200], Step [200/396], Loss: 0.0371
# Epoch [102/200], Step [300/396], Loss: 0.0277
# Epoch done in  0:01:57.527136
# Epoch  103  started...
# Epoch [103/200], Step [100/396], Loss: 0.0093
# Epoch [103/200], Step [200/396], Loss: 0.0869
# Epoch [103/200], Step [300/396], Loss: 0.2151
# Epoch done in  0:01:57.814758
# Epoch  104  started...
# Epoch [104/200], Step [100/396], Loss: 0.0195
# Epoch [104/200], Step [200/396], Loss: 0.0080
# Epoch [104/200], Step [300/396], Loss: 0.0154
# Epoch done in  0:01:56.469534
# Epoch  105  started...
# Epoch [105/200], Step [100/396], Loss: 0.0229
# Epoch [105/200], Step [200/396], Loss: 0.0648
# Epoch [105/200], Step [300/396], Loss: 0.0383
# Epoch done in  0:01:56.482697
# Epoch  106  started...
# Epoch [106/200], Step [100/396], Loss: 0.0356
# Epoch [106/200], Step [200/396], Loss: 0.0065
# Epoch [106/200], Step [300/396], Loss: 0.0554
# Epoch done in  0:01:56.532427
# Epoch  107  started...
# Epoch [107/200], Step [100/396], Loss: 0.1113
# Epoch [107/200], Step [200/396], Loss: 0.0837
# Epoch [107/200], Step [300/396], Loss: 0.0899
# Epoch done in  0:01:55.822993
# Epoch  108  started...
# Epoch [108/200], Step [100/396], Loss: 0.0624
# Epoch [108/200], Step [200/396], Loss: 0.0938
# Epoch [108/200], Step [300/396], Loss: 0.0640
# Epoch done in  0:01:56.520861
# Epoch  109  started...
# Epoch [109/200], Step [100/396], Loss: 0.0086
# Epoch [109/200], Step [200/396], Loss: 0.0633
# Epoch [109/200], Step [300/396], Loss: 0.0275
# Epoch done in  0:01:56.428341
# Epoch  110  started...
# Epoch [110/200], Step [100/396], Loss: 0.0328
# Epoch [110/200], Step [200/396], Loss: 0.0704
# Epoch [110/200], Step [300/396], Loss: 0.0303
# Epoch done in  0:01:56.702201
# Epoch  111  started...
# Epoch [111/200], Step [100/396], Loss: 0.0035
# => Loss reduced by:	 0.0013572275638580322
#    Saving model state
# Epoch [111/200], Step [200/396], Loss: 0.0130
# Epoch [111/200], Step [300/396], Loss: 0.0731
# Epoch done in  0:01:56.093467
# Epoch  112  started...
# Epoch [112/200], Step [100/396], Loss: 0.0156
# Epoch [112/200], Step [200/396], Loss: 0.0061
# Epoch [112/200], Step [300/396], Loss: 0.0612
# Epoch done in  0:01:56.441746
# Epoch  113  started...
# Epoch [113/200], Step [100/396], Loss: 0.1533
# Epoch [113/200], Step [200/396], Loss: 0.0709
# Epoch [113/200], Step [300/396], Loss: 0.0443
# Epoch done in  0:01:56.825200
# Epoch  114  started...
# Epoch [114/200], Step [100/396], Loss: 0.0771
# Epoch [114/200], Step [200/396], Loss: 0.1285
# Epoch [114/200], Step [300/396], Loss: 0.0105
# Epoch done in  0:01:56.693357
# Epoch  115  started...
# Epoch [115/200], Step [100/396], Loss: 0.1087
# Epoch [115/200], Step [200/396], Loss: 0.0039
# Epoch [115/200], Step [300/396], Loss: 0.0063
# Epoch done in  0:01:57.186502
# Epoch  116  started...
# Epoch [116/200], Step [100/396], Loss: 0.0556
# Epoch [116/200], Step [200/396], Loss: 0.0400
# Epoch [116/200], Step [300/396], Loss: 0.0109
# Epoch done in  0:01:56.605011
# Epoch  117  started...
# Epoch [117/200], Step [100/396], Loss: 0.0050
# Epoch [117/200], Step [200/396], Loss: 0.4019
# Epoch [117/200], Step [300/396], Loss: 0.0027
# => Loss reduced by:	 0.0008253008127212524
#    Saving model state
# Epoch done in  0:01:56.592743
# Epoch  118  started...
# Epoch [118/200], Step [100/396], Loss: 0.1399
# Epoch [118/200], Step [200/396], Loss: 0.0390
# Epoch [118/200], Step [300/396], Loss: 0.0095
# Epoch done in  0:01:57.180020
# Epoch  119  started...
# Epoch [119/200], Step [100/396], Loss: 0.0289
# Epoch [119/200], Step [200/396], Loss: 0.0129
# Epoch [119/200], Step [300/396], Loss: 0.0240
# Epoch done in  0:01:55.963381
# Epoch  120  started...
# Epoch [120/200], Step [100/396], Loss: 0.0179
# Epoch [120/200], Step [200/396], Loss: 0.0541
# Epoch [120/200], Step [300/396], Loss: 0.0022
# => Loss reduced by:	 0.0004474520683288574
#    Saving model state
# Epoch done in  0:01:56.186095
# Epoch  121  started...
# Epoch [121/200], Step [100/396], Loss: 0.0372
# Epoch [121/200], Step [200/396], Loss: 0.7688
# Epoch [121/200], Step [300/396], Loss: 0.0232
# Epoch done in  0:01:57.406721
# Epoch  122  started...
# Epoch [122/200], Step [100/396], Loss: 0.1688
# Epoch [122/200], Step [200/396], Loss: 0.0099
# Epoch [122/200], Step [300/396], Loss: 0.0253
# Epoch done in  0:01:57.695418
# Epoch  123  started...
# Epoch [123/200], Step [100/396], Loss: 0.0170
# Epoch [123/200], Step [200/396], Loss: 0.0211
# Epoch [123/200], Step [300/396], Loss: 0.0932
# Epoch done in  0:01:58.271310
# Epoch  124  started...
# Epoch [124/200], Step [100/396], Loss: 0.0094
# Epoch [124/200], Step [200/396], Loss: 0.0534
# Epoch [124/200], Step [300/396], Loss: 0.0176
# Epoch done in  0:01:58.660623
# Epoch  125  started...
# Epoch [125/200], Step [100/396], Loss: 0.1573
# Epoch [125/200], Step [200/396], Loss: 0.0654
# Epoch [125/200], Step [300/396], Loss: 0.0441
# Epoch done in  0:01:58.385896
# Epoch  126  started...
# Epoch [126/200], Step [100/396], Loss: 0.0023
# Epoch [126/200], Step [200/396], Loss: 0.0402
# Epoch [126/200], Step [300/396], Loss: 0.0370
# Epoch done in  0:01:57.728073
# Epoch  127  started...
# Epoch [127/200], Step [100/396], Loss: 0.0026
# Epoch [127/200], Step [200/396], Loss: 0.0275
# Epoch [127/200], Step [300/396], Loss: 0.0657
# Epoch done in  0:01:56.675780
# Epoch  128  started...
# Epoch [128/200], Step [100/396], Loss: 0.0607
# Epoch [128/200], Step [200/396], Loss: 0.0931
# Epoch [128/200], Step [300/396], Loss: 0.0726
# Epoch done in  0:01:56.348315
# Epoch  129  started...
# Epoch [129/200], Step [100/396], Loss: 0.1184
# Epoch [129/200], Step [200/396], Loss: 0.1260
# Epoch [129/200], Step [300/396], Loss: 0.0292
# Epoch done in  0:01:55.461601
# Epoch  130  started...
# Epoch [130/200], Step [100/396], Loss: 0.0019
# => Loss reduced by:	 0.0003108382225036621
#    Saving model state
# Epoch [130/200], Step [200/396], Loss: 0.0150
# Epoch [130/200], Step [300/396], Loss: 0.0022
# Epoch done in  0:02:10.789782
# Epoch  131  started...
# Epoch [131/200], Step [100/396], Loss: 0.2726
# Epoch [131/200], Step [200/396], Loss: 0.0380
# Epoch [131/200], Step [300/396], Loss: 0.0120
# Epoch done in  0:01:56.909072
# Epoch  132  started...
# Epoch [132/200], Step [100/396], Loss: 0.2639
# Epoch [132/200], Step [200/396], Loss: 0.0025
# Epoch [132/200], Step [300/396], Loss: 0.0069
# Epoch done in  0:01:56.404395
# Epoch  133  started...
# Epoch [133/200], Step [100/396], Loss: 0.0764
# Epoch [133/200], Step [200/396], Loss: 0.0369
# Epoch [133/200], Step [300/396], Loss: 0.0109
# Epoch done in  0:01:59.206184
# Epoch  134  started...
# Epoch [134/200], Step [100/396], Loss: 0.0578
# Epoch [134/200], Step [200/396], Loss: 0.0569
# Epoch [134/200], Step [300/396], Loss: 0.0701
# Epoch done in  0:01:57.273976
# Epoch  135  started...
# Epoch [135/200], Step [100/396], Loss: 0.0683
# Epoch [135/200], Step [200/396], Loss: 0.0829
# Epoch [135/200], Step [300/396], Loss: 0.1373
# Epoch done in  0:01:56.021441
# Epoch  136  started...
# Epoch [136/200], Step [100/396], Loss: 0.0178
# Epoch [136/200], Step [200/396], Loss: 0.0127
# Epoch [136/200], Step [300/396], Loss: 0.0029
# Epoch done in  0:01:56.569847
# Epoch  137  started...
# Epoch [137/200], Step [100/396], Loss: 0.0266
# Epoch [137/200], Step [200/396], Loss: 0.0603
# Epoch [137/200], Step [300/396], Loss: 0.0029
# Epoch done in  0:01:56.628955
# Epoch  138  started...
# Epoch [138/200], Step [100/396], Loss: 0.0396
# Epoch [138/200], Step [200/396], Loss: 0.0020
# Epoch [138/200], Step [300/396], Loss: 0.2259
# Epoch done in  0:01:56.391290
# Epoch  139  started...
# Epoch [139/200], Step [100/396], Loss: 0.0098
# Epoch [139/200], Step [200/396], Loss: 0.0124
# Epoch [139/200], Step [300/396], Loss: 0.1013
# Epoch done in  0:01:57.055378
# Epoch  140  started...
# Epoch [140/200], Step [100/396], Loss: 0.0576
# Epoch [140/200], Step [200/396], Loss: 0.0239
# Epoch [140/200], Step [300/396], Loss: 0.0549
# Epoch done in  0:01:57.148702
# Epoch  141  started...
# Epoch [141/200], Step [100/396], Loss: 0.1010
# Epoch [141/200], Step [200/396], Loss: 0.1978
# Epoch [141/200], Step [300/396], Loss: 0.0011
# => Loss reduced by:	 0.00077800452709198
#    Saving model state
# Epoch done in  0:01:57.336456
# Epoch  142  started...
# Epoch [142/200], Step [100/396], Loss: 0.0538
# Epoch [142/200], Step [200/396], Loss: 0.0763
# Epoch [142/200], Step [300/396], Loss: 0.0589
# Epoch done in  0:01:57.196568
# Epoch  143  started...
# Epoch [143/200], Step [100/396], Loss: 0.0366
# Epoch [143/200], Step [200/396], Loss: 0.0068
# Epoch [143/200], Step [300/396], Loss: 0.0031
# Epoch done in  0:01:56.745468
# Epoch  144  started...
# Epoch [144/200], Step [100/396], Loss: 0.0933
# Epoch [144/200], Step [200/396], Loss: 0.0213
# Epoch [144/200], Step [300/396], Loss: 0.0004
# => Loss reduced by:	 0.0007425397634506226
#    Saving model state
# Epoch done in  0:01:57.390166
# Epoch  145  started...
# Epoch [145/200], Step [100/396], Loss: 0.0133
# Epoch [145/200], Step [200/396], Loss: 0.0033
# Epoch [145/200], Step [300/396], Loss: 0.0048
# Epoch done in  0:01:56.686507
# Epoch  146  started...
# Epoch [146/200], Step [100/396], Loss: 0.0404
# Epoch [146/200], Step [200/396], Loss: 0.2438
# Epoch [146/200], Step [300/396], Loss: 0.0723
# Epoch done in  0:01:56.479207
# Epoch  147  started...
# Epoch [147/200], Step [100/396], Loss: 0.0053
# Epoch [147/200], Step [200/396], Loss: 0.0111
# Epoch [147/200], Step [300/396], Loss: 0.0492
# Epoch done in  0:01:56.608630
# Epoch  148  started...
# Epoch [148/200], Step [100/396], Loss: 0.0022
# Epoch [148/200], Step [200/396], Loss: 0.0700
# Epoch [148/200], Step [300/396], Loss: 0.0151
# Epoch done in  0:01:56.460539
# Epoch  149  started...
# Epoch [149/200], Step [100/396], Loss: 0.0733
# Epoch [149/200], Step [200/396], Loss: 0.0070
# Epoch [149/200], Step [300/396], Loss: 0.0027
# Epoch done in  0:01:56.818837
# Epoch  150  started...
# Epoch [150/200], Step [100/396], Loss: 0.1398
# Epoch [150/200], Step [200/396], Loss: 0.0541
# Epoch [150/200], Step [300/396], Loss: 0.0708
# Epoch done in  0:01:56.997695
# Epoch  151  started...
# Epoch [151/200], Step [100/396], Loss: 0.0039
# Epoch [151/200], Step [200/396], Loss: 0.0132
# Epoch [151/200], Step [300/396], Loss: 0.1621
# Epoch done in  0:01:54.290188
# Epoch  152  started...
# Epoch [152/200], Step [100/396], Loss: 0.1134
# Epoch [152/200], Step [200/396], Loss: 0.0034
# Epoch [152/200], Step [300/396], Loss: 0.0426
# Epoch done in  0:01:52.380896
# Epoch  153  started...
# Epoch [153/200], Step [100/396], Loss: 0.0506
# Epoch [153/200], Step [200/396], Loss: 0.0073
# Epoch [153/200], Step [300/396], Loss: 0.0057
# Epoch done in  0:04:31.060481
# Epoch  154  started...
# Epoch [154/200], Step [100/396], Loss: 0.0752
# Epoch [154/200], Step [200/396], Loss: 0.0254
# Epoch [154/200], Step [300/396], Loss: 0.0057
# Epoch done in  0:01:49.438011
# Epoch  155  started...
# Epoch [155/200], Step [100/396], Loss: 0.1102
# Epoch [155/200], Step [200/396], Loss: 0.1160
# Epoch [155/200], Step [300/396], Loss: 0.0119
# Epoch done in  0:01:47.086986
# Epoch  156  started...
# Epoch [156/200], Step [100/396], Loss: 0.0482
# Epoch [156/200], Step [200/396], Loss: 0.0534
# Epoch [156/200], Step [300/396], Loss: 0.0058
# Epoch done in  0:01:46.635636
# Epoch  157  started...
# Epoch [157/200], Step [100/396], Loss: 0.1860
# Epoch [157/200], Step [200/396], Loss: 0.0129
# Epoch [157/200], Step [300/396], Loss: 0.0074
# Epoch done in  0:01:46.660009
# Epoch  158  started...
# Epoch [158/200], Step [100/396], Loss: 0.0862
# Epoch [158/200], Step [200/396], Loss: 0.0752
# Epoch [158/200], Step [300/396], Loss: 0.0038
# Epoch done in  0:01:46.014553
# Epoch  159  started...
# Epoch [159/200], Step [100/396], Loss: 0.0091
# Epoch [159/200], Step [200/396], Loss: 0.0068
# Epoch [159/200], Step [300/396], Loss: 0.0209
# Epoch done in  0:01:50.240053
# Epoch  160  started...
# Epoch [160/200], Step [100/396], Loss: 0.0985
# Epoch [160/200], Step [200/396], Loss: 0.0293
# Epoch [160/200], Step [300/396], Loss: 0.0551
# Epoch done in  0:01:48.849774
# Epoch  161  started...
# Epoch [161/200], Step [100/396], Loss: 0.0071
# Epoch [161/200], Step [200/396], Loss: 0.0062
# Epoch [161/200], Step [300/396], Loss: 0.0056
# Epoch done in  0:01:52.860802
# Epoch  162  started...
# Epoch [162/200], Step [100/396], Loss: 0.0057
# Epoch [162/200], Step [200/396], Loss: 0.1207
# Epoch [162/200], Step [300/396], Loss: 0.0037
# Epoch done in  0:01:53.930988
# Epoch  163  started...
# Epoch [163/200], Step [100/396], Loss: 0.0051
# Epoch [163/200], Step [200/396], Loss: 0.1123
# Epoch [163/200], Step [300/396], Loss: 0.1199
# Epoch done in  0:02:06.340445
# Epoch  164  started...
# Epoch [164/200], Step [100/396], Loss: 0.0972
# Epoch [164/200], Step [200/396], Loss: 0.0023
# Epoch [164/200], Step [300/396], Loss: 0.0365
# Epoch done in  0:01:53.142471
# Epoch  165  started...
# Epoch [165/200], Step [100/396], Loss: 0.0701
# Epoch [165/200], Step [200/396], Loss: 0.0479
# Epoch [165/200], Step [300/396], Loss: 0.0520
# Epoch done in  0:01:54.743637
# Epoch  166  started...
# Epoch [166/200], Step [100/396], Loss: 0.0078
# Epoch [166/200], Step [200/396], Loss: 0.0698
# Epoch [166/200], Step [300/396], Loss: 0.0496
# Epoch done in  0:01:53.415792
# Epoch  167  started...
# Epoch [167/200], Step [100/396], Loss: 0.0017
# Epoch [167/200], Step [200/396], Loss: 0.0020
# Epoch [167/200], Step [300/396], Loss: 0.0222
# Epoch done in  0:01:52.392488
# Epoch  168  started...
# Epoch [168/200], Step [100/396], Loss: 0.0041
# Epoch [168/200], Step [200/396], Loss: 0.0502
# Epoch [168/200], Step [300/396], Loss: 0.0052
# Epoch done in  0:01:52.664675
# Epoch  169  started...
# Epoch [169/200], Step [100/396], Loss: 0.0815
# Epoch [169/200], Step [200/396], Loss: 0.0169
# Epoch [169/200], Step [300/396], Loss: 0.0146
# Epoch done in  0:01:53.966657
# Epoch  170  started...
# Epoch [170/200], Step [100/396], Loss: 0.0407
# Epoch [170/200], Step [200/396], Loss: 0.0032
# Epoch [170/200], Step [300/396], Loss: 0.0568
# Epoch done in  0:01:55.126198
# Epoch  171  started...
# Epoch [171/200], Step [100/396], Loss: 0.0249
# Epoch [171/200], Step [200/396], Loss: 0.0840
# Epoch [171/200], Step [300/396], Loss: 0.0066
# Epoch done in  0:01:50.831491
# Epoch  172  started...
# Epoch [172/200], Step [100/396], Loss: 0.1331
# Epoch [172/200], Step [200/396], Loss: 0.0516
# Epoch [172/200], Step [300/396], Loss: 0.0045
# Epoch done in  0:01:48.285157
# Epoch  173  started...
# Epoch [173/200], Step [100/396], Loss: 0.0077
# Epoch [173/200], Step [200/396], Loss: 0.0178
# Epoch [173/200], Step [300/396], Loss: 0.0653
# Epoch done in  0:01:49.332268
# Epoch  174  started...
# Epoch [174/200], Step [100/396], Loss: 0.0289
# Epoch [174/200], Step [200/396], Loss: 0.0659
# Epoch [174/200], Step [300/396], Loss: 0.0730
# Epoch done in  0:01:47.781841
# Epoch  175  started...
# Epoch [175/200], Step [100/396], Loss: 0.1099
# Epoch [175/200], Step [200/396], Loss: 0.0205
# Epoch [175/200], Step [300/396], Loss: 0.0811
# Epoch done in  0:01:46.876638
# Epoch  176  started...
# Epoch [176/200], Step [100/396], Loss: 0.0366
# Epoch [176/200], Step [200/396], Loss: 0.0047
# Epoch [176/200], Step [300/396], Loss: 0.0083
# Epoch done in  0:01:47.417981
# Epoch  177  started...
# Epoch [177/200], Step [100/396], Loss: 0.0077
# Epoch [177/200], Step [200/396], Loss: 0.0189
# Epoch [177/200], Step [300/396], Loss: 0.0099
# Epoch done in  0:01:46.684295
# Epoch  178  started...
# Epoch [178/200], Step [100/396], Loss: 0.0621
# Epoch [178/200], Step [200/396], Loss: 0.0380
# Epoch [178/200], Step [300/396], Loss: 0.0057
# Epoch done in  0:01:46.310833
# Epoch  179  started...
# Epoch [179/200], Step [100/396], Loss: 0.4482
# Epoch [179/200], Step [200/396], Loss: 0.0203
# Epoch [179/200], Step [300/396], Loss: 0.0019
# Epoch done in  0:01:46.531244
# Epoch  180  started...
# Epoch [180/200], Step [100/396], Loss: 0.0735
# Epoch [180/200], Step [200/396], Loss: 0.1024
# Epoch [180/200], Step [300/396], Loss: 0.0080
# Epoch done in  0:01:45.706386
# Epoch  181  started...
# Epoch [181/200], Step [100/396], Loss: 0.0186
# Epoch [181/200], Step [200/396], Loss: 0.0410
# Epoch [181/200], Step [300/396], Loss: 0.0035
# Epoch done in  0:01:45.104461
# Epoch  182  started...
# Epoch [182/200], Step [100/396], Loss: 0.0192
# Epoch [182/200], Step [200/396], Loss: 0.1379
# Epoch [182/200], Step [300/396], Loss: 0.0118
# Epoch done in  0:01:47.032761
# Epoch  183  started...
# Epoch [183/200], Step [100/396], Loss: 0.1715
# Epoch [183/200], Step [200/396], Loss: 0.1010
# Epoch [183/200], Step [300/396], Loss: 0.0118
# Epoch done in  0:01:48.806756
# Epoch  184  started...
# Epoch [184/200], Step [100/396], Loss: 0.0273
# Epoch [184/200], Step [200/396], Loss: 0.0733
# Epoch [184/200], Step [300/396], Loss: 0.0112
# Epoch done in  0:01:51.254868
# Epoch  185  started...
# Epoch [185/200], Step [100/396], Loss: 0.1192
# Epoch [185/200], Step [200/396], Loss: 0.0119
# Epoch [185/200], Step [300/396], Loss: 0.0025
# Epoch done in  0:01:53.197994
# Epoch  186  started...
# Epoch [186/200], Step [100/396], Loss: 0.0360
# Epoch [186/200], Step [200/396], Loss: 0.0003
# => Loss reduced by:	 7.863342761993408e-05
#    Saving model state
# Epoch [186/200], Step [300/396], Loss: 0.0053
# Epoch done in  0:01:53.119621
# Epoch  187  started...
# Epoch [187/200], Step [100/396], Loss: 0.0263
# Epoch [187/200], Step [200/396], Loss: 0.0915
# Epoch [187/200], Step [300/396], Loss: 0.0159
# Epoch done in  0:01:53.864094
# Epoch  188  started...
# Epoch [188/200], Step [100/396], Loss: 0.1651
# Epoch [188/200], Step [200/396], Loss: 0.2036
# Epoch [188/200], Step [300/396], Loss: 0.0074
# Epoch done in  0:01:53.028402
# Epoch  189  started...
# Epoch [189/200], Step [100/396], Loss: 0.0253
# Epoch [189/200], Step [200/396], Loss: 0.0046
# Epoch [189/200], Step [300/396], Loss: 0.0735
# Epoch done in  0:01:54.559609
# Epoch  190  started...
# Epoch [190/200], Step [100/396], Loss: 0.0236
# Epoch [190/200], Step [200/396], Loss: 0.0019
# Epoch [190/200], Step [300/396], Loss: 0.1698
# Epoch done in  0:01:54.456265
# Epoch  191  started...
# Epoch [191/200], Step [100/396], Loss: 0.0019
# Epoch [191/200], Step [200/396], Loss: 0.0490
# Epoch [191/200], Step [300/396], Loss: 0.0294
# Epoch done in  0:01:55.016521
# Epoch  192  started...
# Epoch [192/200], Step [100/396], Loss: 0.0056
# Epoch [192/200], Step [200/396], Loss: 0.2633
# Epoch [192/200], Step [300/396], Loss: 0.1744
# Epoch done in  0:01:55.035167
# Epoch  193  started...
# Epoch [193/200], Step [100/396], Loss: 0.0387
# Epoch [193/200], Step [200/396], Loss: 0.0721
# Epoch [193/200], Step [300/396], Loss: 0.0045
# Epoch done in  0:01:59.496941
# Epoch  194  started...
# Epoch [194/200], Step [100/396], Loss: 0.0031
# Epoch [194/200], Step [200/396], Loss: 0.0339
# Epoch [194/200], Step [300/396], Loss: 0.0615
# Epoch done in  0:01:57.970495
# Epoch  195  started...
# Epoch [195/200], Step [100/396], Loss: 0.0210
# Epoch [195/200], Step [200/396], Loss: 0.0011
# Epoch [195/200], Step [300/396], Loss: 0.0510
# Epoch done in  0:01:54.571105
# Epoch  196  started...
# Epoch [196/200], Step [100/396], Loss: 0.0002
# => Loss reduced by:	 0.00011104345321655273
#    Saving model state
# Epoch [196/200], Step [200/396], Loss: 0.0753
# Epoch [196/200], Step [300/396], Loss: 0.0252
# Epoch done in  0:01:52.963484
# Epoch  197  started...
# Epoch [197/200], Step [100/396], Loss: 0.0661
# Epoch [197/200], Step [200/396], Loss: 0.0056
# Epoch [197/200], Step [300/396], Loss: 0.0029
# Epoch done in  0:01:53.329371
# Epoch  198  started...
# Epoch [198/200], Step [100/396], Loss: 0.0681
# Epoch [198/200], Step [200/396], Loss: 0.0064
# Epoch [198/200], Step [300/396], Loss: 0.0193
# Epoch done in  0:01:53.303343
# Epoch  199  started...
# Epoch [199/200], Step [100/396], Loss: 0.0698
# Epoch [199/200], Step [200/396], Loss: 0.0082
# Epoch [199/200], Step [300/396], Loss: 0.0849
# Epoch done in  0:01:53.554100
# Epoch  200  started...
# Epoch [200/200], Step [100/396], Loss: 0.0368
# Epoch [200/200], Step [200/396], Loss: 0.0832
# Epoch [200/200], Step [300/396], Loss: 0.0130
# Epoch done in  0:01:53.653366
# Training done in  6:15:10.276524

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 93.36283185840708 %

# %%
files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")

labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = False

X = []
Y = []
M = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))
    m = f.split("-")
    m = m[-2]
    M.append(m)

data = {"images":X,"labels":Y,"magnification":M }
images_df_t = pd.DataFrame(data, columns = ['images','labels'])
images_df = pd.DataFrame(data, columns = ['images','labels','magnification'])
images_df_40 = images_df.loc[images_df['magnification']=='40'].drop(['magnification'], axis=1)
images_df_100 = images_df.loc[images_df['magnification']=='100'].drop(['magnification'], axis=1)
images_df_200 = images_df.loc[images_df['magnification']=='200'].drop(['magnification'], axis=1)
images_df_400 = images_df.loc[images_df['magnification']=='400'].drop(['magnification'], axis=1)

dataset_img40 = MyDataset(df_data=images_df_40, transform=trans_valid)
loader_img40 = DataLoader(dataset = dataset_img40, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img100 = MyDataset(df_data=images_df_100, transform=trans_valid)
loader_img100 = DataLoader(dataset = dataset_img100, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img200 = MyDataset(df_data=images_df_200, transform=trans_valid)
loader_img200 = DataLoader(dataset = dataset_img200, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img400 = MyDataset(df_data=images_df_400, transform=trans_valid)
loader_img400 = DataLoader(dataset = dataset_img400, batch_size=batch_size//2, shuffle=False, num_workers=0)
l_list = [loader_img40,loader_img100,loader_img200,loader_img400]
# Out:
# Processed  7909 files

# %%
model.load_state_dict(torch.load('final_state.dct'))
model.eval()
count = 0
for l in l_list:
    count+=1
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in l:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _,predicted = torch.max(outputs.data,1)
            total+=labels.size(0)
            correct+= (predicted==labels).sum().item()
        print('Test Accuracy of model on {} is {} %'.format(count,100*(correct/total)))
# Out:
# Test Accuracy of model on 1 is 97.89473684210527 %
# Test Accuracy of model on 2 is 97.6453628063431 %
# Test Accuracy of model on 3 is 97.66517635370094 %
# Test Accuracy of model on 4 is 97.14285714285714 %

# %%
timestamp_exec_end = time.time()
print("Total execution time: ",str(datetime.timedelta(seconds=(timestamp_exec_end - timestamp_exec_start))))
# Out:
# Total execution time:  6:17:51.805480
