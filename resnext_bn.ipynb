# %%
import pandas as pd
import numpy as np
import time
import datetime
timestamp_exec_start = time.time()

files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")

labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = True

X = []
Y = []
M = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))
    m = f.split("-")
    m = m[-2]
    M.append(m)

data = {"images":X,"labels":Y,"magnification":M }
images_df_t = pd.DataFrame(data, columns = ['images','labels'])
images_df = pd.DataFrame(data, columns = ['images','labels','magnification'])
images_df_40 = images_df.loc[images_df['magnification']=='40'].drop(['magnification'], axis=1)
images_df_100 = images_df.loc[images_df['magnification']=='100'].drop(['magnification'], axis=1)
images_df_200 = images_df.loc[images_df['magnification']=='200'].drop(['magnification'], axis=1)
images_df_400 = images_df.loc[images_df['magnification']=='400'].drop(['magnification'], axis=1)
# Out:
# Processed  7909 files

# %%
# DELETE AFTER APPENDING TO NB ############################################################
batch_size = 16

import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label
    
trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

##############################################################################################

dataset_img40 = MyDataset(df_data=images_df_40, transform=trans_valid)
loader_img40 = DataLoader(dataset = dataset_img40, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img100 = MyDataset(df_data=images_df_100, transform=trans_valid)
loader_img100 = DataLoader(dataset = dataset_img100, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img200 = MyDataset(df_data=images_df_200, transform=trans_valid)
loader_img200 = DataLoader(dataset = dataset_img200, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img400 = MyDataset(df_data=images_df_400, transform=trans_valid)
loader_img400 = DataLoader(dataset = dataset_img400, batch_size=batch_size//2, shuffle=False, num_workers=0)
l_list = [loader_img40,loader_img100,loader_img200,loader_img400]

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset


train, val = train_test_split(images_df_t, stratify=images_df_t.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6327, 1582)

# %%
## Parameters for model

# Hyper parameters
num_epochs = 100
num_classes = 2
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %%
import torchvision.models as models

model = models.resnext50_32x4d(pretrained=True)

model.fc = nn.Linear(512*4,num_classes)

model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/checkpoints/resnext50_32x4d-7cdf4587.pth
# HBox(children=(FloatProgress(value=0.0, max=100441675.0), HTML(value='')))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %%
timestamp_train_start = time.time()

loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/100], Step [100/396], Loss: 0.2071
# => Loss reduced by:	 8.792923018336296
#    Saving model state
# Epoch [1/100], Step [200/396], Loss: 0.1030
# => Loss reduced by:	 0.10411623120307922
#    Saving model state
# Epoch [1/100], Step [300/396], Loss: 0.2868
# Epoch done in  0:03:34.935211
# Epoch  2  started...
# Epoch [2/100], Step [100/396], Loss: 0.1088
# Epoch [2/100], Step [200/396], Loss: 0.0274
# => Loss reduced by:	 0.07555746287107468
#    Saving model state
# Epoch [2/100], Step [300/396], Loss: 0.0975
# Epoch done in  0:03:19.290366
# Epoch  3  started...
# Epoch [3/100], Step [100/396], Loss: 0.0250
# => Loss reduced by:	 0.002383638173341751
#    Saving model state
# Epoch [3/100], Step [200/396], Loss: 0.0405
# Epoch [3/100], Step [300/396], Loss: 0.0511
# Epoch done in  0:03:17.339350
# Epoch  4  started...
# Epoch [4/100], Step [100/396], Loss: 0.0580
# Epoch [4/100], Step [200/396], Loss: 0.0017
# => Loss reduced by:	 0.02331944927573204
#    Saving model state
# Epoch [4/100], Step [300/396], Loss: 0.0065
# Epoch done in  0:03:16.149096
# Epoch  5  started...
# Epoch [5/100], Step [100/396], Loss: 0.0057
# Epoch [5/100], Step [200/396], Loss: 0.0752
# Epoch [5/100], Step [300/396], Loss: 0.0122
# Epoch done in  0:03:16.990123
# Epoch  6  started...
# Epoch [6/100], Step [100/396], Loss: 0.0023
# Epoch [6/100], Step [200/396], Loss: 0.0193
# Epoch [6/100], Step [300/396], Loss: 0.1746
# Epoch done in  0:03:15.374102
# Epoch  7  started...
# Epoch [7/100], Step [100/396], Loss: 0.0065
# Epoch [7/100], Step [200/396], Loss: 0.1514
# Epoch [7/100], Step [300/396], Loss: 0.0026
# Epoch done in  0:03:16.331853
# Epoch  8  started...
# Epoch [8/100], Step [100/396], Loss: 0.0258
# Epoch [8/100], Step [200/396], Loss: 0.0111
# Epoch [8/100], Step [300/396], Loss: 0.0019
# Epoch done in  0:03:16.516393
# Epoch  9  started...
# Epoch [9/100], Step [100/396], Loss: 0.0003
# => Loss reduced by:	 0.001417689025402069
#    Saving model state
# Epoch [9/100], Step [200/396], Loss: 0.0036
# Epoch [9/100], Step [300/396], Loss: 0.0043
# Epoch done in  0:03:16.577328
# Epoch  10  started...
# Epoch [10/100], Step [100/396], Loss: 0.0028
# Epoch [10/100], Step [200/396], Loss: 0.0166
# Epoch [10/100], Step [300/396], Loss: 0.0786
# Epoch done in  0:03:16.861720
# Epoch  11  started...
# Epoch [11/100], Step [100/396], Loss: 0.0063
# Epoch [11/100], Step [200/396], Loss: 0.0012
# Epoch [11/100], Step [300/396], Loss: 0.0032
# Epoch done in  0:03:16.021758
# Epoch  12  started...
# Epoch [12/100], Step [100/396], Loss: 0.0008
# Epoch [12/100], Step [200/396], Loss: 0.0593
# Epoch [12/100], Step [300/396], Loss: 0.0252
# Epoch done in  0:03:17.237224
# Epoch  13  started...
# Epoch [13/100], Step [100/396], Loss: 0.0027
# Epoch [13/100], Step [200/396], Loss: 0.0007
# Epoch [13/100], Step [300/396], Loss: 0.0012
# Epoch done in  0:03:16.365199
# Epoch  14  started...
# Epoch [14/100], Step [100/396], Loss: 0.0290
# Epoch [14/100], Step [200/396], Loss: 0.0009
# Epoch [14/100], Step [300/396], Loss: 0.0006
# Epoch done in  0:03:15.457920
# Epoch  15  started...
# Epoch [15/100], Step [100/396], Loss: 0.0031
# Epoch [15/100], Step [200/396], Loss: 0.3327
# Epoch [15/100], Step [300/396], Loss: 0.0020
# Epoch done in  0:03:25.009036
# Epoch  16  started...
# Epoch [16/100], Step [100/396], Loss: 0.0024
# Epoch [16/100], Step [200/396], Loss: 0.0003
# => Loss reduced by:	 1.0892748832702637e-05
#    Saving model state
# Epoch [16/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:14.768807
# Epoch  17  started...
# Epoch [17/100], Step [100/396], Loss: 0.0007
# Epoch [17/100], Step [200/396], Loss: 0.0002
# => Loss reduced by:	 0.00011841952800750732
#    Saving model state
# Epoch [17/100], Step [300/396], Loss: 0.0070
# Epoch done in  0:03:16.352742
# Epoch  18  started...
# Epoch [18/100], Step [100/396], Loss: 0.0924
# Epoch [18/100], Step [200/396], Loss: 0.0003
# Epoch [18/100], Step [300/396], Loss: 0.0304
# Epoch done in  0:03:16.967004
# Epoch  19  started...
# Epoch [19/100], Step [100/396], Loss: 0.0005
# Epoch [19/100], Step [200/396], Loss: 0.0072
# Epoch [19/100], Step [300/396], Loss: 0.0028
# Epoch done in  0:09:42.200541
# Epoch  20  started...
# Epoch [20/100], Step [100/396], Loss: 0.0005
# Epoch [20/100], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 0.00011990964412689209
#    Saving model state
# Epoch [20/100], Step [300/396], Loss: 0.0401
# Epoch done in  0:03:16.732714
# Epoch  21  started...
# Epoch [21/100], Step [100/396], Loss: 0.0027
# Epoch [21/100], Step [200/396], Loss: 0.0011
# Epoch [21/100], Step [300/396], Loss: 0.0008
# Epoch done in  0:03:17.066089
# Epoch  22  started...
# Epoch [22/100], Step [100/396], Loss: 0.0009
# Epoch [22/100], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 2.2202730178833008e-05
#    Saving model state
# Epoch [22/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.229658
# Epoch  23  started...
# Epoch [23/100], Step [100/396], Loss: 0.0007
# Epoch [23/100], Step [200/396], Loss: 0.0007
# Epoch [23/100], Step [300/396], Loss: 0.0103
# Epoch done in  0:03:16.001778
# Epoch  24  started...
# Epoch [24/100], Step [100/396], Loss: 0.0010
# Epoch [24/100], Step [200/396], Loss: 0.0013
# Epoch [24/100], Step [300/396], Loss: 0.0001
# Epoch done in  0:03:17.625015
# Epoch  25  started...
# Epoch [25/100], Step [100/396], Loss: 0.0006
# Epoch [25/100], Step [200/396], Loss: 0.0016
# Epoch [25/100], Step [300/396], Loss: 0.0002
# Epoch done in  0:03:16.063798
# Epoch  26  started...
# Epoch [26/100], Step [100/396], Loss: 0.0000
# Epoch [26/100], Step [200/396], Loss: 0.0011
# Epoch [26/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.500008
# Epoch  27  started...
# Epoch [27/100], Step [100/396], Loss: 0.0004
# Epoch [27/100], Step [200/396], Loss: 0.0017
# Epoch [27/100], Step [300/396], Loss: 0.0033
# Epoch done in  0:03:16.839627
# Epoch  28  started...
# Epoch [28/100], Step [100/396], Loss: 0.0001
# Epoch [28/100], Step [200/396], Loss: 0.0089
# Epoch [28/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.511515
# Epoch  29  started...
# Epoch [29/100], Step [100/396], Loss: 0.0001
# Epoch [29/100], Step [200/396], Loss: 0.0020
# Epoch [29/100], Step [300/396], Loss: 0.0004
# Epoch done in  0:03:15.846182
# Epoch  30  started...
# Epoch [30/100], Step [100/396], Loss: 0.0003
# Epoch [30/100], Step [200/396], Loss: 0.0006
# Epoch [30/100], Step [300/396], Loss: 0.0005
# Epoch done in  0:03:14.607968
# Epoch  31  started...
# Epoch [31/100], Step [100/396], Loss: 0.0003
# Epoch [31/100], Step [200/396], Loss: 0.0002
# Epoch [31/100], Step [300/396], Loss: 0.0007
# Epoch done in  0:03:17.158299
# Epoch  32  started...
# Epoch [32/100], Step [100/396], Loss: 0.0001
# Epoch [32/100], Step [200/396], Loss: 0.0003
# Epoch [32/100], Step [300/396], Loss: 0.0008
# Epoch done in  0:03:16.006828
# Epoch  33  started...
# Epoch [33/100], Step [100/396], Loss: 0.0001
# Epoch [33/100], Step [200/396], Loss: 0.0001
# Epoch [33/100], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 7.897615432739258e-06
#    Saving model state
# Epoch done in  0:03:17.341455
# Epoch  34  started...
# Epoch [34/100], Step [100/396], Loss: 0.0008
# Epoch [34/100], Step [200/396], Loss: 0.0000
# Epoch [34/100], Step [300/396], Loss: 0.0092
# Epoch done in  0:03:15.794946
# Epoch  35  started...
# Epoch [35/100], Step [100/396], Loss: 0.0001
# Epoch [35/100], Step [200/396], Loss: 0.0102
# Epoch [35/100], Step [300/396], Loss: 0.0002
# Epoch done in  0:03:15.201923
# Epoch  36  started...
# Epoch [36/100], Step [100/396], Loss: 0.0001
# Epoch [36/100], Step [200/396], Loss: 0.0056
# Epoch [36/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.452547
# Epoch  37  started...
# Epoch [37/100], Step [100/396], Loss: 0.0002
# Epoch [37/100], Step [200/396], Loss: 0.0014
# Epoch [37/100], Step [300/396], Loss: 0.0005
# Epoch done in  0:03:15.307527
# Epoch  38  started...
# Epoch [38/100], Step [100/396], Loss: 0.0021
# Epoch [38/100], Step [200/396], Loss: 0.0000
# Epoch [38/100], Step [300/396], Loss: 0.0011
# Epoch done in  0:03:15.410080
# Epoch  39  started...
# Epoch [39/100], Step [100/396], Loss: 0.0004
# Epoch [39/100], Step [200/396], Loss: 0.0050
# Epoch [39/100], Step [300/396], Loss: 0.0062
# Epoch done in  0:03:15.291525
# Epoch  40  started...
# Epoch [40/100], Step [100/396], Loss: 0.0016
# Epoch [40/100], Step [200/396], Loss: 0.0034
# Epoch [40/100], Step [300/396], Loss: 0.0190
# Epoch done in  0:03:15.782790
# Epoch  41  started...
# Epoch [41/100], Step [100/396], Loss: 0.0001
# Epoch [41/100], Step [200/396], Loss: 0.0001
# Epoch [41/100], Step [300/396], Loss: 0.0004
# Epoch done in  0:03:15.771521
# Epoch  42  started...
# Epoch [42/100], Step [100/396], Loss: 0.0001
# Epoch [42/100], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 1.8775463104248047e-06
#    Saving model state
# Epoch [42/100], Step [300/396], Loss: 0.0008
# Epoch done in  0:03:16.165204
# Epoch  43  started...
# Epoch [43/100], Step [100/396], Loss: 0.0000
# Epoch [43/100], Step [200/396], Loss: 0.0000
# Epoch [43/100], Step [300/396], Loss: 0.0074
# Epoch done in  0:03:16.602591
# Epoch  44  started...
# Epoch [44/100], Step [100/396], Loss: 0.0000
# Epoch [44/100], Step [200/396], Loss: 0.0001
# Epoch [44/100], Step [300/396], Loss: 0.0280
# Epoch done in  0:03:15.632341
# Epoch  45  started...
# Epoch [45/100], Step [100/396], Loss: 0.0002
# Epoch [45/100], Step [200/396], Loss: 0.0000
# Epoch [45/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.108735
# Epoch  46  started...
# Epoch [46/100], Step [100/396], Loss: 0.0001
# Epoch [46/100], Step [200/396], Loss: 0.0000
# Epoch [46/100], Step [300/396], Loss: 0.0006
# Epoch done in  0:03:17.390654
# Epoch  47  started...
# Epoch [47/100], Step [100/396], Loss: 0.0001
# Epoch [47/100], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 6.258487701416016e-07
#    Saving model state
# Epoch [47/100], Step [300/396], Loss: 0.0001
# Epoch done in  0:03:17.958762
# Epoch  48  started...
# Epoch [48/100], Step [100/396], Loss: 0.0001
# Epoch [48/100], Step [200/396], Loss: 0.0010
# Epoch [48/100], Step [300/396], Loss: 0.0004
# Epoch done in  0:03:16.428380
# Epoch  49  started...
# Epoch [49/100], Step [100/396], Loss: 0.0004
# Epoch [49/100], Step [200/396], Loss: 0.0001
# Epoch [49/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.631722
# Epoch  50  started...
# Epoch [50/100], Step [100/396], Loss: 0.0034
# Epoch [50/100], Step [200/396], Loss: 0.0063
# Epoch [50/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.999499
# Epoch  51  started...
# Epoch [51/100], Step [100/396], Loss: 0.0015
# Epoch [51/100], Step [200/396], Loss: 0.0002
# Epoch [51/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:17.327902
# Epoch  52  started...
# Epoch [52/100], Step [100/396], Loss: 0.0000
# Epoch [52/100], Step [200/396], Loss: 0.0000
# Epoch [52/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:14.928808
# Epoch  53  started...
# Epoch [53/100], Step [100/396], Loss: 0.0005
# Epoch [53/100], Step [200/396], Loss: 0.0002
# Epoch [53/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.800774
# Epoch  54  started...
# Epoch [54/100], Step [100/396], Loss: 0.0001
# Epoch [54/100], Step [200/396], Loss: 0.0000
# Epoch [54/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.950445
# Epoch  55  started...
# Epoch [55/100], Step [100/396], Loss: 0.0000
# Epoch [55/100], Step [200/396], Loss: 0.0001
# Epoch [55/100], Step [300/396], Loss: 0.0001
# Epoch done in  0:03:14.779737
# Epoch  56  started...
# Epoch [56/100], Step [100/396], Loss: 0.0001
# Epoch [56/100], Step [200/396], Loss: 0.0017
# Epoch [56/100], Step [300/396], Loss: 0.0002
# Epoch done in  0:03:15.593250
# Epoch  57  started...
# Epoch [57/100], Step [100/396], Loss: 0.0043
# Epoch [57/100], Step [200/396], Loss: 0.0004
# Epoch [57/100], Step [300/396], Loss: 0.0002
# Epoch done in  0:03:16.369725
# Epoch  58  started...
# Epoch [58/100], Step [100/396], Loss: 0.0006
# Epoch [58/100], Step [200/396], Loss: 0.0001
# Epoch [58/100], Step [300/396], Loss: 0.0001
# Epoch done in  0:03:16.464186
# Epoch  59  started...
# Epoch [59/100], Step [100/396], Loss: 0.0000
# Epoch [59/100], Step [200/396], Loss: 0.0004
# Epoch [59/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.918514
# Epoch  60  started...
# Epoch [60/100], Step [100/396], Loss: 0.0001
# Epoch [60/100], Step [200/396], Loss: 0.0010
# Epoch [60/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.403417
# Epoch  61  started...
# Epoch [61/100], Step [100/396], Loss: 0.0000
# Epoch [61/100], Step [200/396], Loss: 0.0000
# Epoch [61/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.104449
# Epoch  62  started...
# Epoch [62/100], Step [100/396], Loss: 0.0018
# Epoch [62/100], Step [200/396], Loss: 0.0000
# Epoch [62/100], Step [300/396], Loss: 0.0002
# Epoch done in  0:03:16.907189
# Epoch  63  started...
# Epoch [63/100], Step [100/396], Loss: 0.0000
# Epoch [63/100], Step [200/396], Loss: 0.0002
# Epoch [63/100], Step [300/396], Loss: 0.0015
# Epoch done in  0:03:16.055163
# Epoch  64  started...
# Epoch [64/100], Step [100/396], Loss: 0.0000
# Epoch [64/100], Step [200/396], Loss: 0.0076
# Epoch [64/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.075665
# Epoch  65  started...
# Epoch [65/100], Step [100/396], Loss: 0.0000
# Epoch [65/100], Step [200/396], Loss: 0.0001
# Epoch [65/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:17.938128
# Epoch  66  started...
# Epoch [66/100], Step [100/396], Loss: 0.0091
# Epoch [66/100], Step [200/396], Loss: 0.0001
# Epoch [66/100], Step [300/396], Loss: 0.0026
# Epoch done in  0:03:15.911293
# Epoch  67  started...
# Epoch [67/100], Step [100/396], Loss: 0.0001
# Epoch [67/100], Step [200/396], Loss: 0.0001
# Epoch [67/100], Step [300/396], Loss: 0.0219
# Epoch done in  0:03:16.219557
# Epoch  68  started...
# Epoch [68/100], Step [100/396], Loss: 0.0001
# Epoch [68/100], Step [200/396], Loss: 0.0000
# Epoch [68/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:19.685648
# Epoch  69  started...
# Epoch [69/100], Step [100/396], Loss: 0.0017
# Epoch [69/100], Step [200/396], Loss: 0.0000
# Epoch [69/100], Step [300/396], Loss: 0.0006
# Epoch done in  0:03:17.741427
# Epoch  70  started...
# Epoch [70/100], Step [100/396], Loss: 0.0000
# Epoch [70/100], Step [200/396], Loss: 0.0001
# Epoch [70/100], Step [300/396], Loss: 0.0001
# Epoch done in  0:03:16.974421
# Epoch  71  started...
# Epoch [71/100], Step [100/396], Loss: 0.0378
# Epoch [71/100], Step [200/396], Loss: 0.0000
# Epoch [71/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:18.148162
# Epoch  72  started...
# Epoch [72/100], Step [100/396], Loss: 0.0014
# Epoch [72/100], Step [200/396], Loss: 0.0022
# Epoch [72/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.816200
# Epoch  73  started...
# Epoch [73/100], Step [100/396], Loss: 0.0001
# Epoch [73/100], Step [200/396], Loss: 0.0000
# Epoch [73/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.298643
# Epoch  74  started...
# Epoch [74/100], Step [100/396], Loss: 0.0001
# Epoch [74/100], Step [200/396], Loss: 0.0004
# Epoch [74/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.119903
# Epoch  75  started...
# Epoch [75/100], Step [100/396], Loss: 0.0000
# Epoch [75/100], Step [200/396], Loss: 0.0001
# Epoch [75/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.374420
# Epoch  76  started...
# Epoch [76/100], Step [100/396], Loss: 0.0002
# Epoch [76/100], Step [200/396], Loss: 0.0000
# Epoch [76/100], Step [300/396], Loss: 0.0003
# Epoch done in  0:03:16.864503
# Epoch  77  started...
# Epoch [77/100], Step [100/396], Loss: 0.0002
# Epoch [77/100], Step [200/396], Loss: 0.0000
# Epoch [77/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:38.990446
# Epoch  78  started...
# Epoch [78/100], Step [100/396], Loss: 0.0003
# Epoch [78/100], Step [200/396], Loss: 0.0000
# Epoch [78/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.282016
# Epoch  79  started...
# Epoch [79/100], Step [100/396], Loss: 0.0000
# Epoch [79/100], Step [200/396], Loss: 0.0000
# Epoch [79/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:18.224731
# Epoch  80  started...
# Epoch [80/100], Step [100/396], Loss: 0.0000
# Epoch [80/100], Step [200/396], Loss: 0.0001
# Epoch [80/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.636977
# Epoch  81  started...
# Epoch [81/100], Step [100/396], Loss: 0.0000
# Epoch [81/100], Step [200/396], Loss: 0.0000
# Epoch [81/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:17.168937
# Epoch  82  started...
# Epoch [82/100], Step [100/396], Loss: 0.0001
# Epoch [82/100], Step [200/396], Loss: 0.0000
# Epoch [82/100], Step [300/396], Loss: 0.1460
# Epoch done in  0:03:16.450948
# Epoch  83  started...
# Epoch [83/100], Step [100/396], Loss: 0.0000
# Epoch [83/100], Step [200/396], Loss: 0.0000
# Epoch [83/100], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 4.172325134277344e-07
#    Saving model state
# Epoch done in  0:03:16.798672
# Epoch  84  started...
# Epoch [84/100], Step [100/396], Loss: 0.0001
# Epoch [84/100], Step [200/396], Loss: 0.0000
# Epoch [84/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.468614
# Epoch  85  started...
# Epoch [85/100], Step [100/396], Loss: 0.0000
# Epoch [85/100], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 2.086162567138672e-07
#    Saving model state
# Epoch [85/100], Step [300/396], Loss: 0.0038
# Epoch done in  0:03:16.855999
# Epoch  86  started...
# Epoch [86/100], Step [100/396], Loss: 0.0000
# Epoch [86/100], Step [200/396], Loss: 0.0003
# Epoch [86/100], Step [300/396], Loss: 0.0033
# Epoch done in  0:03:15.513811
# Epoch  87  started...
# Epoch [87/100], Step [100/396], Loss: 0.0000
# Epoch [87/100], Step [200/396], Loss: 0.0000
# Epoch [87/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.338632
# Epoch  88  started...
# Epoch [88/100], Step [100/396], Loss: 0.0000
# Epoch [88/100], Step [200/396], Loss: 0.0448
# Epoch [88/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.974333
# Epoch  89  started...
# Epoch [89/100], Step [100/396], Loss: 0.0000
# Epoch [89/100], Step [200/396], Loss: 0.0000
# Epoch [89/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.031812
# Epoch  90  started...
# Epoch [90/100], Step [100/396], Loss: 0.0000
# Epoch [90/100], Step [200/396], Loss: 0.0000
# Epoch [90/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.676738
# Epoch  91  started...
# Epoch [91/100], Step [100/396], Loss: 0.0000
# Epoch [91/100], Step [200/396], Loss: 0.0000
# Epoch [91/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.151403
# Epoch  92  started...
# Epoch [92/100], Step [100/396], Loss: 0.0004
# Epoch [92/100], Step [200/396], Loss: 0.0000
# Epoch [92/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.489735
# Epoch  93  started...
# Epoch [93/100], Step [100/396], Loss: 0.0000
# Epoch [93/100], Step [200/396], Loss: 0.0000
# Epoch [93/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.583571
# Epoch  94  started...
# Epoch [94/100], Step [100/396], Loss: 0.0000
# Epoch [94/100], Step [200/396], Loss: 0.0000
# Epoch [94/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.681600
# Epoch  95  started...
# Epoch [95/100], Step [100/396], Loss: 0.0000
# Epoch [95/100], Step [200/396], Loss: 0.0000
# Epoch [95/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:16.181170
# Epoch  96  started...
# Epoch [96/100], Step [100/396], Loss: 0.0000
# Epoch [96/100], Step [200/396], Loss: 0.0001
# Epoch [96/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:15.792306
# Epoch  97  started...
# Epoch [97/100], Step [100/396], Loss: 0.0001
# Epoch [97/100], Step [200/396], Loss: 0.0000
# Epoch [97/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:13.374949
# Epoch  98  started...
# Epoch [98/100], Step [100/396], Loss: 0.0000
# Epoch [98/100], Step [200/396], Loss: 0.0000
# Epoch [98/100], Step [300/396], Loss: 0.0000
# Epoch done in  0:03:12.671813
# Epoch  99  started...
# Epoch [99/100], Step [100/396], Loss: 0.0000
# Epoch [99/100], Step [200/396], Loss: 0.0000
# Epoch [99/100], Step [300/396], Loss: 0.0014
# Epoch done in  0:03:16.992889
# Epoch  100  started...
# Epoch [100/100], Step [100/396], Loss: 0.0000
# Epoch [100/100], Step [200/396], Loss: 0.0004
# Epoch [100/100], Step [300/396], Loss: 0.0005
# Epoch done in  0:03:17.832418
# Training done in  5:34:37.179035

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 98.92541087231352 %

# %%
model.load_state_dict(torch.load('final_state.dct'))
model.eval()
count = 0
for l in l_list:
    count+=1
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in l:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _,predicted = torch.max(outputs.data,1)
            total+=labels.size(0)
            correct+= (predicted==labels).sum().item()
        print('Test Accuracy of model on {} is {} %'.format(count,100*(correct/total)))
# Out:
# Test Accuracy of model on 1 is 99.74937343358395 %
# Test Accuracy of model on 2 is 99.85583853916387 %
# Test Accuracy of model on 3 is 99.8012916045703 %
# Test Accuracy of model on 4 is 99.72527472527473 %
