# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
        # print(os.path.join(dirname, filename))

import time
import datetime
timestamp_exec_start = time.time()


files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")


labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = False

X = []
Y = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))

data = {"images":X,"labels":Y}
images_df = pd.DataFrame(data, columns = ['images','labels'])
images_df.groupby("labels")["labels"].count()
# Out:
# Processed  7909 files
# labels
# 0     444
# 1    1014
# 2     569
# 3     453
# 4    3451
# 5     626
# 6     792
# 7     560
# Name: labels, dtype: int64

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

# %%
train, val = train_test_split(images_df, stratify=images_df.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6327, 1582)

# %%
class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
## Parameters for model

# Hyper parameters
num_epochs = 150
num_classes = 8
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
# Utility function for saving model
# During training, the loss values are stored in a list.
# We check the last two values to see if the loss has reduced.
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %% [markdown]
# Now, we create the model and train it.

# %%
import torchvision.models as models

model = models.densenet121(pretrained=True)

model.classifier = nn.Linear(1024,num_classes)

model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 75.9MB/s]

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %% [markdown]
# import os
# import urllib.request
# url = "https://onedrive.live.com/download?cid=E5569BBAB912B6A5&resid=E5569BBAB912B6A5%21532997&authkey=AIIbJpY85FBd61c"
# file_name = "download.dct"
# print("Downloading pre-trained model state...")
# urllib.request.urlretrieve(url, file_name)
# print("Done!")
# model.load_state_dict(torch.load(file_name))
# import os.path
# if os.path.exists(file_name):
#     try:
#         model.load_state_dict(torch.load(file_name))
#         print("Downloaded model state loaded successfully.")
#     except:
#         print("Error loading state dict.")

# %%
# Train the model
timestamp_train_start = time.time()

loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/150], Step [100/396], Loss: 1.4082
# => Loss reduced by:	 7.591842532157898
#    Saving model state
# Epoch [1/150], Step [200/396], Loss: 0.9388
# => Loss reduced by:	 0.469341516494751
#    Saving model state
# Epoch [1/150], Step [300/396], Loss: 1.0248
# Epoch done in  0:03:04.808728
# Epoch  2  started...
# Epoch [2/150], Step [100/396], Loss: 0.4138
# => Loss reduced by:	 0.5249681174755096
#    Saving model state
# Epoch [2/150], Step [200/396], Loss: 0.5762
# Epoch [2/150], Step [300/396], Loss: 0.4448
# Epoch done in  0:02:29.835710
# Epoch  3  started...
# Epoch [3/150], Step [100/396], Loss: 0.3504
# => Loss reduced by:	 0.06345292925834656
#    Saving model state
# Epoch [3/150], Step [200/396], Loss: 0.5052
# Epoch [3/150], Step [300/396], Loss: 0.3480
# => Loss reduced by:	 0.0023616552352905273
#    Saving model state
# Epoch done in  0:02:31.788760
# Epoch  4  started...
# Epoch [4/150], Step [100/396], Loss: 0.3902
# Epoch [4/150], Step [200/396], Loss: 0.2868
# => Loss reduced by:	 0.06126457452774048
#    Saving model state
# Epoch [4/150], Step [300/396], Loss: 0.5459
# Epoch done in  0:02:30.531409
# Epoch  5  started...
# Epoch [5/150], Step [100/396], Loss: 0.1928
# => Loss reduced by:	 0.09400679171085358
#    Saving model state
# Epoch [5/150], Step [200/396], Loss: 0.3891
# Epoch [5/150], Step [300/396], Loss: 0.2436
# Epoch done in  0:02:29.597244
# Epoch  6  started...
# Epoch [6/150], Step [100/396], Loss: 0.3617
# Epoch [6/150], Step [200/396], Loss: 0.1138
# => Loss reduced by:	 0.07895761728286743
#    Saving model state
# Epoch [6/150], Step [300/396], Loss: 0.0785
# => Loss reduced by:	 0.03529001772403717
#    Saving model state
# Epoch done in  0:02:27.808485
# Epoch  7  started...
# Epoch [7/150], Step [100/396], Loss: 0.1332
# Epoch [7/150], Step [200/396], Loss: 0.0551
# => Loss reduced by:	 0.023386582732200623
#    Saving model state
# Epoch [7/150], Step [300/396], Loss: 0.1481
# Epoch done in  0:02:27.351820
# Epoch  8  started...
# Epoch [8/150], Step [100/396], Loss: 0.0944
# Epoch [8/150], Step [200/396], Loss: 0.2557
# Epoch [8/150], Step [300/396], Loss: 0.1691
# Epoch done in  0:02:27.491072
# Epoch  9  started...
# Epoch [9/150], Step [100/396], Loss: 0.1337
# Epoch [9/150], Step [200/396], Loss: 0.1071
# Epoch [9/150], Step [300/396], Loss: 0.2194
# Epoch done in  0:02:28.032268
# Epoch  10  started...
# Epoch [10/150], Step [100/396], Loss: 0.1793
# Epoch [10/150], Step [200/396], Loss: 0.1162
# Epoch [10/150], Step [300/396], Loss: 0.4707
# Epoch done in  0:02:28.338528
# Epoch  11  started...
# Epoch [11/150], Step [100/396], Loss: 0.0881
# Epoch [11/150], Step [200/396], Loss: 0.0685
# Epoch [11/150], Step [300/396], Loss: 0.0556
# Epoch done in  0:02:30.482572
# Epoch  12  started...
# Epoch [12/150], Step [100/396], Loss: 0.1876
# Epoch [12/150], Step [200/396], Loss: 0.0700
# Epoch [12/150], Step [300/396], Loss: 0.0348
# => Loss reduced by:	 0.02034907042980194
#    Saving model state
# Epoch done in  0:02:27.263224
# Epoch  13  started...
# Epoch [13/150], Step [100/396], Loss: 0.1674
# Epoch [13/150], Step [200/396], Loss: 0.1389
# Epoch [13/150], Step [300/396], Loss: 0.1054
# Epoch done in  0:02:24.612246
# Epoch  14  started...
# Epoch [14/150], Step [100/396], Loss: 0.0612
# Epoch [14/150], Step [200/396], Loss: 0.0120
# => Loss reduced by:	 0.022770464420318604
#    Saving model state
# Epoch [14/150], Step [300/396], Loss: 0.1564
# Epoch done in  0:02:22.896508
# Epoch  15  started...
# Epoch [15/150], Step [100/396], Loss: 0.1051
# Epoch [15/150], Step [200/396], Loss: 0.2289
# Epoch [15/150], Step [300/396], Loss: 0.1575
# Epoch done in  0:02:21.752672
# Epoch  16  started...
# Epoch [16/150], Step [100/396], Loss: 0.1283
# Epoch [16/150], Step [200/396], Loss: 0.1123
# Epoch [16/150], Step [300/396], Loss: 0.0618
# Epoch done in  0:02:22.346568
# Epoch  17  started...
# Epoch [17/150], Step [100/396], Loss: 0.0569
# Epoch [17/150], Step [200/396], Loss: 0.0357
# Epoch [17/150], Step [300/396], Loss: 0.0168
# Epoch done in  0:02:20.647567
# Epoch  18  started...
# Epoch [18/150], Step [100/396], Loss: 0.0596
# Epoch [18/150], Step [200/396], Loss: 0.0455
# Epoch [18/150], Step [300/396], Loss: 0.0554
# Epoch done in  0:02:20.929667
# Epoch  19  started...
# Epoch [19/150], Step [100/396], Loss: 0.0565
# Epoch [19/150], Step [200/396], Loss: 0.0195
# Epoch [19/150], Step [300/396], Loss: 0.0160
# Epoch done in  0:02:21.744258
# Epoch  20  started...
# Epoch [20/150], Step [100/396], Loss: 0.0318
# Epoch [20/150], Step [200/396], Loss: 0.0451
# Epoch [20/150], Step [300/396], Loss: 0.0381
# Epoch done in  0:02:20.969186
# Epoch  21  started...
# Epoch [21/150], Step [100/396], Loss: 0.0176
# Epoch [21/150], Step [200/396], Loss: 0.1249
# Epoch [21/150], Step [300/396], Loss: 0.0397
# Epoch done in  0:02:22.075099
# Epoch  22  started...
# Epoch [22/150], Step [100/396], Loss: 0.1119
# Epoch [22/150], Step [200/396], Loss: 0.0906
# Epoch [22/150], Step [300/396], Loss: 0.1218
# Epoch done in  0:02:20.917445
# Epoch  23  started...
# Epoch [23/150], Step [100/396], Loss: 0.1363
# Epoch [23/150], Step [200/396], Loss: 0.0154
# Epoch [23/150], Step [300/396], Loss: 0.0096
# => Loss reduced by:	 0.002427518367767334
#    Saving model state
# Epoch done in  0:02:20.657536
# Epoch  24  started...
# Epoch [24/150], Step [100/396], Loss: 0.0038
# => Loss reduced by:	 0.00573316216468811
#    Saving model state
# Epoch [24/150], Step [200/396], Loss: 0.0371
# Epoch [24/150], Step [300/396], Loss: 0.0607
# Epoch done in  0:02:21.939849
# Epoch  25  started...
# Epoch [25/150], Step [100/396], Loss: 0.0089
# Epoch [25/150], Step [200/396], Loss: 0.0079
# Epoch [25/150], Step [300/396], Loss: 0.0101
# Epoch done in  0:02:20.121125
# Epoch  26  started...
# Epoch [26/150], Step [100/396], Loss: 0.0134
# Epoch [26/150], Step [200/396], Loss: 0.1023
# Epoch [26/150], Step [300/396], Loss: 0.0544
# Epoch done in  0:02:20.943293
# Epoch  27  started...
# Epoch [27/150], Step [100/396], Loss: 0.1774
# Epoch [27/150], Step [200/396], Loss: 0.1203
# Epoch [27/150], Step [300/396], Loss: 0.0055
# Epoch done in  0:02:23.962343
# Epoch  28  started...
# Epoch [28/150], Step [100/396], Loss: 0.0029
# => Loss reduced by:	 0.0009286999702453613
#    Saving model state
# Epoch [28/150], Step [200/396], Loss: 0.0868
# Epoch [28/150], Step [300/396], Loss: 0.0062
# Epoch done in  0:02:21.013661
# Epoch  29  started...
# Epoch [29/150], Step [100/396], Loss: 0.0948
# Epoch [29/150], Step [200/396], Loss: 0.0123
# Epoch [29/150], Step [300/396], Loss: 0.0276
# Epoch done in  0:02:25.175309
# Epoch  30  started...
# Epoch [30/150], Step [100/396], Loss: 0.0386
# Epoch [30/150], Step [200/396], Loss: 0.0352
# Epoch [30/150], Step [300/396], Loss: 0.0551
# Epoch done in  0:02:23.081291
# Epoch  31  started...
# Epoch [31/150], Step [100/396], Loss: 0.0050
# Epoch [31/150], Step [200/396], Loss: 0.0259
# Epoch [31/150], Step [300/396], Loss: 0.0493
# Epoch done in  0:02:22.346717
# Epoch  32  started...
# Epoch [32/150], Step [100/396], Loss: 0.0370
# Epoch [32/150], Step [200/396], Loss: 0.0620
# Epoch [32/150], Step [300/396], Loss: 0.0404
# Epoch done in  0:02:37.704156
# Epoch  33  started...
# Epoch [33/150], Step [100/396], Loss: 0.0334
# Epoch [33/150], Step [200/396], Loss: 0.0449
# Epoch [33/150], Step [300/396], Loss: 0.0318
# Epoch done in  0:02:21.719159
# Epoch  34  started...
# Epoch [34/150], Step [100/396], Loss: 0.0265
# Epoch [34/150], Step [200/396], Loss: 0.0362
# Epoch [34/150], Step [300/396], Loss: 0.0038
# Epoch done in  0:02:23.797702
# Epoch  35  started...
# Epoch [35/150], Step [100/396], Loss: 0.0255
# Epoch [35/150], Step [200/396], Loss: 0.0073
# Epoch [35/150], Step [300/396], Loss: 0.0257
# Epoch done in  0:02:22.820525
# Epoch  36  started...
# Epoch [36/150], Step [100/396], Loss: 0.0517
# Epoch [36/150], Step [200/396], Loss: 0.0247
# Epoch [36/150], Step [300/396], Loss: 0.0478
# Epoch done in  0:02:23.121809
# Epoch  37  started...
# Epoch [37/150], Step [100/396], Loss: 0.0436
# Epoch [37/150], Step [200/396], Loss: 0.0097
# Epoch [37/150], Step [300/396], Loss: 0.0043
# Epoch done in  0:02:23.217200
# Epoch  38  started...
# Epoch [38/150], Step [100/396], Loss: 0.0084
# Epoch [38/150], Step [200/396], Loss: 0.0901
# Epoch [38/150], Step [300/396], Loss: 0.0122
# Epoch done in  0:02:22.622219
# Epoch  39  started...
# Epoch [39/150], Step [100/396], Loss: 0.1093
# Epoch [39/150], Step [200/396], Loss: 0.0478
# Epoch [39/150], Step [300/396], Loss: 0.0032
# Epoch done in  0:02:22.738747
# Epoch  40  started...
# Epoch [40/150], Step [100/396], Loss: 0.0017
# => Loss reduced by:	 0.001173555850982666
#    Saving model state
# Epoch [40/150], Step [200/396], Loss: 0.0631
# Epoch [40/150], Step [300/396], Loss: 0.0142
# Epoch done in  0:02:23.580141
# Epoch  41  started...
# Epoch [41/150], Step [100/396], Loss: 0.0250
# Epoch [41/150], Step [200/396], Loss: 0.0058
# Epoch [41/150], Step [300/396], Loss: 0.0407
# Epoch done in  0:02:22.425886
# Epoch  42  started...
# Epoch [42/150], Step [100/396], Loss: 0.0927
# Epoch [42/150], Step [200/396], Loss: 0.0293
# Epoch [42/150], Step [300/396], Loss: 0.0039
# Epoch done in  0:02:23.277174
# Epoch  43  started...
# Epoch [43/150], Step [100/396], Loss: 0.0184
# Epoch [43/150], Step [200/396], Loss: 0.0639
# Epoch [43/150], Step [300/396], Loss: 0.0503
# Epoch done in  0:02:23.332931
# Epoch  44  started...
# Epoch [44/150], Step [100/396], Loss: 0.0067
# Epoch [44/150], Step [200/396], Loss: 0.0015
# => Loss reduced by:	 0.000295102596282959
#    Saving model state
# Epoch [44/150], Step [300/396], Loss: 0.0468
# Epoch done in  0:02:23.786280
# Epoch  45  started...
# Epoch [45/150], Step [100/396], Loss: 0.0028
# Epoch [45/150], Step [200/396], Loss: 0.0017
# Epoch [45/150], Step [300/396], Loss: 0.0019
# Epoch done in  0:02:24.687035
# Epoch  46  started...
# Epoch [46/150], Step [100/396], Loss: 0.0031
# Epoch [46/150], Step [200/396], Loss: 0.0060
# Epoch [46/150], Step [300/396], Loss: 0.0047
# Epoch done in  0:02:22.931539
# Epoch  47  started...
# Epoch [47/150], Step [100/396], Loss: 0.0631
# Epoch [47/150], Step [200/396], Loss: 0.0175
# Epoch [47/150], Step [300/396], Loss: 0.1317
# Epoch done in  0:02:23.480900
# Epoch  48  started...
# Epoch [48/150], Step [100/396], Loss: 0.0205
# Epoch [48/150], Step [200/396], Loss: 0.0994
# Epoch [48/150], Step [300/396], Loss: 0.0014
# => Loss reduced by:	 1.537799835205078e-05
#    Saving model state
# Epoch done in  0:02:23.185100
# Epoch  49  started...
# Epoch [49/150], Step [100/396], Loss: 0.0516
# Epoch [49/150], Step [200/396], Loss: 0.0394
# Epoch [49/150], Step [300/396], Loss: 0.0628
# Epoch done in  0:02:23.744490
# Epoch  50  started...
# Epoch [50/150], Step [100/396], Loss: 0.0153
# Epoch [50/150], Step [200/396], Loss: 0.0681
# Epoch [50/150], Step [300/396], Loss: 0.0016
# Epoch done in  0:02:23.632849
# Epoch  51  started...
# Epoch [51/150], Step [100/396], Loss: 0.0031
# Epoch [51/150], Step [200/396], Loss: 0.1984
# Epoch [51/150], Step [300/396], Loss: 0.0437
# Epoch done in  0:02:22.926833
# Epoch  52  started...
# Epoch [52/150], Step [100/396], Loss: 0.0633
# Epoch [52/150], Step [200/396], Loss: 0.0065
# Epoch [52/150], Step [300/396], Loss: 0.0522
# Epoch done in  0:02:23.405937
# Epoch  53  started...
# Epoch [53/150], Step [100/396], Loss: 0.0023
# Epoch [53/150], Step [200/396], Loss: 0.0032
# Epoch [53/150], Step [300/396], Loss: 0.0040
# Epoch done in  0:02:23.347988
# Epoch  54  started...
# Epoch [54/150], Step [100/396], Loss: 0.0042
# Epoch [54/150], Step [200/396], Loss: 0.0016
# Epoch [54/150], Step [300/396], Loss: 0.0487
# Epoch done in  0:02:23.032348
# Epoch  55  started...
# Epoch [55/150], Step [100/396], Loss: 0.0740
# Epoch [55/150], Step [200/396], Loss: 0.0007
# => Loss reduced by:	 0.0007098019123077393
#    Saving model state
# Epoch [55/150], Step [300/396], Loss: 0.0024
# Epoch done in  0:02:29.349471
# Epoch  56  started...
# Epoch [56/150], Step [100/396], Loss: 0.0272
# Epoch [56/150], Step [200/396], Loss: 0.0380
# Epoch [56/150], Step [300/396], Loss: 0.1175
# Epoch done in  0:02:26.420158
# Epoch  57  started...
# Epoch [57/150], Step [100/396], Loss: 0.0005
# => Loss reduced by:	 0.00022345781326293945
#    Saving model state
# Epoch [57/150], Step [200/396], Loss: 0.0008
# Epoch [57/150], Step [300/396], Loss: 0.0422
# Epoch done in  0:02:26.045431
# Epoch  58  started...
# Epoch [58/150], Step [100/396], Loss: 0.1313
# Epoch [58/150], Step [200/396], Loss: 0.0146
# Epoch [58/150], Step [300/396], Loss: 0.0016
# Epoch done in  0:02:24.068319
# Epoch  59  started...
# Epoch [59/150], Step [100/396], Loss: 0.1425
# Epoch [59/150], Step [200/396], Loss: 0.0609
# Epoch [59/150], Step [300/396], Loss: 0.0540
# Epoch done in  0:02:23.286436
# Epoch  60  started...
# Epoch [60/150], Step [100/396], Loss: 0.0057
# Epoch [60/150], Step [200/396], Loss: 0.0311
# Epoch [60/150], Step [300/396], Loss: 0.0022
# Epoch done in  0:02:22.581002
# Epoch  61  started...
# Epoch [61/150], Step [100/396], Loss: 0.0100
# Epoch [61/150], Step [200/396], Loss: 0.0657
# Epoch [61/150], Step [300/396], Loss: 0.0857
# Epoch done in  0:02:22.072456
# Epoch  62  started...
# Epoch [62/150], Step [100/396], Loss: 0.0079
# Epoch [62/150], Step [200/396], Loss: 0.0061
# Epoch [62/150], Step [300/396], Loss: 0.0010
# Epoch done in  0:02:22.819480
# Epoch  63  started...
# Epoch [63/150], Step [100/396], Loss: 0.0073
# Epoch [63/150], Step [200/396], Loss: 0.0057
# Epoch [63/150], Step [300/396], Loss: 0.0013
# Epoch done in  0:02:21.733746
# Epoch  64  started...
# Epoch [64/150], Step [100/396], Loss: 0.0290
# Epoch [64/150], Step [200/396], Loss: 0.0222
# Epoch [64/150], Step [300/396], Loss: 0.0425
# Epoch done in  0:02:21.632009
# Epoch  65  started...
# Epoch [65/150], Step [100/396], Loss: 0.0007
# Epoch [65/150], Step [200/396], Loss: 0.0484
# Epoch [65/150], Step [300/396], Loss: 0.1920
# Epoch done in  0:02:21.971633
# Epoch  66  started...
# Epoch [66/150], Step [100/396], Loss: 0.0329
# Epoch [66/150], Step [200/396], Loss: 0.0031
# Epoch [66/150], Step [300/396], Loss: 0.0589
# Epoch done in  0:02:23.263958
# Epoch  67  started...
# Epoch [67/150], Step [100/396], Loss: 0.0006
# Epoch [67/150], Step [200/396], Loss: 0.0674
# Epoch [67/150], Step [300/396], Loss: 0.1020
# Epoch done in  0:02:22.521479
# Epoch  68  started...
# Epoch [68/150], Step [100/396], Loss: 0.0436
# Epoch [68/150], Step [200/396], Loss: 0.0184
# Epoch [68/150], Step [300/396], Loss: 0.0347
# Epoch done in  0:02:22.165282
# Epoch  69  started...
# Epoch [69/150], Step [100/396], Loss: 0.0005
# Epoch [69/150], Step [200/396], Loss: 0.0080
# Epoch [69/150], Step [300/396], Loss: 0.0357
# Epoch done in  0:02:21.760769
# Epoch  70  started...
# Epoch [70/150], Step [100/396], Loss: 0.0394
# Epoch [70/150], Step [200/396], Loss: 0.0025
# Epoch [70/150], Step [300/396], Loss: 0.0443
# Epoch done in  0:02:23.268921
# Epoch  71  started...
# Epoch [71/150], Step [100/396], Loss: 0.1036
# Epoch [71/150], Step [200/396], Loss: 0.0007
# Epoch [71/150], Step [300/396], Loss: 0.0603
# Epoch done in  0:02:22.520421
# Epoch  72  started...
# Epoch [72/150], Step [100/396], Loss: 0.0107
# Epoch [72/150], Step [200/396], Loss: 0.0060
# Epoch [72/150], Step [300/396], Loss: 0.0570
# Epoch done in  0:02:22.160911
# Epoch  73  started...
# Epoch [73/150], Step [100/396], Loss: 0.0032
# Epoch [73/150], Step [200/396], Loss: 0.0068
# Epoch [73/150], Step [300/396], Loss: 0.0037
# Epoch done in  0:02:22.771407
# Epoch  74  started...
# Epoch [74/150], Step [100/396], Loss: 0.0017
# Epoch [74/150], Step [200/396], Loss: 0.0011
# Epoch [74/150], Step [300/396], Loss: 0.1239
# Epoch done in  0:02:23.025793
# Epoch  75  started...
# Epoch [75/150], Step [100/396], Loss: 0.0034
# Epoch [75/150], Step [200/396], Loss: 0.0018
# Epoch [75/150], Step [300/396], Loss: 0.0469
# Epoch done in  0:02:24.047540
# Epoch  76  started...
# Epoch [76/150], Step [100/396], Loss: 0.0563
# Epoch [76/150], Step [200/396], Loss: 0.0041
# Epoch [76/150], Step [300/396], Loss: 0.1043
# Epoch done in  0:02:23.286118
# Epoch  77  started...
# Epoch [77/150], Step [100/396], Loss: 0.0052
# Epoch [77/150], Step [200/396], Loss: 0.0166
# Epoch [77/150], Step [300/396], Loss: 0.0010
# Epoch done in  0:02:23.217811
# Epoch  78  started...
# Epoch [78/150], Step [100/396], Loss: 0.0524
# Epoch [78/150], Step [200/396], Loss: 0.0012
# Epoch [78/150], Step [300/396], Loss: 0.1655
# Epoch done in  0:02:23.894084
# Epoch  79  started...
# Epoch [79/150], Step [100/396], Loss: 0.0473
# Epoch [79/150], Step [200/396], Loss: 0.0039
# Epoch [79/150], Step [300/396], Loss: 0.0383
# Epoch done in  0:02:26.485620
# Epoch  80  started...
# Epoch [80/150], Step [100/396], Loss: 0.0510
# Epoch [80/150], Step [200/396], Loss: 0.0027
# Epoch [80/150], Step [300/396], Loss: 0.0072
# Epoch done in  0:02:30.349496
# Epoch  81  started...
# Epoch [81/150], Step [100/396], Loss: 0.0991
# Epoch [81/150], Step [200/396], Loss: 0.0017
# Epoch [81/150], Step [300/396], Loss: 0.0124
# Epoch done in  0:02:30.716435
# Epoch  82  started...
# Epoch [82/150], Step [100/396], Loss: 0.0009
# Epoch [82/150], Step [200/396], Loss: 0.0027
# Epoch [82/150], Step [300/396], Loss: 0.0046
# Epoch done in  0:02:30.462894
# Epoch  83  started...
# Epoch [83/150], Step [100/396], Loss: 0.0184
# Epoch [83/150], Step [200/396], Loss: 0.0013
# Epoch [83/150], Step [300/396], Loss: 0.0007
# Epoch done in  0:02:30.315712
# Epoch  84  started...
# Epoch [84/150], Step [100/396], Loss: 0.1109
# Epoch [84/150], Step [200/396], Loss: 0.0344
# Epoch [84/150], Step [300/396], Loss: 0.1083
# Epoch done in  0:02:31.120288
# Epoch  85  started...
# Epoch [85/150], Step [100/396], Loss: 0.0039
# Epoch [85/150], Step [200/396], Loss: 0.0031
# Epoch [85/150], Step [300/396], Loss: 0.0044
# Epoch done in  0:02:25.728301
# Epoch  86  started...
# Epoch [86/150], Step [100/396], Loss: 0.0529
# Epoch [86/150], Step [200/396], Loss: 0.0079
# Epoch [86/150], Step [300/396], Loss: 0.0460
# Epoch done in  0:02:26.179428
# Epoch  87  started...
# Epoch [87/150], Step [100/396], Loss: 0.0497
# Epoch [87/150], Step [200/396], Loss: 0.0893
# Epoch [87/150], Step [300/396], Loss: 0.0130
# Epoch done in  0:02:24.597195
# Epoch  88  started...
# Epoch [88/150], Step [100/396], Loss: 0.0311
# Epoch [88/150], Step [200/396], Loss: 0.0181
# Epoch [88/150], Step [300/396], Loss: 0.0001
# => Loss reduced by:	 0.00042432546615600586
#    Saving model state
# Epoch done in  0:02:22.733147
# Epoch  89  started...
# Epoch [89/150], Step [100/396], Loss: 0.0914
# Epoch [89/150], Step [200/396], Loss: 0.0012
# Epoch [89/150], Step [300/396], Loss: 0.0009
# Epoch done in  0:02:22.710386
# Epoch  90  started...
# Epoch [90/150], Step [100/396], Loss: 0.0513
# Epoch [90/150], Step [200/396], Loss: 0.0007
# Epoch [90/150], Step [300/396], Loss: 0.0001
# => Loss reduced by:	 2.3543834686279297e-06
#    Saving model state
# Epoch done in  0:02:22.650581
# Epoch  91  started...
# Epoch [91/150], Step [100/396], Loss: 0.0468
# Epoch [91/150], Step [200/396], Loss: 0.1255
# Epoch [91/150], Step [300/396], Loss: 0.0161
# Epoch done in  0:02:22.554230
# Epoch  92  started...
# Epoch [92/150], Step [100/396], Loss: 0.0012
# Epoch [92/150], Step [200/396], Loss: 0.0004
# Epoch [92/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:21.452552
# Epoch  93  started...
# Epoch [93/150], Step [100/396], Loss: 0.0558
# Epoch [93/150], Step [200/396], Loss: 0.0492
# Epoch [93/150], Step [300/396], Loss: 0.0015
# Epoch done in  0:02:21.946799
# Epoch  94  started...
# Epoch [94/150], Step [100/396], Loss: 0.0021
# Epoch [94/150], Step [200/396], Loss: 0.0064
# Epoch [94/150], Step [300/396], Loss: 0.0388
# Epoch done in  0:02:22.332404
# Epoch  95  started...
# Epoch [95/150], Step [100/396], Loss: 0.0100
# Epoch [95/150], Step [200/396], Loss: 0.0005
# Epoch [95/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:22.402834
# Epoch  96  started...
# Epoch [96/150], Step [100/396], Loss: 0.0007
# Epoch [96/150], Step [200/396], Loss: 0.0419
# Epoch [96/150], Step [300/396], Loss: 0.0016
# Epoch done in  0:02:23.144658
# Epoch  97  started...
# Epoch [97/150], Step [100/396], Loss: 0.0003
# Epoch [97/150], Step [200/396], Loss: 0.0595
# Epoch [97/150], Step [300/396], Loss: 0.0393
# Epoch done in  0:02:23.892792
# Epoch  98  started...
# Epoch [98/150], Step [100/396], Loss: 0.0322
# Epoch [98/150], Step [200/396], Loss: 0.0374
# Epoch [98/150], Step [300/396], Loss: 0.0024
# Epoch done in  0:02:21.513304
# Epoch  99  started...
# Epoch [99/150], Step [100/396], Loss: 0.1430
# Epoch [99/150], Step [200/396], Loss: 0.0004
# Epoch [99/150], Step [300/396], Loss: 0.0009
# Epoch done in  0:02:22.136051
# Epoch  100  started...
# Epoch [100/150], Step [100/396], Loss: 0.2084
# Epoch [100/150], Step [200/396], Loss: 0.0006
# Epoch [100/150], Step [300/396], Loss: 0.0009
# Epoch done in  0:02:24.147253
# Epoch  101  started...
# Epoch [101/150], Step [100/396], Loss: 0.0006
# Epoch [101/150], Step [200/396], Loss: 0.0014
# Epoch [101/150], Step [300/396], Loss: 0.0146
# Epoch done in  0:02:22.276714
# Epoch  102  started...
# Epoch [102/150], Step [100/396], Loss: 0.0133
# Epoch [102/150], Step [200/396], Loss: 0.0337
# Epoch [102/150], Step [300/396], Loss: 0.0317
# Epoch done in  0:02:22.927457
# Epoch  103  started...
# Epoch [103/150], Step [100/396], Loss: 0.0041
# Epoch [103/150], Step [200/396], Loss: 0.0004
# Epoch [103/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:22.820927
# Epoch  104  started...
# Epoch [104/150], Step [100/396], Loss: 0.0009
# Epoch [104/150], Step [200/396], Loss: 0.0020
# Epoch [104/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:23.338414
# Epoch  105  started...
# Epoch [105/150], Step [100/396], Loss: 0.0047
# Epoch [105/150], Step [200/396], Loss: 0.0415
# Epoch [105/150], Step [300/396], Loss: 0.0005
# Epoch done in  0:02:23.787152
# Epoch  106  started...
# Epoch [106/150], Step [100/396], Loss: 0.0027
# Epoch [106/150], Step [200/396], Loss: 0.0254
# Epoch [106/150], Step [300/396], Loss: 0.0409
# Epoch done in  0:02:22.159185
# Epoch  107  started...
# Epoch [107/150], Step [100/396], Loss: 0.0915
# Epoch [107/150], Step [200/396], Loss: 0.0137
# Epoch [107/150], Step [300/396], Loss: 0.0022
# Epoch done in  0:02:22.145860
# Epoch  108  started...
# Epoch [108/150], Step [100/396], Loss: 0.0005
# Epoch [108/150], Step [200/396], Loss: 0.0504
# Epoch [108/150], Step [300/396], Loss: 0.0422
# Epoch done in  0:02:22.807334
# Epoch  109  started...
# Epoch [109/150], Step [100/396], Loss: 0.0862
# Epoch [109/150], Step [200/396], Loss: 0.0034
# Epoch [109/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:02:23.023106
# Epoch  110  started...
# Epoch [110/150], Step [100/396], Loss: 0.0488
# Epoch [110/150], Step [200/396], Loss: 0.0065
# Epoch [110/150], Step [300/396], Loss: 0.0449
# Epoch done in  0:02:23.887908
# Epoch  111  started...
# Epoch [111/150], Step [100/396], Loss: 0.0037
# Epoch [111/150], Step [200/396], Loss: 0.0003
# Epoch [111/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:23.627847
# Epoch  112  started...
# Epoch [112/150], Step [100/396], Loss: 0.0460
# Epoch [112/150], Step [200/396], Loss: 0.0703
# Epoch [112/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:24.460032
# Epoch  113  started...
# Epoch [113/150], Step [100/396], Loss: 0.0016
# Epoch [113/150], Step [200/396], Loss: 0.0005
# Epoch [113/150], Step [300/396], Loss: 0.0087
# Epoch done in  0:02:23.381020
# Epoch  114  started...
# Epoch [114/150], Step [100/396], Loss: 0.0421
# Epoch [114/150], Step [200/396], Loss: 0.0487
# Epoch [114/150], Step [300/396], Loss: 0.0380
# Epoch done in  0:02:23.479560
# Epoch  115  started...
# Epoch [115/150], Step [100/396], Loss: 0.0486
# Epoch [115/150], Step [200/396], Loss: 0.0030
# Epoch [115/150], Step [300/396], Loss: 0.0014
# Epoch done in  0:02:23.447463
# Epoch  116  started...
# Epoch [116/150], Step [100/396], Loss: 0.0026
# Epoch [116/150], Step [200/396], Loss: 0.0029
# Epoch [116/150], Step [300/396], Loss: 0.0006
# Epoch done in  0:02:22.461130
# Epoch  117  started...
# Epoch [117/150], Step [100/396], Loss: 0.0004
# Epoch [117/150], Step [200/396], Loss: 0.0329
# Epoch [117/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:22.825880
# Epoch  118  started...
# Epoch [118/150], Step [100/396], Loss: 0.0868
# Epoch [118/150], Step [200/396], Loss: 0.0083
# Epoch [118/150], Step [300/396], Loss: 0.0525
# Epoch done in  0:02:23.771672
# Epoch  119  started...
# Epoch [119/150], Step [100/396], Loss: 0.0560
# Epoch [119/150], Step [200/396], Loss: 0.0459
# Epoch [119/150], Step [300/396], Loss: 0.0011
# Epoch done in  0:02:22.647949
# Epoch  120  started...
# Epoch [120/150], Step [100/396], Loss: 0.0437
# Epoch [120/150], Step [200/396], Loss: 0.0025
# Epoch [120/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:23.391870
# Epoch  121  started...
# Epoch [121/150], Step [100/396], Loss: 0.0009
# Epoch [121/150], Step [200/396], Loss: 0.0005
# Epoch [121/150], Step [300/396], Loss: 0.0261
# Epoch done in  0:02:24.221897
# Epoch  122  started...
# Epoch [122/150], Step [100/396], Loss: 0.0005
# Epoch [122/150], Step [200/396], Loss: 0.0004
# Epoch [122/150], Step [300/396], Loss: 0.0010
# Epoch done in  0:02:23.701445
# Epoch  123  started...
# Epoch [123/150], Step [100/396], Loss: 0.0508
# Epoch [123/150], Step [200/396], Loss: 0.0019
# Epoch [123/150], Step [300/396], Loss: 0.0023
# Epoch done in  0:02:24.022300
# Epoch  124  started...
# Epoch [124/150], Step [100/396], Loss: 0.0450
# Epoch [124/150], Step [200/396], Loss: 0.0007
# Epoch [124/150], Step [300/396], Loss: 0.0646
# Epoch done in  0:02:23.289156
# Epoch  125  started...
# Epoch [125/150], Step [100/396], Loss: 0.0001
# Epoch [125/150], Step [200/396], Loss: 0.0843
# Epoch [125/150], Step [300/396], Loss: 0.0469
# Epoch done in  0:02:24.643200
# Epoch  126  started...
# Epoch [126/150], Step [100/396], Loss: 0.0004
# Epoch [126/150], Step [200/396], Loss: 0.0160
# Epoch [126/150], Step [300/396], Loss: 0.0007
# Epoch done in  0:02:23.686142
# Epoch  127  started...
# Epoch [127/150], Step [100/396], Loss: 0.0001
# => Loss reduced by:	 2.333521842956543e-05
#    Saving model state
# Epoch [127/150], Step [200/396], Loss: 0.0006
# Epoch [127/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:22.434249
# Epoch  128  started...
# Epoch [128/150], Step [100/396], Loss: 0.0019
# Epoch [128/150], Step [200/396], Loss: 0.0972
# Epoch [128/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:21.894536
# Epoch  129  started...
# Epoch [129/150], Step [100/396], Loss: 0.0072
# Epoch [129/150], Step [200/396], Loss: 0.0009
# Epoch [129/150], Step [300/396], Loss: 0.1647
# Epoch done in  0:02:21.602247
# Epoch  130  started...
# Epoch [130/150], Step [100/396], Loss: 0.0002
# Epoch [130/150], Step [200/396], Loss: 0.0851
# Epoch [130/150], Step [300/396], Loss: 0.0387
# Epoch done in  0:02:20.565057
# Epoch  131  started...
# Epoch [131/150], Step [100/396], Loss: 0.0003
# Epoch [131/150], Step [200/396], Loss: 0.0062
# Epoch [131/150], Step [300/396], Loss: 0.0496
# Epoch done in  0:02:22.082743
# Epoch  132  started...
# Epoch [132/150], Step [100/396], Loss: 0.0031
# Epoch [132/150], Step [200/396], Loss: 0.0002
# Epoch [132/150], Step [300/396], Loss: 0.0834
# Epoch done in  0:02:21.217348
# Epoch  133  started...
# Epoch [133/150], Step [100/396], Loss: 0.0065
# Epoch [133/150], Step [200/396], Loss: 0.0251
# Epoch [133/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:21.464758
# Epoch  134  started...
# Epoch [134/150], Step [100/396], Loss: 0.0079
# Epoch [134/150], Step [200/396], Loss: 0.0005
# Epoch [134/150], Step [300/396], Loss: 0.0014
# Epoch done in  0:02:20.842105
# Epoch  135  started...
# Epoch [135/150], Step [100/396], Loss: 0.0013
# Epoch [135/150], Step [200/396], Loss: 0.0343
# Epoch [135/150], Step [300/396], Loss: 0.0795
# Epoch done in  0:02:20.383021
# Epoch  136  started...
# Epoch [136/150], Step [100/396], Loss: 0.0020
# Epoch [136/150], Step [200/396], Loss: 0.1285
# Epoch [136/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:02:21.260798
# Epoch  137  started...
# Epoch [137/150], Step [100/396], Loss: 0.0008
# Epoch [137/150], Step [200/396], Loss: 0.0003
# Epoch [137/150], Step [300/396], Loss: 0.0946
# Epoch done in  0:02:20.500572
# Epoch  138  started...
# Epoch [138/150], Step [100/396], Loss: 0.0802
# Epoch [138/150], Step [200/396], Loss: 0.0001
# Epoch [138/150], Step [300/396], Loss: 0.0381
# Epoch done in  0:02:20.107907
# Epoch  139  started...
# Epoch [139/150], Step [100/396], Loss: 0.0542
# Epoch [139/150], Step [200/396], Loss: 0.0002
# Epoch [139/150], Step [300/396], Loss: 0.0436
# Epoch done in  0:02:20.428603
# Epoch  140  started...
# Epoch [140/150], Step [100/396], Loss: 0.0020
# Epoch [140/150], Step [200/396], Loss: 0.0004
# Epoch [140/150], Step [300/396], Loss: 0.0512
# Epoch done in  0:02:20.357092
# Epoch  141  started...
# Epoch [141/150], Step [100/396], Loss: 0.0001
# => Loss reduced by:	 5.364418029785156e-07
#    Saving model state
# Epoch [141/150], Step [200/396], Loss: 0.0044
# Epoch [141/150], Step [300/396], Loss: 0.0928
# Epoch done in  0:02:20.306017
# Epoch  142  started...
# Epoch [142/150], Step [100/396], Loss: 0.0028
# Epoch [142/150], Step [200/396], Loss: 0.0409
# Epoch [142/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:20.872950
# Epoch  143  started...
# Epoch [143/150], Step [100/396], Loss: 0.0470
# Epoch [143/150], Step [200/396], Loss: 0.0009
# Epoch [143/150], Step [300/396], Loss: 0.1192
# Epoch done in  0:02:20.487209
# Epoch  144  started...
# Epoch [144/150], Step [100/396], Loss: 0.0004
# Epoch [144/150], Step [200/396], Loss: 0.0417
# Epoch [144/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:20.620816
# Epoch  145  started...
# Epoch [145/150], Step [100/396], Loss: 0.0002
# Epoch [145/150], Step [200/396], Loss: 0.0022
# Epoch [145/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:20.424457
# Epoch  146  started...
# Epoch [146/150], Step [100/396], Loss: 0.0017
# Epoch [146/150], Step [200/396], Loss: 0.0001
# Epoch [146/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:20.431715
# Epoch  147  started...
# Epoch [147/150], Step [100/396], Loss: 0.0019
# Epoch [147/150], Step [200/396], Loss: 0.0001
# Epoch [147/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:20.607755
# Epoch  148  started...
# Epoch [148/150], Step [100/396], Loss: 0.0004
# Epoch [148/150], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 7.957220077514648e-06
#    Saving model state
# Epoch [148/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:20.824429
# Epoch  149  started...
# Epoch [149/150], Step [100/396], Loss: 0.0434
# Epoch [149/150], Step [200/396], Loss: 0.0024
# Epoch [149/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:20.499588
# Epoch  150  started...
# Epoch [150/150], Step [100/396], Loss: 0.0006
# Epoch [150/150], Step [200/396], Loss: 0.0006
# Epoch [150/150], Step [300/396], Loss: 0.0508
# Epoch done in  0:02:20.158614
# Training done in  5:59:26.094818

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 93.61567635903918 %

# %%
timestamp_exec_end = time.time()
print("Total execution time: ",str(datetime.timedelta(seconds=(timestamp_exec_end - timestamp_exec_start))))
# Out:
# Total execution time:  6:00:11.033530
