# %%
import pandas as pd
import numpy as np
import time
import datetime
timestamp_exec_start = time.time()

files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")

labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = True

X = []
Y = []
M = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))
    m = f.split("-")
    m = m[-2]
    M.append(m)

data = {"images":X,"labels":Y,"magnification":M }
images_df_t = pd.DataFrame(data, columns = ['images','labels'])
images_df = pd.DataFrame(data, columns = ['images','labels','magnification'])
images_df_40 = images_df.loc[images_df['magnification']=='40'].drop(['magnification'], axis=1)
images_df_100 = images_df.loc[images_df['magnification']=='100'].drop(['magnification'], axis=1)
images_df_200 = images_df.loc[images_df['magnification']=='200'].drop(['magnification'], axis=1)
images_df_400 = images_df.loc[images_df['magnification']=='400'].drop(['magnification'], axis=1)
# Out:
# Processed  7909 files

# %%
# DELETE AFTER APPENDING TO NB ############################################################
batch_size = 16

import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label
    
trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

##############################################################################################

dataset_img40 = MyDataset(df_data=images_df_40, transform=trans_valid)
loader_img40 = DataLoader(dataset = dataset_img40, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img100 = MyDataset(df_data=images_df_100, transform=trans_valid)
loader_img100 = DataLoader(dataset = dataset_img100, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img200 = MyDataset(df_data=images_df_200, transform=trans_valid)
loader_img200 = DataLoader(dataset = dataset_img200, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img400 = MyDataset(df_data=images_df_400, transform=trans_valid)
loader_img400 = DataLoader(dataset = dataset_img400, batch_size=batch_size//2, shuffle=False, num_workers=0)
l_list = [loader_img40,loader_img100,loader_img200,loader_img400]

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset


train, val = train_test_split(images_df_t, stratify=images_df_t.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6327, 1582)

# %%
## Parameters for model

# Hyper parameters
num_epochs = 150
num_classes = 2
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %%
#%%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import os
import glob
import PIL
from PIL import Image
from torch.utils import data as D
from torch.utils.data.sampler import SubsetRandomSampler
import random
#%%
class depthwise_separable_conv(nn.Module):
    def __init__(self, nin, nout, kernel_size, padding, bias=False):
        super(depthwise_separable_conv, self).__init__()
        self.depthwise = nn.Conv2d(nin, nin, kernel_size=kernel_size, padding=padding, groups=nin, bias=bias)
        self.pointwise = nn.Conv2d(nin, nout, kernel_size=1, bias=bias)

    def forward(self, x):
        out = self.depthwise(x)
        out = self.pointwise(out)
        return out
# %%
class Xception(nn.Module):
    def __init__(self, input_channel, num_classes=8):
        super(Xception, self).__init__()
        
        # Entry Flow
        self.entry_flow_1 = nn.Sequential(
            nn.Conv2d(input_channel, 32, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True)
        )
        
        self.entry_flow_2 = nn.Sequential(
            depthwise_separable_conv(64, 128, 3, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            
            depthwise_separable_conv(128, 128, 3, 1),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.entry_flow_2_residual = nn.Conv2d(64, 128, kernel_size=1, stride=2, padding=0)
        
        self.entry_flow_3 = nn.Sequential(
            nn.ReLU(True),
            depthwise_separable_conv(128, 256, 3, 1),
            nn.BatchNorm2d(256),
            
            nn.ReLU(True),
            depthwise_separable_conv(256, 256, 3, 1),
            nn.BatchNorm2d(256),
            
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.entry_flow_3_residual = nn.Conv2d(128, 256, kernel_size=1, stride=2, padding=0)
        
        self.entry_flow_4 = nn.Sequential(
            nn.ReLU(True),
            depthwise_separable_conv(256, 728, 3, 1),
            nn.BatchNorm2d(728),
            
            nn.ReLU(True),
            depthwise_separable_conv(728, 728, 3, 1),
            nn.BatchNorm2d(728),
            
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.entry_flow_4_residual = nn.Conv2d(256, 728, kernel_size=1, stride=2, padding=0)
        
        # Middle Flow
        self.middle_flow = nn.Sequential(
            nn.ReLU(True),
            depthwise_separable_conv(728, 728, 3, 1),
            nn.BatchNorm2d(728),
            
            nn.ReLU(True),
            depthwise_separable_conv(728, 728, 3, 1),
            nn.BatchNorm2d(728),
            
            nn.ReLU(True),
            depthwise_separable_conv(728, 728, 3, 1),
            nn.BatchNorm2d(728)
        )
        
        # Exit Flow
        self.exit_flow_1 = nn.Sequential(
            nn.ReLU(True),
            depthwise_separable_conv(728, 728, 3, 1),
            nn.BatchNorm2d(728),
            
            nn.ReLU(True),
            depthwise_separable_conv(728, 1024, 3, 1),
            nn.BatchNorm2d(1024),
            
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        self.exit_flow_1_residual = nn.Conv2d(728, 1024, kernel_size=1, stride=2, padding=0)
        self.exit_flow_2 = nn.Sequential(
            depthwise_separable_conv(1024, 1536, 3, 1),
            nn.BatchNorm2d(1536),
            nn.ReLU(True),
            
            depthwise_separable_conv(1536, 2048, 3, 1),
            nn.BatchNorm2d(2048),
            nn.ReLU(True)
        )
        
        self.linear = nn.Linear(2048, num_classes)
        
    def forward(self, x):
        entry_out1 = self.entry_flow_1(x)
        entry_out2 = self.entry_flow_2(entry_out1) + self.entry_flow_2_residual(entry_out1)
        entry_out3 = self.entry_flow_3(entry_out2) + self.entry_flow_3_residual(entry_out2)
        entry_out = self.entry_flow_4(entry_out3) + self.entry_flow_4_residual(entry_out3)
        
        middle_out = self.middle_flow(entry_out) + entry_out
        
        for i in range(7):
          middle_out = self.middle_flow(middle_out) + middle_out

        exit_out1 = self.exit_flow_1(middle_out) + self.exit_flow_1_residual(middle_out)
        exit_out2 = self.exit_flow_2(exit_out1)

        exit_avg_pool = F.adaptive_avg_pool2d(exit_out2, (1, 1))                
        exit_avg_pool_flat = exit_avg_pool.view(exit_avg_pool.size(0), -1)

        output = self.linear(exit_avg_pool_flat)
        
        return output

# %%
model = Xception(3, num_classes).to(device)

dummy = torch.ones((16,3,224,224)).cuda()
out = model(dummy)
print(out.shape)
# Out:
# torch.Size([16, 2])

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %%
# Train the model
timestamp_train_start = time.time()

loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/150], Step [100/396], Loss: 0.4370
# => Loss reduced by:	 8.562975019216537
#    Saving model state
# Epoch [1/150], Step [200/396], Loss: 0.3883
# => Loss reduced by:	 0.0487595796585083
#    Saving model state
# Epoch [1/150], Step [300/396], Loss: 0.3900
# Epoch done in  0:02:20.391434
# Epoch  2  started...
# Epoch [2/150], Step [100/396], Loss: 0.5783
# Epoch [2/150], Step [200/396], Loss: 0.4983
# Epoch [2/150], Step [300/396], Loss: 0.2672
# => Loss reduced by:	 0.1211080253124237
#    Saving model state
# Epoch done in  0:01:55.239493
# Epoch  3  started...
# Epoch [3/150], Step [100/396], Loss: 0.2064
# => Loss reduced by:	 0.06073346734046936
#    Saving model state
# Epoch [3/150], Step [200/396], Loss: 0.2166
# Epoch [3/150], Step [300/396], Loss: 0.1641
# => Loss reduced by:	 0.04230055212974548
#    Saving model state
# Epoch done in  0:01:53.903023
# Epoch  4  started...
# Epoch [4/150], Step [100/396], Loss: 0.2657
# Epoch [4/150], Step [200/396], Loss: 0.2849
# Epoch [4/150], Step [300/396], Loss: 0.1779
# Epoch done in  0:01:53.804825
# Epoch  5  started...
# Epoch [5/150], Step [100/396], Loss: 0.1728
# Epoch [5/150], Step [200/396], Loss: 0.1563
# => Loss reduced by:	 0.007781535387039185
#    Saving model state
# Epoch [5/150], Step [300/396], Loss: 0.1812
# Epoch done in  0:01:52.570529
# Epoch  6  started...
# Epoch [6/150], Step [100/396], Loss: 0.3087
# Epoch [6/150], Step [200/396], Loss: 0.1641
# Epoch [6/150], Step [300/396], Loss: 0.3102
# Epoch done in  0:01:51.785438
# Epoch  7  started...
# Epoch [7/150], Step [100/396], Loss: 0.1791
# Epoch [7/150], Step [200/396], Loss: 0.2746
# Epoch [7/150], Step [300/396], Loss: 0.0598
# => Loss reduced by:	 0.09651253372430801
#    Saving model state
# Epoch done in  0:01:51.685033
# Epoch  8  started...
# Epoch [8/150], Step [100/396], Loss: 0.2478
# Epoch [8/150], Step [200/396], Loss: 0.1231
# Epoch [8/150], Step [300/396], Loss: 0.2233
# Epoch done in  0:01:51.531582
# Epoch  9  started...
# Epoch [9/150], Step [100/396], Loss: 0.1385
# Epoch [9/150], Step [200/396], Loss: 0.1799
# Epoch [9/150], Step [300/396], Loss: 0.1675
# Epoch done in  0:01:51.389125
# Epoch  10  started...
# Epoch [10/150], Step [100/396], Loss: 0.1245
# Epoch [10/150], Step [200/396], Loss: 0.3690
# Epoch [10/150], Step [300/396], Loss: 0.2565
# Epoch done in  0:01:51.836035
# Epoch  11  started...
# Epoch [11/150], Step [100/396], Loss: 0.2003
# Epoch [11/150], Step [200/396], Loss: 0.3291
# Epoch [11/150], Step [300/396], Loss: 0.0848
# Epoch done in  0:01:51.742517
# Epoch  12  started...
# Epoch [12/150], Step [100/396], Loss: 0.2922
# Epoch [12/150], Step [200/396], Loss: 0.2319
# Epoch [12/150], Step [300/396], Loss: 0.5445
# Epoch done in  0:01:51.794093
# Epoch  13  started...
# Epoch [13/150], Step [100/396], Loss: 0.0848
# Epoch [13/150], Step [200/396], Loss: 0.0827
# Epoch [13/150], Step [300/396], Loss: 0.1754
# Epoch done in  0:01:51.916761
# Epoch  14  started...
# Epoch [14/150], Step [100/396], Loss: 0.1249
# Epoch [14/150], Step [200/396], Loss: 0.0739
# Epoch [14/150], Step [300/396], Loss: 0.2611
# Epoch done in  0:02:01.315722
# Epoch  15  started...
# Epoch [15/150], Step [100/396], Loss: 0.1522
# Epoch [15/150], Step [200/396], Loss: 0.0830
# Epoch [15/150], Step [300/396], Loss: 0.0738
# Epoch done in  0:01:51.427906
# Epoch  16  started...
# Epoch [16/150], Step [100/396], Loss: 0.0365
# => Loss reduced by:	 0.023342199623584747
#    Saving model state
# Epoch [16/150], Step [200/396], Loss: 0.0625
# Epoch [16/150], Step [300/396], Loss: 0.2010
# Epoch done in  0:01:51.541764
# Epoch  17  started...
# Epoch [17/150], Step [100/396], Loss: 0.0729
# Epoch [17/150], Step [200/396], Loss: 0.1290
# Epoch [17/150], Step [300/396], Loss: 0.0811
# Epoch done in  0:01:50.732651
# Epoch  18  started...
# Epoch [18/150], Step [100/396], Loss: 0.0684
# Epoch [18/150], Step [200/396], Loss: 0.1546
# Epoch [18/150], Step [300/396], Loss: 0.0722
# Epoch done in  0:01:50.796031
# Epoch  19  started...
# Epoch [19/150], Step [100/396], Loss: 0.0148
# => Loss reduced by:	 0.02168547362089157
#    Saving model state
# Epoch [19/150], Step [200/396], Loss: 0.3381
# Epoch [19/150], Step [300/396], Loss: 0.4133
# Epoch done in  0:01:51.135631
# Epoch  20  started...
# Epoch [20/150], Step [100/396], Loss: 0.0383
# Epoch [20/150], Step [200/396], Loss: 0.2085
# Epoch [20/150], Step [300/396], Loss: 0.2056
# Epoch done in  0:01:50.578296
# Epoch  21  started...
# Epoch [21/150], Step [100/396], Loss: 0.1117
# Epoch [21/150], Step [200/396], Loss: 0.0885
# Epoch [21/150], Step [300/396], Loss: 0.0676
# Epoch done in  0:01:51.334847
# Epoch  22  started...
# Epoch [22/150], Step [100/396], Loss: 0.0628
# Epoch [22/150], Step [200/396], Loss: 0.3095
# Epoch [22/150], Step [300/396], Loss: 0.0356
# Epoch done in  0:01:51.091046
# Epoch  23  started...
# Epoch [23/150], Step [100/396], Loss: 0.0096
# => Loss reduced by:	 0.005195967853069305
#    Saving model state
# Epoch [23/150], Step [200/396], Loss: 0.0263
# Epoch [23/150], Step [300/396], Loss: 0.1648
# Epoch done in  0:01:51.039607
# Epoch  24  started...
# Epoch [24/150], Step [100/396], Loss: 0.1930
# Epoch [24/150], Step [200/396], Loss: 0.0310
# Epoch [24/150], Step [300/396], Loss: 0.2165
# Epoch done in  0:01:51.147366
# Epoch  25  started...
# Epoch [25/150], Step [100/396], Loss: 0.0436
# Epoch [25/150], Step [200/396], Loss: 0.1049
# Epoch [25/150], Step [300/396], Loss: 0.1457
# Epoch done in  0:01:50.725686
# Epoch  26  started...
# Epoch [26/150], Step [100/396], Loss: 0.1149
# Epoch [26/150], Step [200/396], Loss: 0.0967
# Epoch [26/150], Step [300/396], Loss: 0.0725
# Epoch done in  0:01:51.429645
# Epoch  27  started...
# Epoch [27/150], Step [100/396], Loss: 0.0546
# Epoch [27/150], Step [200/396], Loss: 0.1707
# Epoch done in  0:01:51.747773
# Epoch  41  started...
# Epoch [41/150], Step [100/396], Loss: 0.0387
# Epoch [41/150], Step [200/396], Loss: 0.0747
# Epoch [41/150], Step [300/396], Loss: 0.0059
# Epoch done in  0:01:51.255450
# Epoch  42  started...
# Epoch [42/150], Step [100/396], Loss: 0.0062
# Epoch [42/150], Step [200/396], Loss: 0.0482
# Epoch [42/150], Step [300/396], Loss: 0.0246
# Epoch done in  0:01:50.941666
# Epoch  43  started...
# Epoch [43/150], Step [100/396], Loss: 0.0525
# Epoch [43/150], Step [200/396], Loss: 0.0067
# Epoch [43/150], Step [300/396], Loss: 0.1024
# Epoch done in  0:01:51.473389
# Epoch  44  started...
# Epoch [44/150], Step [100/396], Loss: 0.0004
# => Loss reduced by:	 0.0038242414593696594
#    Saving model state
# Epoch [44/150], Step [200/396], Loss: 0.0233
# Epoch [44/150], Step [300/396], Loss: 0.0079
# Epoch done in  0:01:51.013079
# Epoch  45  started...
# Epoch [45/150], Step [100/396], Loss: 0.0315
# Epoch [45/150], Step [200/396], Loss: 0.3533
# Epoch [45/150], Step [300/396], Loss: 0.0336
# Epoch done in  0:01:51.070265
# Epoch  46  started...
# Epoch [46/150], Step [100/396], Loss: 0.0057
# Epoch [46/150], Step [200/396], Loss: 0.1650
# Epoch [46/150], Step [300/396], Loss: 0.1855
# Epoch done in  0:01:50.776539
# Epoch  47  started...
# Epoch [47/150], Step [100/396], Loss: 0.0129
# Epoch [47/150], Step [200/396], Loss: 0.0274
# Epoch [47/150], Step [300/396], Loss: 0.0064
# Epoch done in  0:01:50.858150
# Epoch  48  started...
# Epoch [48/150], Step [100/396], Loss: 0.0185
# Epoch [48/150], Step [200/396], Loss: 0.1967
# Epoch [48/150], Step [300/396], Loss: 0.1144
# Epoch done in  0:01:51.270973
# Epoch  49  started...
# Epoch [49/150], Step [100/396], Loss: 0.0148
# Epoch [49/150], Step [200/396], Loss: 0.0258
# Epoch [49/150], Step [300/396], Loss: 0.0264
# Epoch done in  0:01:51.900810
# Epoch  50  started...
# Epoch [50/150], Step [100/396], Loss: 0.0355
# Epoch [50/150], Step [200/396], Loss: 0.0160
# Epoch [50/150], Step [300/396], Loss: 0.0022
# Epoch done in  0:01:51.530753
# Epoch  51  started...
# Epoch [51/150], Step [100/396], Loss: 0.2330
# Epoch [51/150], Step [200/396], Loss: 0.0061
# Epoch [51/150], Step [300/396], Loss: 0.0208
# Epoch done in  0:01:51.995719
# Epoch  52  started...
# Epoch [52/150], Step [100/396], Loss: 0.0293
# Epoch [52/150], Step [200/396], Loss: 0.0171
# Epoch [52/150], Step [300/396], Loss: 0.0149
# Epoch done in  0:01:51.328586
# Epoch  53  started...
# Epoch [53/150], Step [100/396], Loss: 0.0119
# Epoch [53/150], Step [200/396], Loss: 0.0515
# Epoch [53/150], Step [300/396], Loss: 0.0170
# Epoch done in  0:01:51.267706
# Epoch  54  started...
# Epoch [54/150], Step [100/396], Loss: 0.0073
# Epoch done in  0:01:51.546189
# Epoch  82  started...
# Epoch [82/150], Step [100/396], Loss: 0.0008
# Epoch [82/150], Step [200/396], Loss: 0.0001
# => Loss reduced by:	 7.316470146179199e-06
#    Saving model state
# Epoch [82/150], Step [300/396], Loss: 0.1106
# Epoch done in  0:01:51.811399
# Epoch  83  started...
# Epoch [83/150], Step [100/396], Loss: 0.0009
# Epoch [83/150], Step [200/396], Loss: 0.0006
# Epoch [83/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:01:51.256138
# Epoch  84  started...
# Epoch [84/150], Step [100/396], Loss: 0.0073
# Epoch [84/150], Step [200/396], Loss: 0.0016
# Epoch [84/150], Step [300/396], Loss: 0.0005
# Epoch done in  0:01:51.549570
# Epoch  85  started...
# Epoch [85/150], Step [100/396], Loss: 0.1672
# Epoch [85/150], Step [200/396], Loss: 0.0027
# Epoch [85/150], Step [300/396], Loss: 0.0320
# Epoch done in  0:01:51.676565
# Epoch  86  started...
# Epoch [86/150], Step [100/396], Loss: 0.0075
# Epoch [86/150], Step [200/396], Loss: 0.0003
# Epoch [86/150], Step [300/396], Loss: 0.1882
# Epoch done in  0:01:51.505595
# Epoch  87  started...
# Epoch [87/150], Step [100/396], Loss: 0.0070
# Epoch [87/150], Step [200/396], Loss: 0.0023
# Epoch [87/150], Step [300/396], Loss: 0.0001
# => Loss reduced by:	 6.015598773956299e-05
#    Saving model state
# Epoch done in  0:01:51.749884
# Epoch  88  started...
# Epoch [88/150], Step [100/396], Loss: 0.0064
# Epoch [88/150], Step [200/396], Loss: 0.0158
# Epoch [88/150], Step [300/396], Loss: 0.0207
# Epoch done in  0:01:51.334975
# Epoch  89  started...
# Epoch [89/150], Step [100/396], Loss: 0.0002
# Epoch [89/150], Step [200/396], Loss: 0.0005
# Epoch [89/150], Step [300/396], Loss: 0.0091
# Epoch done in  0:01:50.873280
# Epoch  90  started...
# Epoch [90/150], Step [100/396], Loss: 0.2102
# Epoch [90/150], Step [200/396], Loss: 0.0029
# Epoch [90/150], Step [300/396], Loss: 0.0231
# Epoch done in  0:01:51.325071
# Epoch  91  started...
# Epoch [91/150], Step [100/396], Loss: 0.0508
# Epoch [91/150], Step [200/396], Loss: 0.0010
# Epoch [91/150], Step [300/396], Loss: 0.0484
# Epoch done in  0:01:51.596762
# Epoch  92  started...
# Epoch [92/150], Step [100/396], Loss: 0.0020
# Epoch [92/150], Step [200/396], Loss: 0.0004
# Epoch [92/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:52.309921
# Epoch  93  started...
# Epoch [93/150], Step [100/396], Loss: 0.0012
# Epoch [93/150], Step [200/396], Loss: 0.0764
# Epoch [93/150], Step [300/396], Loss: 0.0257
# Epoch done in  0:01:51.673625
# Epoch  94  started...
# Epoch [94/150], Step [100/396], Loss: 0.0008
# Epoch [94/150], Step [200/396], Loss: 0.0044
# Epoch [94/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:51.249687
# Epoch  95  started...
# Epoch [95/150], Step [100/396], Loss: 0.0217
# Epoch [95/150], Step [200/396], Loss: 0.0302
# Epoch [95/150], Step [300/396], Loss: 0.0071
# Epoch done in  0:01:51.589355
# Epoch  96  started...
# Epoch [96/150], Step [100/396], Loss: 0.0000
# => Loss reduced by:	 1.5810132026672363e-05
#    Saving model state
# Epoch [96/150], Step [200/396], Loss: 0.0275
# Epoch [96/150], Step [300/396], Loss: 0.0374
# Epoch done in  0:01:52.054794
# Epoch  97  started...
# Epoch [97/150], Step [100/396], Loss: 0.3116
# Epoch [97/150], Step [200/396], Loss: 0.0051
# Epoch [97/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:51.232038
# Epoch  98  started...
# Epoch [98/150], Step [100/396], Loss: 0.0002
# Epoch [98/150], Step [200/396], Loss: 0.0122
# Epoch [98/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:52.056587
# Epoch  99  started...
# Epoch [99/150], Step [100/396], Loss: 0.0010
# Epoch [99/150], Step [200/396], Loss: 0.0231
# Epoch [99/150], Step [300/396], Loss: 0.0039
# Epoch done in  0:01:52.130150
# Epoch  100  started...
# Epoch [100/150], Step [100/396], Loss: 0.0050
# Epoch [100/150], Step [200/396], Loss: 0.0007
# Epoch [100/150], Step [300/396], Loss: 0.0092
# Epoch done in  0:01:51.882651
# Epoch  101  started...
# Epoch [101/150], Step [100/396], Loss: 0.0057
# Epoch [101/150], Step [200/396], Loss: 0.0106
# Epoch [101/150], Step [300/396], Loss: 0.0007
# Epoch done in  0:01:51.796413
# Epoch  102  started...
# Epoch [102/150], Step [100/396], Loss: 0.0002
# Epoch [102/150], Step [200/396], Loss: 0.0007
# Epoch [102/150], Step [300/396], Loss: 0.0191
# Epoch done in  0:01:51.127990
# Epoch  103  started...
# Epoch [103/150], Step [100/396], Loss: 0.0002
# Epoch [103/150], Step [200/396], Loss: 0.0019
# Epoch [103/150], Step [300/396], Loss: 0.0068
# Epoch done in  0:01:51.188656
# Epoch  104  started...
# Epoch [104/150], Step [100/396], Loss: 0.0015
# Epoch [104/150], Step [200/396], Loss: 0.0003
# Epoch [104/150], Step [300/396], Loss: 0.0015
# Epoch done in  0:01:50.749563
# Epoch  105  started...
# Epoch [105/150], Step [100/396], Loss: 0.0342
# Epoch [105/150], Step [200/396], Loss: 0.0021
# Epoch [105/150], Step [300/396], Loss: 0.0047
# Epoch done in  0:01:50.938801
# Epoch  106  started...
# Epoch [106/150], Step [100/396], Loss: 0.0005
# Epoch [106/150], Step [200/396], Loss: 0.3496
# Epoch [106/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:01:51.062118
# Epoch  107  started...
# Epoch [107/150], Step [100/396], Loss: 0.0505
# Epoch [107/150], Step [200/396], Loss: 0.0015
# Epoch [107/150], Step [300/396], Loss: 0.0062
# Epoch done in  0:01:51.365252
# Epoch  108  started...
# Epoch [108/150], Step [100/396], Loss: 0.0006
# Epoch [108/150], Step [200/396], Loss: 0.0348
# Epoch [108/150], Step [300/396], Loss: 0.0073
# Epoch done in  0:01:50.834614
# Epoch  109  started...
# Epoch [109/150], Step [100/396], Loss: 0.0005
# Epoch [109/150], Step [200/396], Loss: 0.0014
# Epoch [109/150], Step [300/396], Loss: 0.0033
# Epoch done in  0:01:51.035559
# Epoch  110  started...
# Epoch [110/150], Step [100/396], Loss: 0.0011
# Epoch [110/150], Step [200/396], Loss: 0.0000
# Epoch [110/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:01:50.910319
# Epoch  111  started...
# Epoch [111/150], Step [100/396], Loss: 0.0333
# Epoch [111/150], Step [200/396], Loss: 0.0002
# Epoch [111/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:50.672342
# Epoch  112  started...
# Epoch [112/150], Step [100/396], Loss: 0.0028
# Epoch [112/150], Step [200/396], Loss: 0.0004
# Epoch [112/150], Step [300/396], Loss: 0.0191
# Epoch done in  0:01:50.756165
# Epoch  113  started...
# Epoch [113/150], Step [100/396], Loss: 0.0007
# Epoch [113/150], Step [200/396], Loss: 0.0015
# Epoch [113/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:50.796864
# Epoch  114  started...
# Epoch [114/150], Step [100/396], Loss: 0.0031
# Epoch [114/150], Step [200/396], Loss: 0.0057
# Epoch [114/150], Step [300/396], Loss: 0.0487
# Epoch done in  0:01:52.434951
# Epoch  115  started...
# Epoch [115/150], Step [100/396], Loss: 0.1652
# Epoch [115/150], Step [200/396], Loss: 0.1751
# Epoch [115/150], Step [300/396], Loss: 0.0672
# Epoch done in  0:01:50.751093
# Epoch  116  started...
# Epoch [116/150], Step [100/396], Loss: 0.0005
# Epoch [116/150], Step [200/396], Loss: 0.4890
# Epoch [116/150], Step [300/396], Loss: 0.0032
# Epoch done in  0:01:50.583478
# Epoch  117  started...
# Epoch [117/150], Step [100/396], Loss: 0.0019
# Epoch [117/150], Step [200/396], Loss: 0.0001
# Epoch [117/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:01:50.216727
# Epoch  118  started...
# Epoch [118/150], Step [100/396], Loss: 0.0271
# Epoch [118/150], Step [200/396], Loss: 0.0015
# Epoch [118/150], Step [300/396], Loss: 0.0007
# Epoch done in  0:01:50.774607
# Epoch  119  started...
# Epoch [119/150], Step [100/396], Loss: 0.0009
# Epoch [119/150], Step [200/396], Loss: 0.0002
# Epoch [119/150], Step [300/396], Loss: 0.0016
# Epoch done in  0:01:50.584215
# Epoch  120  started...
# Epoch [120/150], Step [100/396], Loss: 0.0057
# Epoch [120/150], Step [200/396], Loss: 0.0114
# Epoch [120/150], Step [300/396], Loss: 0.0005
# Epoch done in  0:01:50.765574
# Epoch  121  started...
# Epoch [121/150], Step [100/396], Loss: 0.0120
# Epoch [121/150], Step [200/396], Loss: 0.0010
# Epoch [121/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:51.343545
# Epoch  122  started...
# Epoch [122/150], Step [100/396], Loss: 0.0008
# Epoch [122/150], Step [200/396], Loss: 0.0037
# Epoch [122/150], Step [300/396], Loss: 0.0253
# Epoch done in  0:01:51.001070
# Epoch  123  started...
# Epoch [123/150], Step [100/396], Loss: 0.0376
# Epoch [123/150], Step [200/396], Loss: 0.0100
# Epoch [123/150], Step [300/396], Loss: 0.0040
# Epoch done in  0:01:50.802588
# Epoch  124  started...
# Epoch [124/150], Step [100/396], Loss: 0.0009
# Epoch [124/150], Step [200/396], Loss: 0.0034
# Epoch [124/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:01:50.990679
# Epoch  125  started...
# Epoch [125/150], Step [100/396], Loss: 0.0001
# Epoch [125/150], Step [200/396], Loss: 0.0009
# Epoch [125/150], Step [300/396], Loss: 0.0305
# Epoch done in  0:01:50.846719
# Epoch  126  started...
# Epoch [126/150], Step [100/396], Loss: 0.0015
# Epoch [126/150], Step [200/396], Loss: 0.0001
# Epoch [126/150], Step [300/396], Loss: 0.0050
# Epoch done in  0:01:51.061684
# Epoch  127  started...
# Epoch [127/150], Step [100/396], Loss: 0.0263
# Epoch [127/150], Step [200/396], Loss: 0.0006
# Epoch [127/150], Step [300/396], Loss: 0.0005
# Epoch done in  0:01:51.301402
# Epoch  128  started...
# Epoch [128/150], Step [100/396], Loss: 0.0102
# Epoch [128/150], Step [200/396], Loss: 0.0006
# Epoch [128/150], Step [300/396], Loss: 0.0000
# Epoch done in  0:01:50.894502
# Epoch  129  started...
# Epoch [129/150], Step [100/396], Loss: 0.0001
# Epoch [129/150], Step [200/396], Loss: 0.0008
# Epoch [129/150], Step [300/396], Loss: 0.0004
# Epoch done in  0:01:51.279585
# Epoch  130  started...
# Epoch [130/150], Step [100/396], Loss: 0.0004
# Epoch [130/150], Step [200/396], Loss: 0.0001
# Epoch [130/150], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 2.5600194931030273e-05
#    Saving model state
# Epoch done in  0:01:51.372012
# Epoch  131  started...
# Epoch [131/150], Step [100/396], Loss: 0.0001
# Epoch [131/150], Step [200/396], Loss: 0.0001
# Epoch [131/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:01:51.297960
# Epoch  132  started...
# Epoch [132/150], Step [100/396], Loss: 0.0001
# Epoch [132/150], Step [200/396], Loss: 0.0121
# Epoch [132/150], Step [300/396], Loss: 0.0032
# Epoch done in  0:01:51.694958
# Epoch  133  started...
# Epoch [133/150], Step [100/396], Loss: 0.0565
# Epoch [133/150], Step [200/396], Loss: 0.1075
# Epoch [133/150], Step [300/396], Loss: 0.0063
# Epoch done in  0:01:51.966890
# Epoch  134  started...
# Epoch [134/150], Step [100/396], Loss: 0.0010
# Epoch [134/150], Step [200/396], Loss: 0.3657
# Epoch [134/150], Step [300/396], Loss: 0.0008
# Epoch done in  0:01:51.764053
# Epoch  135  started...
# Epoch [135/150], Step [100/396], Loss: 0.0028
# Epoch [135/150], Step [200/396], Loss: 0.0024
# Epoch [135/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:51.216926
# Epoch  136  started...
# Epoch [136/150], Step [100/396], Loss: 0.0002
# Epoch [136/150], Step [200/396], Loss: 0.0001
# Epoch [136/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:50.933150
# Epoch  137  started...
# Epoch [137/150], Step [100/396], Loss: 0.0002
# Epoch [137/150], Step [200/396], Loss: 0.0003
# Epoch [137/150], Step [300/396], Loss: 0.0000
# Epoch done in  0:01:50.554769
# Epoch  138  started...
# Epoch [138/150], Step [100/396], Loss: 0.0002
# Epoch [138/150], Step [200/396], Loss: 0.0004
# Epoch [138/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:51.077133
# Epoch  139  started...
# Epoch [139/150], Step [100/396], Loss: 0.0149
# Epoch [139/150], Step [200/396], Loss: 0.0008
# Epoch [139/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:50.964877
# Epoch  140  started...
# Epoch [140/150], Step [100/396], Loss: 0.0002
# Epoch [140/150], Step [200/396], Loss: 0.0012
# Epoch [140/150], Step [300/396], Loss: 0.0073
# Epoch done in  0:01:51.670360
# Epoch  141  started...
# Epoch [141/150], Step [100/396], Loss: 0.0000
# Epoch [141/150], Step [200/396], Loss: 0.0000
# Epoch [141/150], Step [300/396], Loss: 0.0090
# Epoch done in  0:01:52.010397
# Epoch  142  started...
# Epoch [142/150], Step [100/396], Loss: 0.0070
# Epoch [142/150], Step [200/396], Loss: 0.0001
# Epoch [142/150], Step [300/396], Loss: 0.0004
# Epoch done in  0:01:51.593330
# Epoch  143  started...
# Epoch [143/150], Step [100/396], Loss: 0.0065
# Epoch [143/150], Step [200/396], Loss: 0.0002
# Epoch [143/150], Step [300/396], Loss: 0.0006
# Epoch done in  0:01:51.641951
# Epoch  144  started...
# Epoch [144/150], Step [100/396], Loss: 0.0012
# Epoch [144/150], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 3.904104232788086e-06
#    Saving model state
# Epoch [144/150], Step [300/396], Loss: 0.0007
# Epoch done in  0:01:53.160420
# Epoch  145  started...
# Epoch [145/150], Step [100/396], Loss: 0.0000
# Epoch [145/150], Step [200/396], Loss: 0.0005
# Epoch [145/150], Step [300/396], Loss: 0.0029
# Epoch done in  0:01:51.036163
# Epoch  146  started...
# Epoch [146/150], Step [100/396], Loss: 0.0001
# Epoch [146/150], Step [200/396], Loss: 0.0193
# Epoch [146/150], Step [300/396], Loss: 0.0001
# Epoch done in  0:01:51.506529
# Epoch  147  started...
# Epoch [147/150], Step [100/396], Loss: 0.0048
# Epoch [147/150], Step [200/396], Loss: 0.0004
# Epoch [147/150], Step [300/396], Loss: 0.0003
# Epoch done in  0:01:51.109850
# Epoch  148  started...
# Epoch [148/150], Step [100/396], Loss: 0.0002
# Epoch [148/150], Step [200/396], Loss: 0.0001
# Epoch [148/150], Step [300/396], Loss: 0.0021
# Epoch done in  0:01:50.766232
# Epoch  149  started...
# Epoch [149/150], Step [100/396], Loss: 0.0001
# Epoch [149/150], Step [200/396], Loss: 0.0002
# Epoch [149/150], Step [300/396], Loss: 0.0002
# Epoch done in  0:01:51.511784
# Epoch  150  started...
# Epoch [150/150], Step [100/396], Loss: 0.0003
# Epoch [150/150], Step [200/396], Loss: 0.1346
# Epoch [150/150], Step [300/396], Loss: 0.0036
# Epoch done in  0:01:51.154090
# Training done in  4:39:31.804858

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 91.08723135271808 %

# %%
model.load_state_dict(torch.load('final_state.dct'))
model.eval()
count = 0
for l in l_list:
    count+=1
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in l:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _,predicted = torch.max(outputs.data,1)
            total+=labels.size(0)
            correct+= (predicted==labels).sum().item()
        print('Test Accuracy of model on {} is {} %'.format(count,100*(correct/total)))
# Out:
# Test Accuracy of model on 1 is 91.62907268170426 %
# Test Accuracy of model on 2 is 92.93608841902932 %
# Test Accuracy of model on 3 is 94.5851962245405 %
# Test Accuracy of model on 4 is 92.52747252747253 %
