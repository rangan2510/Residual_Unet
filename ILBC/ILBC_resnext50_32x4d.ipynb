# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
        # print(os.path.join(dirname, filename))

import time
import datetime
timestamp_exec_start = time.time()


files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")


labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = True

X = []
Y = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))

data = {"images":X,"labels":Y}
images_df = pd.DataFrame(data, columns = ['images','labels'])
images_df.groupby("labels")["labels"].count()
# Out:
# Processed  7909 files
# labels
# 0    2480
# 1    5429
# Name: labels, dtype: int64

# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset

# %%
train, val = train_test_split(images_df, stratify=images_df.labels, test_size=0.2)
len(train), len(val)
# Out:
# (6327, 1582)

# %%
class MyDataset(Dataset):
    def __init__(self, df_data,transform=None):
        super().__init__()
        self.df = df_data.values
        
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_path,label = self.df[index]
        
        image = cv2.imread(img_path)
        image = cv2.resize(image, (224,224))
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
## Parameters for model

# Hyper parameters
num_epochs = 75
num_classes = 2
batch_size = 16
learning_rate = 0.0002

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Utility function for saving model
# During training, the loss values are stored in a list.
# We check the last two values to see if the loss has reduced.
def save_checkpoint(state, loss):
    global best_loss
    """Save checkpoint if a new best is achieved"""
    if best_loss>=loss:        
        print ("=> Loss reduced by:\t",best_loss - loss)
        print("   Saving model state")
        torch.save(state, "state_dict.dct")  # save checkpoint
        best_loss = loss

# %%
trans_train = transforms.Compose([transforms.ToPILImage(),
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.RandomHorizontalFlip(), 
                                  transforms.RandomVerticalFlip(),
                                  transforms.RandomRotation(20), 
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

trans_valid = transforms.Compose([transforms.ToPILImage(),                    
                                  transforms.Pad(64, padding_mode='reflect'),
                                  transforms.Resize(224, interpolation = 2),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])])

dataset_train = MyDataset(df_data=train, transform=trans_train)
dataset_valid = MyDataset(df_data=val,transform=trans_valid)

loader_train = DataLoader(dataset = dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
loader_valid = DataLoader(dataset = dataset_valid, batch_size=batch_size//2, shuffle=False, num_workers=0)

# %% [markdown]
# Now, we create the model and train it.

# %%
import torch.nn as nn
from torchvision import models


model =  models.resnext50_32x4d(pretrained=True)
model.fc = nn.Linear(in_features=2048, out_features=num_classes, bias=True)
model = model.to(device)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/checkpoints/resnext50_32x4d-7cdf4587.pth
# HBox(children=(FloatProgress(value=0.0, max=100441675.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %% [markdown]
# import os
# import urllib.request
# url = "https://onedrive.live.com/download?cid=E5569BBAB912B6A5&resid=E5569BBAB912B6A5%21532997&authkey=AIIbJpY85FBd61c"
# file_name = "download.dct"
# print("Downloading pre-trained model state...")
# urllib.request.urlretrieve(url, file_name)
# print("Done!")
# model.load_state_dict(torch.load(file_name))
# import os.path
# if os.path.exists(file_name):
#     try:
#         model.load_state_dict(torch.load(file_name))
#         print("Downloaded model state loaded successfully.")
#     except:
#         print("Error loading state dict.")

# %%
# Train the model
timestamp_train_start = time.time()

loss_hist = []
best_loss = 9
total_step = len(loader_train)

for epoch in range(num_epochs):
    timestamp_epoch_start = time.time()
    print("Epoch ", epoch+1," started...")
    for i, (images, labels) in enumerate(loader_train):
        images = images.to(device)
        labels = labels.to(device)
                
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
       
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))    
             # Checkpointing
            loss_hist.append(float(loss.item())) #add current loss value.
            save_checkpoint(model.state_dict(),float(loss.item()))
                    
    timestamp_epoch_end = time.time()
    print("Epoch done in ",str(datetime.timedelta(seconds=(timestamp_epoch_end - timestamp_epoch_start))))
    
timestamp_train_end = time.time()
print("Training done in ",str(datetime.timedelta(seconds=(timestamp_train_end - timestamp_train_start))))
# Out:
# Epoch  1  started...
# Epoch [1/75], Step [100/396], Loss: 0.2554
# => Loss reduced by:	 8.744550883769989
#    Saving model state
# Epoch [1/75], Step [200/396], Loss: 0.0943
# => Loss reduced by:	 0.16111064702272415
#    Saving model state
# Epoch [1/75], Step [300/396], Loss: 0.0256
# => Loss reduced by:	 0.0687185563147068
#    Saving model state
# Epoch done in  0:03:35.089168
# Epoch  2  started...
# Epoch [2/75], Step [100/396], Loss: 0.0106
# => Loss reduced by:	 0.01504407450556755
#    Saving model state
# Epoch [2/75], Step [200/396], Loss: 0.1545
# Epoch [2/75], Step [300/396], Loss: 0.0290
# Epoch done in  0:02:59.108606
# Epoch  3  started...
# Epoch [3/75], Step [100/396], Loss: 0.0052
# => Loss reduced by:	 0.005376093089580536
#    Saving model state
# Epoch [3/75], Step [200/396], Loss: 0.0349
# Epoch [3/75], Step [300/396], Loss: 0.0162
# Epoch done in  0:02:58.963768
# Epoch  4  started...
# Epoch [4/75], Step [100/396], Loss: 0.0753
# Epoch [4/75], Step [200/396], Loss: 0.1634
# Epoch [4/75], Step [300/396], Loss: 0.0186
# Epoch done in  0:02:58.193718
# Epoch  5  started...
# Epoch [5/75], Step [100/396], Loss: 0.0340
# Epoch [5/75], Step [200/396], Loss: 0.1625
# Epoch [5/75], Step [300/396], Loss: 0.0039
# => Loss reduced by:	 0.001328594982624054
#    Saving model state
# Epoch done in  0:02:56.981097
# Epoch  6  started...
# Epoch [6/75], Step [100/396], Loss: 0.0367
# Epoch [6/75], Step [200/396], Loss: 0.0073
# Epoch [6/75], Step [300/396], Loss: 0.0059
# Epoch done in  0:02:59.032375
# Epoch  7  started...
# Epoch [7/75], Step [100/396], Loss: 0.0655
# Epoch [7/75], Step [200/396], Loss: 0.0967
# Epoch [7/75], Step [300/396], Loss: 0.0256
# Epoch done in  0:02:56.474264
# Epoch  8  started...
# Epoch [8/75], Step [100/396], Loss: 0.0083
# Epoch [8/75], Step [200/396], Loss: 0.0006
# => Loss reduced by:	 0.0033011063933372498
#    Saving model state
# Epoch [8/75], Step [300/396], Loss: 0.0324
# Epoch done in  0:02:57.449119
# Epoch  9  started...
# Epoch [9/75], Step [100/396], Loss: 0.0288
# Epoch [9/75], Step [200/396], Loss: 0.0009
# Epoch [9/75], Step [300/396], Loss: 0.0090
# Epoch done in  0:02:56.647514
# Epoch  10  started...
# Epoch [10/75], Step [100/396], Loss: 0.0254
# Epoch [10/75], Step [200/396], Loss: 0.0632
# Epoch [10/75], Step [300/396], Loss: 0.0017
# Epoch done in  0:02:57.197602
# Epoch  11  started...
# Epoch [11/75], Step [100/396], Loss: 0.0003
# => Loss reduced by:	 0.0002617388963699341
#    Saving model state
# Epoch [11/75], Step [200/396], Loss: 0.0054
# Epoch [11/75], Step [300/396], Loss: 0.0234
# Epoch done in  0:02:57.165226
# Epoch  12  started...
# Epoch [12/75], Step [100/396], Loss: 0.0009
# Epoch [12/75], Step [200/396], Loss: 0.0006
# Epoch [12/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:56.913101
# Epoch  13  started...
# Epoch [13/75], Step [100/396], Loss: 0.0044
# Epoch [13/75], Step [200/396], Loss: 0.0010
# Epoch [13/75], Step [300/396], Loss: 0.0011
# Epoch done in  0:02:57.778964
# Epoch  14  started...
# Epoch [14/75], Step [100/396], Loss: 0.0017
# Epoch [14/75], Step [200/396], Loss: 0.0002
# => Loss reduced by:	 8.70823860168457e-05
#    Saving model state
# Epoch [14/75], Step [300/396], Loss: 0.0036
# Epoch done in  0:02:57.375711
# Epoch  15  started...
# Epoch [15/75], Step [100/396], Loss: 0.0007
# Epoch [15/75], Step [200/396], Loss: 0.0024
# Epoch [15/75], Step [300/396], Loss: 0.0009
# Epoch done in  0:02:57.527316
# Epoch  16  started...
# Epoch [16/75], Step [100/396], Loss: 0.0008
# Epoch [16/75], Step [200/396], Loss: 0.0027
# Epoch [16/75], Step [300/396], Loss: 0.0098
# Epoch done in  0:02:57.302351
# Epoch  17  started...
# Epoch [17/75], Step [100/396], Loss: 0.0001
# => Loss reduced by:	 0.000145837664604187
#    Saving model state
# Epoch [17/75], Step [200/396], Loss: 0.0008
# Epoch [17/75], Step [300/396], Loss: 0.0115
# Epoch done in  0:02:57.590554
# Epoch  18  started...
# Epoch [18/75], Step [100/396], Loss: 0.0799
# Epoch [18/75], Step [200/396], Loss: 0.5597
# Epoch [18/75], Step [300/396], Loss: 0.0328
# Epoch done in  0:02:57.233115
# Epoch  19  started...
# Epoch [19/75], Step [100/396], Loss: 0.0063
# Epoch [19/75], Step [200/396], Loss: 0.0005
# Epoch [19/75], Step [300/396], Loss: 0.0064
# Epoch done in  0:02:57.417375
# Epoch  20  started...
# Epoch [20/75], Step [100/396], Loss: 0.0002
# Epoch [20/75], Step [200/396], Loss: 0.1856
# Epoch [20/75], Step [300/396], Loss: 0.0005
# Epoch done in  0:02:57.573665
# Epoch  21  started...
# Epoch [21/75], Step [100/396], Loss: 0.0001
# Epoch [21/75], Step [200/396], Loss: 0.0001
# => Loss reduced by:	 1.6510486602783203e-05
#    Saving model state
# Epoch [21/75], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:57.492097
# Epoch  22  started...
# Epoch [22/75], Step [100/396], Loss: 0.0002
# Epoch [22/75], Step [200/396], Loss: 0.0001
# Epoch [22/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:57.214296
# Epoch  23  started...
# Epoch [23/75], Step [100/396], Loss: 0.0042
# Epoch [23/75], Step [200/396], Loss: 0.0004
# Epoch [23/75], Step [300/396], Loss: 0.0004
# Epoch done in  0:02:56.746991
# Epoch  24  started...
# Epoch [24/75], Step [100/396], Loss: 0.0000
# => Loss reduced by:	 1.9297003746032715e-05
#    Saving model state
# Epoch [24/75], Step [200/396], Loss: 0.0001
# Epoch [24/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:57.373791
# Epoch  25  started...
# Epoch [25/75], Step [100/396], Loss: 0.0001
# Epoch [25/75], Step [200/396], Loss: 0.0002
# Epoch [25/75], Step [300/396], Loss: 0.0130
# Epoch done in  0:03:01.497502
# Epoch  26  started...
# Epoch [26/75], Step [100/396], Loss: 0.0089
# Epoch [26/75], Step [200/396], Loss: 0.0008
# Epoch [26/75], Step [300/396], Loss: 0.0016
# Epoch done in  0:02:58.135437
# Epoch  27  started...
# Epoch [27/75], Step [100/396], Loss: 0.0002
# Epoch [27/75], Step [200/396], Loss: 0.0015
# Epoch [27/75], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 3.147125244140625e-05
#    Saving model state
# Epoch done in  0:14:03.452367
# Epoch  28  started...
# Epoch [28/75], Step [100/396], Loss: 0.0009
# Epoch [28/75], Step [200/396], Loss: 0.0207
# Epoch [28/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:09:41.169939
# Epoch  29  started...
# Epoch [29/75], Step [100/396], Loss: 0.0426
# Epoch [29/75], Step [200/396], Loss: 0.0001
# Epoch [29/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:59.035563
# Epoch  30  started...
# Epoch [30/75], Step [100/396], Loss: 0.0001
# Epoch [30/75], Step [200/396], Loss: 0.0017
# Epoch [30/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:58.363704
# Epoch  31  started...
# Epoch [31/75], Step [100/396], Loss: 0.0001
# Epoch [31/75], Step [200/396], Loss: 0.0011
# Epoch [31/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:56.109567
# Epoch  32  started...
# Epoch [32/75], Step [100/396], Loss: 0.0009
# Epoch [32/75], Step [200/396], Loss: 0.0001
# Epoch [32/75], Step [300/396], Loss: 0.0106
# Epoch done in  0:02:55.452657
# Epoch  33  started...
# Epoch [33/75], Step [100/396], Loss: 0.0000
# => Loss reduced by:	 2.0265579223632812e-06
#    Saving model state
# Epoch [33/75], Step [200/396], Loss: 0.0069
# Epoch [33/75], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 1.043081283569336e-06
#    Saving model state
# Epoch done in  0:02:57.138404
# Epoch  34  started...
# Epoch [34/75], Step [100/396], Loss: 0.0000
# Epoch [34/75], Step [200/396], Loss: 0.0001
# Epoch [34/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:54.992191
# Epoch  35  started...
# Epoch [35/75], Step [100/396], Loss: 0.0008
# Epoch [35/75], Step [200/396], Loss: 0.0016
# Epoch [35/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.140965
# Epoch  36  started...
# Epoch [36/75], Step [100/396], Loss: 0.0003
# Epoch [36/75], Step [200/396], Loss: 0.0007
# Epoch [36/75], Step [300/396], Loss: 0.0004
# Epoch done in  0:02:55.775330
# Epoch  37  started...
# Epoch [37/75], Step [100/396], Loss: 0.0000
# Epoch [37/75], Step [200/396], Loss: 0.0004
# Epoch [37/75], Step [300/396], Loss: 0.0005
# Epoch done in  0:02:54.909167
# Epoch  38  started...
# Epoch [38/75], Step [100/396], Loss: 0.0042
# Epoch [38/75], Step [200/396], Loss: 0.0014
# Epoch [38/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.575945
# Epoch  39  started...
# Epoch [39/75], Step [100/396], Loss: 0.0006
# Epoch [39/75], Step [200/396], Loss: 0.0001
# Epoch [39/75], Step [300/396], Loss: 0.0061
# Epoch done in  0:02:55.015589
# Epoch  40  started...
# Epoch [40/75], Step [100/396], Loss: 0.0002
# Epoch [40/75], Step [200/396], Loss: 0.0000
# Epoch [40/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.180229
# Epoch  41  started...
# Epoch [41/75], Step [100/396], Loss: 0.0000
# Epoch [41/75], Step [200/396], Loss: 0.0000
# Epoch [41/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:55.651007
# Epoch  42  started...
# Epoch [42/75], Step [100/396], Loss: 0.2133
# Epoch [42/75], Step [200/396], Loss: 0.0001
# Epoch [42/75], Step [300/396], Loss: 0.0115
# Epoch done in  0:02:55.121562
# Epoch  43  started...
# Epoch [43/75], Step [100/396], Loss: 0.0001
# Epoch [43/75], Step [200/396], Loss: 0.0001
# Epoch [43/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:04:09.672615
# Epoch  44  started...
# Epoch [44/75], Step [100/396], Loss: 0.0009
# Epoch [44/75], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 1.6391277313232422e-06
#    Saving model state
# Epoch [44/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:57.682059
# Epoch  45  started...
# Epoch [45/75], Step [100/396], Loss: 0.0000
# Epoch [45/75], Step [200/396], Loss: 0.0000
# Epoch [45/75], Step [300/396], Loss: 0.0006
# Epoch done in  0:02:55.986426
# Epoch  46  started...
# Epoch [46/75], Step [100/396], Loss: 0.0001
# Epoch [46/75], Step [200/396], Loss: 0.0005
# Epoch [46/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:56.219496
# Epoch  47  started...
# Epoch [47/75], Step [100/396], Loss: 0.0001
# Epoch [47/75], Step [200/396], Loss: 0.3028
# Epoch [47/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:56.417336
# Epoch  48  started...
# Epoch [48/75], Step [100/396], Loss: 0.0002
# Epoch [48/75], Step [200/396], Loss: 0.0029
# Epoch [48/75], Step [300/396], Loss: 0.0006
# Epoch done in  0:02:56.193171
# Epoch  49  started...
# Epoch [49/75], Step [100/396], Loss: 0.0001
# Epoch [49/75], Step [200/396], Loss: 0.0002
# Epoch [49/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:56.042516
# Epoch  50  started...
# Epoch [50/75], Step [100/396], Loss: 0.0000
# Epoch [50/75], Step [200/396], Loss: 0.0000
# Epoch [50/75], Step [300/396], Loss: 0.0036
# Epoch done in  0:02:55.271497
# Epoch  51  started...
# Epoch [51/75], Step [100/396], Loss: 0.0003
# Epoch [51/75], Step [200/396], Loss: 0.0114
# Epoch [51/75], Step [300/396], Loss: 0.0004
# Epoch done in  0:02:55.822468
# Epoch  52  started...
# Epoch [52/75], Step [100/396], Loss: 0.0001
# Epoch [52/75], Step [200/396], Loss: 0.0003
# Epoch [52/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.782842
# Epoch  53  started...
# Epoch [53/75], Step [100/396], Loss: 0.1155
# Epoch [53/75], Step [200/396], Loss: 0.0001
# Epoch [53/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.314317
# Epoch  54  started...
# Epoch [54/75], Step [100/396], Loss: 0.0005
# Epoch [54/75], Step [200/396], Loss: 0.0001
# Epoch [54/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:56.362674
# Epoch  55  started...
# Epoch [55/75], Step [100/396], Loss: 0.0000
# Epoch [55/75], Step [200/396], Loss: 0.0000
# Epoch [55/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:56.388276
# Epoch  56  started...
# Epoch [56/75], Step [100/396], Loss: 0.0003
# Epoch [56/75], Step [200/396], Loss: 0.0001
# Epoch [56/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.475986
# Epoch  57  started...
# Epoch [57/75], Step [100/396], Loss: 0.0004
# Epoch [57/75], Step [200/396], Loss: 0.0004
# Epoch [57/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:56.296901
# Epoch  58  started...
# Epoch [58/75], Step [100/396], Loss: 0.0056
# Epoch [58/75], Step [200/396], Loss: 0.0156
# Epoch [58/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:55.598659
# Epoch  59  started...
# Epoch [59/75], Step [100/396], Loss: 0.0000
# Epoch [59/75], Step [200/396], Loss: 0.0000
# => Loss reduced by:	 1.7881393432617188e-07
#    Saving model state
# Epoch [59/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.479527
# Epoch  60  started...
# Epoch [60/75], Step [100/396], Loss: 0.0006
# Epoch [60/75], Step [200/396], Loss: 0.0000
# Epoch [60/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:54.806845
# Epoch  61  started...
# Epoch [61/75], Step [100/396], Loss: 0.0001
# Epoch [61/75], Step [200/396], Loss: 0.0000
# Epoch [61/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:54.609253
# Epoch  62  started...
# Epoch [62/75], Step [100/396], Loss: 0.0002
# Epoch [62/75], Step [200/396], Loss: 0.0000
# Epoch [62/75], Step [300/396], Loss: 0.0000
# => Loss reduced by:	 1.4901161193847656e-06
#    Saving model state
# Epoch done in  0:02:54.646858
# Epoch  63  started...
# Epoch [63/75], Step [100/396], Loss: 0.0001
# Epoch [63/75], Step [200/396], Loss: 0.0000
# Epoch [63/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.930853
# Epoch  64  started...
# Epoch [64/75], Step [100/396], Loss: 0.0026
# Epoch [64/75], Step [200/396], Loss: 0.0002
# Epoch [64/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:54.780963
# Epoch  65  started...
# Epoch [65/75], Step [100/396], Loss: 0.0001
# Epoch [65/75], Step [200/396], Loss: 0.0004
# Epoch [65/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:54.758671
# Epoch  66  started...
# Epoch [66/75], Step [100/396], Loss: 0.0013
# Epoch [66/75], Step [200/396], Loss: 0.0000
# Epoch [66/75], Step [300/396], Loss: 0.0002
# Epoch done in  0:02:54.300227
# Epoch  67  started...
# Epoch [67/75], Step [100/396], Loss: 0.0004
# Epoch [67/75], Step [200/396], Loss: 0.0000
# Epoch [67/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.235195
# Epoch  68  started...
# Epoch [68/75], Step [100/396], Loss: 0.0000
# Epoch [68/75], Step [200/396], Loss: 0.2972
# Epoch [68/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.162387
# Epoch  69  started...
# Epoch [69/75], Step [100/396], Loss: 0.2625
# Epoch [69/75], Step [200/396], Loss: 0.0000
# Epoch [69/75], Step [300/396], Loss: 0.0003
# Epoch done in  0:02:54.603949
# Epoch  70  started...
# Epoch [70/75], Step [100/396], Loss: 0.0000
# Epoch [70/75], Step [200/396], Loss: 0.0000
# Epoch [70/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:55.106061
# Epoch  71  started...
# Epoch [71/75], Step [100/396], Loss: 0.0007
# Epoch [71/75], Step [200/396], Loss: 0.0075
# Epoch [71/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.291900
# Epoch  72  started...
# Epoch [72/75], Step [100/396], Loss: 0.0052
# Epoch [72/75], Step [200/396], Loss: 0.0000
# Epoch [72/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:54.660379
# Epoch  73  started...
# Epoch [73/75], Step [100/396], Loss: 0.0000
# Epoch [73/75], Step [200/396], Loss: 0.0000
# Epoch [73/75], Step [300/396], Loss: 0.0001
# Epoch done in  0:02:54.998718
# Epoch  74  started...
# Epoch [74/75], Step [100/396], Loss: 0.0000
# Epoch [74/75], Step [200/396], Loss: 0.0002
# Epoch [74/75], Step [300/396], Loss: 0.0000
# Epoch done in  0:02:55.602861
# Epoch  75  started...
# Epoch [75/75], Step [100/396], Loss: 0.0000
# Epoch [75/75], Step [200/396], Loss: 0.0000
# Epoch [75/75], Step [300/396], Loss: 0.0005
# Epoch done in  0:02:55.237033
# Training done in  4:00:06.319677

# %%
#load the best model
model.load_state_dict(torch.load("state_dict.dct"))

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in loader_valid:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'final_state.dct')
# Out:
# Test Accuracy of the model on the test images: 98.67256637168141 %

# %%
files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            files.append(os.path.join(dirname, filename))
print("Processed ",len(files),"files")

labels_dict = {"B_A-":0,"B_F-":1,"B_TA":2,"B_PT":3,"M_DC":4,"M_LC":5,"M_MC":6,"M_PC":7}  # for 8 class problem
labels_dict_simple = {"B":0,"M":1}                                                       # for 2 class problem
REDUCED_CLASSES = True

X = []
Y = []
M = []
for f in files:
    x = f.split("/") # break up the path
    x = x[-1:][0]    # extract the file name
    X.append(str(f))
    if REDUCED_CLASSES:
        Y.append(int(labels_dict_simple[x[4]]))
    else:
        Y.append(int(labels_dict[x[4:8]]))
    m = f.split("-")
    m = m[-2]
    M.append(m)

data = {"images":X,"labels":Y,"magnification":M }
images_df_t = pd.DataFrame(data, columns = ['images','labels'])
images_df = pd.DataFrame(data, columns = ['images','labels','magnification'])
images_df_40 = images_df.loc[images_df['magnification']=='40'].drop(['magnification'], axis=1)
images_df_100 = images_df.loc[images_df['magnification']=='100'].drop(['magnification'], axis=1)
images_df_200 = images_df.loc[images_df['magnification']=='200'].drop(['magnification'], axis=1)
images_df_400 = images_df.loc[images_df['magnification']=='400'].drop(['magnification'], axis=1)

dataset_img40 = MyDataset(df_data=images_df_40, transform=trans_valid)
loader_img40 = DataLoader(dataset = dataset_img40, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img100 = MyDataset(df_data=images_df_100, transform=trans_valid)
loader_img100 = DataLoader(dataset = dataset_img100, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img200 = MyDataset(df_data=images_df_200, transform=trans_valid)
loader_img200 = DataLoader(dataset = dataset_img200, batch_size=batch_size//2, shuffle=False, num_workers=0)

dataset_img400 = MyDataset(df_data=images_df_400, transform=trans_valid)
loader_img400 = DataLoader(dataset = dataset_img400, batch_size=batch_size//2, shuffle=False, num_workers=0)
l_list = [loader_img40,loader_img100,loader_img200,loader_img400]
# Out:
# Processed  7909 files

# %%
model.load_state_dict(torch.load('final_state.dct'))
model.eval()
count = 0
for l in l_list:
    count+=1
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in l:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _,predicted = torch.max(outputs.data,1)
            total+=labels.size(0)
            correct+= (predicted==labels).sum().item()
        print('Test Accuracy of model on {} is {} %'.format(count,100*(correct/total)))
# Out:
# Test Accuracy of model on 1 is 99.84962406015038 %
# Test Accuracy of model on 2 is 99.85583853916387 %
# Test Accuracy of model on 3 is 99.85096870342772 %
# Test Accuracy of model on 4 is 99.34065934065934 %

# %%
timestamp_exec_end = time.time()
print("Total execution time: ",str(datetime.timedelta(seconds=(timestamp_exec_end - timestamp_exec_start))))
# Out:
# Total execution time:  4:03:09.897771
